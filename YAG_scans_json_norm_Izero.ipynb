# %%
# %matplotlib nbagg
import numpy as np
import json
import h5py
import matplotlib.pyplot as plt
import scipy
from scipy.special import erf
from scipy.optimize import curve_fit
import os
import sys

# %%
channel_PIPS_trans = "SARES11-GES1:CH1_VAL_GET/data"           #X-ray TRANS diode to PRIME Keysight (channel 1)
channel_PIPS_fluo = "SARES11-GES1:CH2_VAL_GET/data"            #X-ray FLUO diode to PRIME Keysight (channel 2)

#channel_Izero2 = "SARES11-LSCP10-FNS:CH3:VAL_GET/data"          #Izero diode to PRIME Ioxos (channel 3)
#channel_Izero = "SARES11-LSCP10-FNS:CH2:VAL_GET/data"          #Izero diode to PRIME Ioxos (channel 0)
#channel_Izero3 = "SARES11-LSCP10-FNS:CH1:VAL_GET/data"          #Izero diode to PRIME Ioxos (channel 1)
#channel_Izero4 = "SARES11-LSCP10-FNS:CH2:VAL_GET/data"         #Izero diode to PRIME Ioxos (channel 2)

channel_Izero = "SAROP11-CVME-PBPS2:Lnk9Ch12-DATA-SUM/data"            #Izero diode to Wavedream PBPS117 (Up - PDU)
channel_Izero2 = "SAROP11-CVME-PBPS2:Lnk9Ch13-DATA-SUM/data"           #Izero diode to Wavedream PBPS117 (Down - PDD)
channel_Izero3 = "SAROP11-CVME-PBPS2:Lnk9Ch14-DATA-SUM/data"           #Izero diode to Wavedream PBPS117 (Right - PDR)
channel_Izero4 = "SAROP11-CVME-PBPS2:Lnk9Ch15-DATA-SUM/data"           #Izero diode to Wavedream PBPS117 (Left - PDL)

channel_pulse_ids = "SLAAR11-LMOT-M451:ENC_1_BS/pulse_id"      #Pulse ids taken from pump-probe delay stage (100 Hz)

channel_LaserDiode = "SLAAR11-LSCP1-FNS:CH0:VAL_GET/data"      #Laser diode to ESA Laser Ioxos 
channel_Laser_refDiode = "SLAAR11-LSCP1-FNS:CH2:VAL_GET/data"  #Laser diode leaking from beampath, to ESA Laser Ioxos 
channel_delay = "SLAAR11-LMOT-M451:ENC_1_BS/data"              #Delay of pump-probe delay stage
channel_LAM_delaystage = "SLAAR11-LTIM01-EVR0:DUMMY_PV2_NBS/data"       #LAM internal stage position in mm
channel_LAM_stepper = "SLAAR11-LTIM01-EVR0:DUMMY_PV10_NBS/data"         #LAM stepper motor (used for feedback)
channel_PALM_eTOF = "SAROP11-PALMK118:CH2_BUFFER/data"                 #PALM eTof from Ch2
channel_PALM_drift = "SAROP11-PALMK118:CH2_VAL_GET/data"               #PALM drift

channel_laser_yaw= "SLAAR11-LTIM01-EVR0:DUMMY_PV2_NBS/data"
channel_laser_pitch= "SLAAR11-LTIM01-EVR0:DUMMY_PV4_NBS/data"

# testing this palm channel and see what drift it reports 
channel_BAM = "SLAAR11-LTIM01-EVR0:DUMMY_PV9_NBS/data" # SLAAR-GEN:PALM-RAVE CP NMS
#channel_BAM = "SAROP11-PALMK118:CH2_VAL_GET/data" 
#channel_BAM = "S10BC01-DBAM070:EOM1_T1/data"

# %%
def LoadData_YAG(filename):
    with h5py.File(filename, 'r') as BS_file:
        pulse_ids = BS_file[channel_pulse_ids][:]
        #reprate_FEL = pulse_ids%4 == 0  
        #reprate_laser = ((pulse_ids%2 == 0) & (pulse_ids%4 != 0))           #This is for 50 Hz (laser)
        
        reprate_FEL = pulse_ids%2 == 0  
        reprate_laser = ((pulse_ids%1 == 0) & (pulse_ids%2 != 0))           #This is for 100 Hz (laser)
    
        
        LaserDiode_pump = BS_file[channel_LaserDiode][:][reprate_FEL]
        LaserDiode_unpump = BS_file[channel_LaserDiode][:][reprate_laser]
        Izero_pump = BS_file[channel_Izero][:][reprate_FEL]
        Izero_unpump = BS_file[channel_Izero][:][reprate_laser]
        PIPS = BS_file[channel_PIPS_trans][:][reprate_FEL]
        LaserRefDiode = BS_file[channel_Laser_refDiode][:][reprate_laser]
        Delay = BS_file[channel_delay][:][reprate_laser]
        #Delay = BS_file[channel_laser_pitch][:][reprate_laser]
        
        BAM = BS_file[channel_BAM][:][reprate_FEL]

        
    return LaserDiode_pump, LaserDiode_unpump, Izero_pump, Izero_unpump, PIPS, LaserRefDiode, Delay, BAM

def errfunc(x, a, b, c, d):
    return a + b*erf((c-x)*2*np.sqrt(np.log(2))/(np.abs(d)))

# %%
scan_name ="YAG_FEL0.1_laser4uJ_004"
#scan_name ="Overlap_pitch_ref_008"

DIR = "/sf/alvra/data/p17807/res/scan_data/" + scan_name + "/"
#DIR = "/sf/alvra/data/p17803/res/scan_data/" + scan_name + "/"
DIR_json = "/sf/alvra/data/p17807/res/scan_info/"

# %%
# !ls -lah -rt $DIR


# !hostname

listfile = os.listdir(DIR)
number_files = len(listfile)
print ("There are",number_files,"files in the folder", DIR)
# Out:
# total 1.4G
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:37 YAG_FEL0.1_laser4uJ_004_step0000.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:39 YAG_FEL0.1_laser4uJ_004_step0002.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:39 YAG_FEL0.1_laser4uJ_004_step0003.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:39 YAG_FEL0.1_laser4uJ_004_step0004.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:40 YAG_FEL0.1_laser4uJ_004_step0005.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:40 YAG_FEL0.1_laser4uJ_004_step0006.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:40 YAG_FEL0.1_laser4uJ_004_step0007.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:41 YAG_FEL0.1_laser4uJ_004_step0008.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:41 YAG_FEL0.1_laser4uJ_004_step0009.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:42 YAG_FEL0.1_laser4uJ_004_step0010.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:42 YAG_FEL0.1_laser4uJ_004_step0011.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:42 YAG_FEL0.1_laser4uJ_004_step0012.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:43 YAG_FEL0.1_laser4uJ_004_step0013.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:43 YAG_FEL0.1_laser4uJ_004_step0014.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:43 YAG_FEL0.1_laser4uJ_004_step0015.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:44 YAG_FEL0.1_laser4uJ_004_step0016.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:44 YAG_FEL0.1_laser4uJ_004_step0017.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:44 YAG_FEL0.1_laser4uJ_004_step0018.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:45 YAG_FEL0.1_laser4uJ_004_step0019.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:45 YAG_FEL0.1_laser4uJ_004_step0020.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:46 YAG_FEL0.1_laser4uJ_004_step0021.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:46 YAG_FEL0.1_laser4uJ_004_step0022.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:46 YAG_FEL0.1_laser4uJ_004_step0023.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:47 YAG_FEL0.1_laser4uJ_004_step0024.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:47 YAG_FEL0.1_laser4uJ_004_step0025.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:47 YAG_FEL0.1_laser4uJ_004_step0026.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:48 YAG_FEL0.1_laser4uJ_004_step0027.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:48 YAG_FEL0.1_laser4uJ_004_step0028.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:48 YAG_FEL0.1_laser4uJ_004_step0029.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:49 YAG_FEL0.1_laser4uJ_004_step0030.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:49 YAG_FEL0.1_laser4uJ_004_step0031.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:50 YAG_FEL0.1_laser4uJ_004_step0032.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:50 YAG_FEL0.1_laser4uJ_004_step0033.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:50 YAG_FEL0.1_laser4uJ_004_step0034.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:51 YAG_FEL0.1_laser4uJ_004_step0035.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:51 YAG_FEL0.1_laser4uJ_004_step0036.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:51 YAG_FEL0.1_laser4uJ_004_step0037.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:52 YAG_FEL0.1_laser4uJ_004_step0038.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:52 YAG_FEL0.1_laser4uJ_004_step0039.h5
# -rw-r--r--.  1 39147 p17807  34M Mar  5 09:52 YAG_FEL0.1_laser4uJ_004_step0040.h5
# drwxrwsr-x.  2 39147 p17807 4.0K Mar  5 09:53 .
# drwxrwsr-x. 46 39147 p17807 4.0K Mar  9 04:47 ..
# ra-c-003.psi.ch
# There are 40 files in the folder /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/

# %%
json_file = DIR_json + scan_name + "_scan_info.json"
print (json_file)

with open(json_file) as file:
    data = json.load(file)
numFiles = len(data['scan_files'])
#numFiles = 1

print ("Processing",numFiles,"files")
print (json_file)

Laser_pump = []
err_laser_pump = []
Laser_unpump = []
err_laser_unpump = [] 
Izero_pump = []
err_Izero_pump = []
Izero_unpump = []
err_Izero_unpump = []
PIPS = []
Laser_ref = []
Delay_mm = []
BAM = []
BAM_error = []

for i in range(0,numFiles):
    filename = str(data['scan_files'][i][0])
    exists = os.path.isfile(filename)

    if exists:
        print("step",i+1,"of",numFiles,": Processing %s" % (str(data['scan_files'][i][0])))
        (Laser_pump_loop,Laser_unpump_loop,Izero_pump_loop,Izero_unpump_loop,PIPS_loop,Laser_ref_loop,delay_loop,BAM_loop) = LoadData_YAG(str(data['scan_files'][i][0]))
        
        #threshold_pump = Izero_pump_loop > 0
        threshold_unpump = Izero_unpump_loop > 0.03 
        #condition_pump = Izero_pump_loop > np.median(Izero_pump_loop)-1.2*(np.std(Izero_pump_loop))
        condition_unpump = Izero_unpump_loop > np.median(Izero_unpump_loop)-2*(np.std(Izero_unpump_loop))

        #Laser_pump_loop = Laser_pump_loop[condition_pump & threshold_pump]
        
        Laser_pump.append(Laser_pump_loop.mean())
        err_laser_pump.append(Laser_pump_loop.std()/np.sqrt(Laser_pump_loop.size))
        Laser_unpump.append(Laser_unpump_loop.mean())
        err_laser_unpump.append(Laser_unpump_loop.std()/np.sqrt(Laser_unpump_loop.size))
        
        Izero_pump.append(Izero_pump_loop.mean())
        err_Izero_pump.append(Izero_pump_loop.std()/np.sqrt(Izero_pump_loop.size))
        Izero_unpump.append(Izero_unpump_loop.mean())
        err_Izero_unpump.append(Izero_unpump_loop.std()/np.sqrt(Izero_unpump_loop.size))
        
        PIPS.append(PIPS_loop.mean())
        Laser_ref.append(Laser_ref_loop.mean())
        Delay_mm.append(delay_loop.mean())
        BAM.append(BAM_loop.mean())
        BAM_error.append(BAM_loop.std()/np.sqrt(BAM_loop.size))
    
Laser_pump = np.asarray(Laser_pump)
err_laser_pump = np.asarray(err_laser_pump)
Laser_unpump = np.asarray(Laser_unpump)
err_laser_unpump = np.asarray(err_laser_unpump)
Izero_pump = np.asarray(Izero_pump)
err_Izero_pump = np.asarray(err_Izero_pump)
Izero_unpump = np.asarray(Izero_unpump)
err_Izero_unpump = np.asarray(err_Izero_unpump)
Delay_mm = np.asarray(Delay_mm)
BAM = np.asarray(BAM)
BAM_error = np.asarray(BAM_error)
# Out:
# /sf/alvra/data/p17807/res/scan_info/YAG_FEL0.1_laser4uJ_004_scan_info.json
# Processing 41 files
# /sf/alvra/data/p17807/res/scan_info/YAG_FEL0.1_laser4uJ_004_scan_info.json
# step 1 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0000.h5
# step 3 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0002.h5
# step 4 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0003.h5
# step 5 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0004.h5
# step 6 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0005.h5
# step 7 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0006.h5
# step 8 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0007.h5
# step 9 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0008.h5
# step 10 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0009.h5
# step 11 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0010.h5
# step 12 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0011.h5
# step 13 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0012.h5
# step 14 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0013.h5
# step 15 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0014.h5
# step 16 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0015.h5
# step 17 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0016.h5
# step 18 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0017.h5
# step 19 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0018.h5
# step 20 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0019.h5
# step 21 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0020.h5
# step 22 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0021.h5
# step 23 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0022.h5
# step 24 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0023.h5
# step 25 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0024.h5
# step 26 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0025.h5
# step 27 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0026.h5
# step 28 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0027.h5
# step 29 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0028.h5
# step 30 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0029.h5
# step 31 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0030.h5
# step 32 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0031.h5
# step 33 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0032.h5
# step 34 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0033.h5
# step 35 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0034.h5
# step 36 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0035.h5
# step 37 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0036.h5
# step 38 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0037.h5
# step 39 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0038.h5
# step 40 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0039.h5
# step 41 of 41 : Processing /sf/alvra/data/p17807/res/scan_data/YAG_FEL0.1_laser4uJ_004/YAG_FEL0.1_laser4uJ_004_step0040.h5

# %%
Laser_pump_loop[0:10]
# Out:
# array([6830.18518519, 6894.25925926, 6907.7037037 , 6893.25925926,
#        6912.39506173, 6871.98765432, 6876.98765432, 6732.88888889,
#        6833.28395062, 6784.88888889])

# %%
Laser_unpump_loop[0:10]
# Out:
# array([6907.37037037, 6653.24691358, 6766.09876543, 6916.12345679,
#        6814.12345679, 6780.58024691, 6821.02469136, 6774.74074074,
#        6821.55555556, 6801.56790123])

# %%
num_bins = 50

plt.figure(figsize=(5,10))

plt.subplot(211)
plt.plot(Delay_mm, BAM)
low_err = BAM - BAM_error
high_err = BAM + BAM_error
plt.fill_between(np.squeeze(Delay_mm), low_err, high_err, color='lightblue')
plt.title(DIR)

plt.subplot(212)
plt.hist(BAM_loop, num_bins, facecolor='blue', alpha=0.5)
plt.title(filename)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
num_bins = 50
print (Izero_pump_loop.size)
plt.figure()
plt.hist(Izero_pump_loop, num_bins, facecolor='blue', alpha=0.5)
#plt.hist(Izero_pump_loop, num_bins, facecolor='blue', alpha=0.5)
plt.title(DIR)


plt.show()
# Out:
# 250
# <img src="data:image/png;base64,..." width="640">

# %%
laser_pumped_norm = Laser_pump / Izero_pump
#err_laser_pumped_norm = err_laser_pump / Izero_pump
laser_unpumped_norm = Laser_unpump #/ Izero_unpump
#err_laser_unpumped_norm = err_laser_unpump # / Izero_unpump

#Normalization only with Izero_pump (when FEL is present)
laser_pump_norm = Laser_pump / Izero_pump
err_laser_pump_norm = err_laser_pump / Izero_pump
laser_unpump_norm = Laser_unpump / Izero_pump
err_laser_unpump_norm = err_laser_unpump / Izero_pump

laser_diff = -np.log10(laser_pump_norm / laser_unpump_norm)
#laser_diff = laser_pumped / Laser_unpumped # * (Izero_pumped / Izero_global) 
Delay_ps = (Delay_mm - 146.611)*3.333   # factor of 2 in delay due to the delay stage is considered below.
# here to add the time zero value

# %%
# Plot pump probe signal as a function of delay (stage mm)

#savedir = "/das/work/p17/p17569/Beamline/"
plt.figure()
plt.plot(Delay_mm, laser_diff, label="FEL on - FEL off",marker='.')
low_err= (-np.log10(laser_pump_norm / laser_unpump_norm) ) - (np.sqrt((err_laser_pump_norm/laser_pump_norm)**2+(err_laser_unpump_norm/laser_unpump_norm)**2))
high_err= (-np.log10(laser_pump_norm / laser_unpump_norm) ) + (np.sqrt((err_laser_pump_norm/laser_pump_norm)**2+(err_laser_unpump_norm/laser_unpump_norm)**2))
plt.fill_between(np.squeeze(Delay_mm), low_err, high_err, color='lightblue')
plt.title(scan_name)
plt.xlabel("Delay (mm)")
plt.legend(loc="best")
plt.grid()
plt.show()
#plt.savefig(savedir + 'LAMcheck_026')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Plot pump probe signal as a function of time (fs)

#savedir = "/das/work/p17/p17569/Beamline/"
plt.figure()
plt.plot((2*Delay_ps)*1000, laser_diff, label="FEL on - FEL off",marker='.')

low_err= (-np.log10(laser_pump_norm / laser_unpump_norm) ) - (np.sqrt((err_laser_pump_norm/laser_pump_norm)**2+(err_laser_unpump_norm/laser_unpump_norm)**2))
high_err= (-np.log10(laser_pump_norm / laser_unpump_norm) ) + (np.sqrt((err_laser_pump_norm/laser_pump_norm)**2+(err_laser_unpump_norm/laser_unpump_norm)**2))
plt.fill_between(np.squeeze((2*Delay_ps)*1000), low_err, high_err, color='lightblue')

plt.title(scan_name)
plt.xlabel("Delay (fs)")
plt.legend(loc="best")
plt.grid()
plt.show()
#plt.savefig('Timescan_7_diode')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#RUN THIS FOR THE FIT !!!

Delay_mm_toFit = Delay_mm.copy()
Delay_ps_toFit = Delay_ps.copy()
laser_diff_toFit = laser_diff.copy()

# %%
# Now fit with error funciton (defined above)
parameters,extras = curve_fit(errfunc, Delay_mm_toFit, laser_diff_toFit, p0 = [0.05, 1, 148.73, 0.5])

print("Position t0 =",np.abs(np.round(parameters[2],3)),"mm")
print("Width =",np.abs(np.round(parameters[3],3)),"mm")
# Out:
# Position t0 = 148.731 mm
# Width = 0.009 mm

# %%
#... and the plot with the fit curve

#savedir = "/das/work/p17/p17569/Beamline/"

plt.figure()

plt.plot(Delay_mm_toFit, laser_diff_toFit, label="scan_022",marker='.')
plt.plot(Delay_mm_toFit, errfunc(Delay_mm_toFit,*parameters))

#low_err= signal_norm - err_signal_norm
#high_err= signal_norm + err_signal_norm

plt.fill_between(Delay_mm_toFit, low_err, high_err, color='lightblue')
plt.title(np.round(parameters[2], 3) )
plt.grid()
plt.xlabel("Delay (mm)")
plt.legend(loc="best")
plt.show()
#plt.savefig(savedir + 'scan_YAG_007')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Next cell  just to calculate time zero

# %%
time_zero = 146.615      #this is in mm from the delay scans

desidered_delay = 0.750
#choose this in ps

delay_to_set = (100/(2*333))*desidered_delay + time_zero        #factor of 2 because of the delay stage

desidered_delay + time_zero
print ("To be at",desidered_delay,"ps, put the laser pump delay stage to",np.round(delay_to_set,4),"mm")
# Out:
# To be at 0.75 ps, put the laser pump delay stage to 146.7276 mm

# %%
offset_space = 400       # this is in um

offset_time = 2*(offset_space * 1e-6)/3e8/1e-15            #factor of 2 because of the delay stage, results in fs
print ("An offset of",offset_space,"um corresponds to an offset of",np.round(offset_time,4),"fs")
# Out:
# An offset of 400 um corresponds to an offset of 2666.6667 fs

# %%
offset_time = 600      # this is in fs

offset_space = 3e8 * (offset_time * 1e-15)/2/1e-6          #factor of 2 because of the delay stage, results in um
print ("An offset of",offset_time,"fs corresponds to an offset of",np.round(offset_space,4),"um")
# Out:
# An offset of 600 fs corresponds to an offset of 90.0 um

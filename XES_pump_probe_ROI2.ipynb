# %%
# %matplotlib nbagg
import jungfrau_utils as ju
import numpy as np
import json
import os
import time
from matplotlib import pyplot as plt
from matplotlib import cm
from scipy.optimize import curve_fit
from IPython.display import clear_output, display
import matplotlib.colors as colors

import h5py
 

    
from alvra_tools import *
from alvra_tools.channels import *
#from alvra_tools.channels_raw import *

# %%
# Choose a pedestal file (usually located in /sf/alvra/data/*pgroup*/res/JF_pedestals) 
# if you do not want to use the closest in time

# pedestal_file = "/sf/alvra/data/p17983/res/JF_pedestals/pedestal_20190727_2115.JF02T09V02.res.h5"
pedestal_file = None

# %%
#scan_name ="RuFoil_RIXS"
scan_name ="XAS-L-cystine-monoscan"
scan_range = ".run002119-002167"

DIR = "/sf/alvra/data/p18387/raw/scan_data/" + scan_name + "/"
#DIR = "/sf/alvra/data/p18387/raw/XES-L-cystine-2ps/"  
#DIR = "/sf/alvra/data/p18442/raw/scan_data/RuBpy_RIXS_6/"

#DIR_json = "/das/work/p17/p17983/Example_data/res/scan_info/"
#DIR_json = "/sf/alvra/data/p18387/res/scan_info/"
DIR_json = "/sf/alvra/data/p18387/raw/XES_pellet/"


#scan_range = ".run001515-001545"


# !ls -lah -t $DIR

# !hostname

listfile = os.listdir(DIR)
number_files = len(listfile)
print ("There are",number_files,"files in the folder", DIR)
# Out:
# total 3.2T
# drwxrwsr-x.  2 root p18387   64K Feb 23 13:55 .
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002445.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002444.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002445.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002443.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002444.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002442.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002441.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002443.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002442.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002440.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002441.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002439.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002440.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002438.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002439.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002437.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002438.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002436.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002437.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002435.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002434.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002436.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002433.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002435.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002434.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002432.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002431.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002433.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002432.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002430.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002431.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002429.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002430.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002428.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002429.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002427.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002428.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002426.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002425.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002427.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002426.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002424.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002425.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002423.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002422.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002424.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002421.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002423.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002422.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002420.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002421.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002419.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002420.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002418.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002417.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002419.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002418.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002416.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002417.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002415.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002416.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002414.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002415.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002413.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002414.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002412.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002413.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002411.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002412.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002410.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002411.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002409.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002410.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002408.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002407.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002409.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002406.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002408.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002405.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002407.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002404.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002406.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002403.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002405.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002404.JF02T09V02.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002402.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002401.BSREAD.h5
# -rw-r--r--.  1 root p18387     0 Feb 23 13:55 run_002403.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002196.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002195.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002176.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002194.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002190.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002172.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002173.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002161.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002185.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002186.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002188.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002184.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002169.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002171.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002181.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002168.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002179.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:25 run_002177.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:24 run_002170.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:24 run_002167.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:24 run_002166.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:24 run_002165.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:24 run_002162.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:24 run_002164.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:24 run_002163.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:24 run_002158.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:24 run_002159.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:24 run_002160.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002017.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002009.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002016.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002012.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002014.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002015.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002010.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002008.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002013.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002011.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002004.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002003.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002007.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002005.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002002.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002001.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002006.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_002000.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:22 run_001999.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001998.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001994.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001997.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001993.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001996.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001991.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001995.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001992.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001990.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001988.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001989.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001986.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001987.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001981.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001985.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001984.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001978.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001980.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001976.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001977.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001983.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001979.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001982.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001972.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001975.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001973.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001974.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001971.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 12:21 run_001970.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  1.5G Feb 23 12:18 run_002402.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  990M Feb 23 12:18 run_002400.BSREAD.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:18 run_002401.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  990M Feb 23 12:16 run_002399.BSREAD.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:16 run_002400.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  990M Feb 23 12:14 run_002398.BSREAD.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:14 run_002399.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  990M Feb 23 12:13 run_002397.BSREAD.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:13 run_002398.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 12:11 run_002397.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 11:47 run_002204.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 11:47 run_002205.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 11:47 run_002201.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 11:47 run_002200.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 11:47 run_002202.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 11:47 run_002197.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 11:47 run_002199.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 11:47 run_002206.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 11:47 run_002192.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 23 11:47 run_002203.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 11:47 run_002191.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 11:47 run_002198.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 11:47 run_002193.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 11:47 run_002189.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 11:47 run_002182.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 11:47 run_002183.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 11:47 run_002180.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  9.8G Feb 23 11:47 run_002178.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:44 run_002236.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:44 run_002235.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:44 run_002234.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:44 run_002233.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:44 run_002232.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:43 run_002231.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:43 run_002230.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:43 run_002229.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:42 run_002228.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:42 run_002227.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:42 run_002226.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:42 run_002225.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:41 run_002224.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:40 run_002223.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:40 run_002222.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:40 run_002221.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:40 run_002220.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:39 run_002219.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:39 run_002218.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:39 run_002217.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:38 run_002216.BSREAD.h5
# -rw-r--r--.  1 root p18387  133M Feb 23 08:37 run_002215.BSREAD.h5
# -rw-r--r--.  1 root p18387  531M Feb 23 08:37 run_002206.BSREAD.h5
# -rw-r--r--.  1 root p18387  531M Feb 23 08:37 run_002205.BSREAD.h5
# -rw-r--r--.  1 root p18387  531M Feb 23 08:36 run_002204.BSREAD.h5
# -rw-r--r--.  1 root p18387  531M Feb 23 08:36 run_002203.BSREAD.h5
# -rw-r--r--.  1 root p18387  531M Feb 23 08:35 run_002202.BSREAD.h5
# -rw-r--r--.  1 root p18387  531M Feb 23 08:35 run_002201.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:34 run_002200.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:33 run_002199.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:32 run_002198.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:30 run_002197.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:29 run_002196.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:27 run_002195.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:27 run_002194.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:25 run_002182.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:23 run_002181.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:22 run_002180.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:20 run_002179.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:19 run_002178.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:18 run_002177.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:16 run_002176.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:15 run_002175.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:14 run_002174.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:12 run_002173.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:11 run_002172.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:10 run_002171.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:08 run_002170.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:07 run_002169.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:06 run_002168.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:04 run_002167.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:03 run_002166.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 08:01 run_002165.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 07:49 run_002164.BSREAD.h5
# -rw-r--r--.  1 root p18387  850K Feb 23 07:48 run_002163.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 07:48 run_002163.BSREAD.h5
# -rw-r--r--.  1 root p18387   800 Feb 23 07:46 run_002162.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387   800 Feb 23 07:46 run_002157.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 23 07:46 run_002157.BSREAD.h5
# -rw-r--r--.  1 root p18387   800 Feb 23 07:44 run_002156.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 23 07:44 run_002156.BSREAD.h5
# -rw-r--r--.  1 root p18387   14M Feb 23 07:43 run_002155.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 23 07:43 run_002155.BSREAD.h5
# -rw-r--r--.  1 root p18387   22M Feb 23 07:42 run_002154.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 23 07:42 run_002154.BSREAD.h5
# -rw-r--r--.  1 root p18387  9.9M Feb 23 07:41 run_002153.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 23 07:41 run_002153.BSREAD.h5
# -rw-r--r--.  1 root p18387   800 Feb 23 07:41 run_002152.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 23 07:40 run_002152.BSREAD.h5
# -rw-r--r--.  1 root p18387   26M Feb 23 07:40 run_002151.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 23 07:39 run_002151.BSREAD.h5
# -rw-r--r--.  1 root p18387   800 Feb 23 07:39 run_002150.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 23 07:39 run_002150.BSREAD.h5
# -rw-r--r--.  1 root p18387   23M Feb 23 07:38 run_002149.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 23 07:38 run_002149.BSREAD.h5
# -rw-r--r--.  1 root p18387  9.9M Feb 23 07:37 run_002148.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387 1001M Feb 23 02:28 run_002236.JF02T09V02.h5
# -rw-r--r--.  1 root p18387 1001M Feb 23 02:27 run_002235.JF02T09V02.h5
# -rw-r--r--.  1 root p18387 1001M Feb 23 02:27 run_002234.JF02T09V02.h5
# -rw-r--r--.  1 root p18387 1001M Feb 23 02:27 run_002233.JF02T09V02.h5
# -rw-r--r--.  1 root p18387 1001M Feb 23 02:26 run_002232.JF02T09V02.h5
# -rw-r--r--.  1 root p18387 1001M Feb 23 02:26 run_002231.JF02T09V02.h5
BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387   811 Feb 22 23:42 run_002123.BSREAD.IMAGES.h5.err
# -rw-r--r--.  1 root p18387  531M Feb 22 23:41 run_002123.BSREAD.h5
# -rw-r--r--.  1 root p18387  248M Feb 22 23:41 run_002122.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387   811 Feb 22 23:41 run_002122.BSREAD.IMAGES.h5.err
# -rw-r--r--.  1 root p18387  531M Feb 22 23:40 run_002122.BSREAD.h5
# -rw-r--r--.  1 root p18387  274M Feb 22 23:40 run_002121.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387   811 Feb 22 23:40 run_002121.BSREAD.IMAGES.h5.err
# -rw-r--r--.  1 root p18387  531M Feb 22 23:40 run_002121.BSREAD.h5
# -rw-r--r--.  1 root p18387   50M Feb 22 23:39 run_002120.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387   811 Feb 22 23:39 run_002120.BSREAD.IMAGES.h5.err
# -rw-r--r--.  1 root p18387  531M Feb 22 23:39 run_002120.BSREAD.h5
# -rw-r--r--.  1 root p18387  323M Feb 22 23:38 run_002119.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387   811 Feb 22 23:38 run_002119.BSREAD.IMAGES.h5.err
# -rw-r--r--.  1 root p18387  531M Feb 22 23:38 run_002119.BSREAD.h5
# drwxrwsr-x. 20 root p18387  4.0K Feb 22 22:45 ..
# -rw-r--r--.  1 root p18387  652M Feb 22 20:38 run_002017.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:38 run_002017.BSREAD.h5
# -rw-r--r--.  1 root p18387  652M Feb 22 20:37 run_002016.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:37 run_002016.BSREAD.h5
# -rw-r--r--.  1 root p18387  652M Feb 22 20:37 run_002015.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:37 run_002015.BSREAD.h5
# -rw-r--r--.  1 root p18387  652M Feb 22 20:36 run_002014.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:36 run_002014.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:35 run_002013.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:35 run_002013.BSREAD.h5
# -rw-r--r--.  1 root p18387  654M Feb 22 20:34 run_002012.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:34 run_002012.BSREAD.h5
# -rw-r--r--.  1 root p18387  654M Feb 22 20:33 run_002011.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:33 run_002011.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:32 run_002010.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:32 run_002010.BSREAD.h5
# -rw-r--r--.  1 root p18387  652M Feb 22 20:31 run_002009.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:31 run_002009.BSREAD.h5
# -rw-r--r--.  1 root p18387  652M Feb 22 20:31 run_002008.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:30 run_002008.BSREAD.h5
# -rw-r--r--.  1 root p18387  652M Feb 22 20:30 run_002007.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:30 run_002007.BSREAD.h5
# -rw-r--r--.  1 root p18387  652M Feb 22 20:29 run_002006.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:29 run_002006.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:28 run_002005.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:28 run_002005.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:27 run_002004.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:27 run_002004.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:26 run_002003.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:26 run_002003.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:25 run_002002.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:25 run_002002.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:24 run_002001.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:24 run_002001.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:23 run_002000.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:23 run_002000.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:23 run_001999.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:22 run_001999.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:22 run_001998.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:22 run_001998.BSREAD.h5
# -rw-r--r--.  1 root p18387  652M Feb 22 20:21 run_001997.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:21 run_001997.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:20 run_001996.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:20 run_001996.BSREAD.h5
# -rw-r--r--.  1 root p18387  652M Feb 22 20:19 run_001995.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:19 run_001995.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:18 run_001994.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:18 run_001994.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:17 run_001993.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:17 run_001993.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:16 run_001992.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:16 run_001992.BSREAD.h5
# -rw-r--r--.  1 root p18387  652M Feb 22 20:15 run_001991.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:15 run_001991.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:15 run_001990.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:15 run_001990.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:14 run_001989.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:14 run_001989.BSREAD.h5
# -rw-r--r--.  1 root p18387  652M Feb 22 20:13 run_001988.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:13 run_001988.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:12 run_001987.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:12 run_001987.BSREAD.h5
# -rw-r--r--.  1 root p18387  652M Feb 22 20:11 run_001986.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:11 run_001986.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:10 run_001985.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:10 run_001985.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:09 run_001984.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:09 run_001984.BSREAD.h5
# -rw-r--r--.  1 root p18387  652M Feb 22 20:08 run_001983.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:08 run_001983.BSREAD.h5
# -rw-r--r--.  1 root p18387  652M Feb 22 20:08 run_001982.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:07 run_001982.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:07 run_001981.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:07 run_001981.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:06 run_001980.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:06 run_001980.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:05 run_001979.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:05 run_001979.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:04 run_001978.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:04 run_001978.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:03 run_001977.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:03 run_001977.BSREAD.h5
# -rw-r--r--.  1 root p18387  653M Feb 22 20:02 run_001976.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:02 run_001976.BSREAD.h5
# -rw-r--r--.  1 root p18387  652M Feb 22 20:01 run_001975.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:01 run_001975.BSREAD.h5
# -rw-r--r--.  1 root p18387  643M Feb 22 20:01 run_001974.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:01 run_001974.BSREAD.h5
# -rw-r--r--.  1 root p18387  644M Feb 22 20:00 run_001973.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 20:00 run_001973.BSREAD.h5
# -rw-r--r--.  1 root p18387  644M Feb 22 19:59 run_001972.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 19:59 run_001972.BSREAD.h5
# -rw-r--r--.  1 root p18387  644M Feb 22 19:58 run_001971.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 19:58 run_001971.BSREAD.h5
# -rw-r--r--.  1 root p18387  644M Feb 22 19:57 run_001970.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 19:57 run_001970.BSREAD.h5
# -rw-r--r--.  1 root p18387  642M Feb 22 19:56 run_001969.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 22 19:56 run_001969.BSREAD.h5
# -rw-r--r--.  1 root p18387  4.0G Feb 22 19:55 run_001969.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  1.1G Feb 21 16:22 run_001555.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 21 16:22 run_001555.BSREAD.h5
# -rw-r--r--.  1 root p18387  1.7G Feb 21 16:21 run_001554.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 21
BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  1.3G Feb 21 01:42 run_001295.BSREAD.h5
# -rw-r--r--.  1 root p18387   20G Feb 21 01:40 run_001295.JF02T09V02.h5
# -rw-r--r--.  1 root p18387  627M Feb 20 04:22 run_001063.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:22 run_001063.BSREAD.h5
# -rw-r--r--.  1 root p18387  627M Feb 20 04:21 run_001062.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:21 run_001062.BSREAD.h5
# -rw-r--r--.  1 root p18387  626M Feb 20 04:21 run_001061.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:20 run_001061.BSREAD.h5
# -rw-r--r--.  1 root p18387  626M Feb 20 04:20 run_001060.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:20 run_001060.BSREAD.h5
# -rw-r--r--.  1 root p18387  629M Feb 20 04:19 run_001059.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:19 run_001059.BSREAD.h5
# -rw-r--r--.  1 root p18387  627M Feb 20 04:18 run_001058.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:18 run_001058.BSREAD.h5
# -rw-r--r--.  1 root p18387  627M Feb 20 04:17 run_001057.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:17 run_001057.BSREAD.h5
# -rw-r--r--.  1 root p18387  627M Feb 20 04:16 run_001056.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:16 run_001056.BSREAD.h5
# -rw-r--r--.  1 root p18387  628M Feb 20 04:15 run_001055.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:15 run_001055.BSREAD.h5
# -rw-r--r--.  1 root p18387  628M Feb 20 04:15 run_001054.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:15 run_001054.BSREAD.h5
# -rw-r--r--.  1 root p18387  628M Feb 20 04:14 run_001053.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:14 run_001053.BSREAD.h5
# -rw-r--r--.  1 root p18387  629M Feb 20 04:13 run_001052.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:13 run_001052.BSREAD.h5
# -rw-r--r--.  1 root p18387  628M Feb 20 04:12 run_001051.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:12 run_001051.BSREAD.h5
# -rw-r--r--.  1 root p18387  627M Feb 20 04:11 run_001050.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:11 run_001050.BSREAD.h5
# -rw-r--r--.  1 root p18387  628M Feb 20 04:10 run_001049.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:10 run_001049.BSREAD.h5
# -rw-r--r--.  1 root p18387  627M Feb 20 04:09 run_001048.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:09 run_001048.BSREAD.h5
# -rw-r--r--.  1 root p18387  627M Feb 20 04:09 run_001047.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:09 run_001047.BSREAD.h5
# -rw-r--r--.  1 root p18387  628M Feb 20 04:08 run_001046.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:08 run_001046.BSREAD.h5
# -rw-r--r--.  1 root p18387  628M Feb 20 04:07 run_001045.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:07 run_001045.BSREAD.h5
# -rw-r--r--.  1 root p18387  626M Feb 20 04:06 run_001044.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:06 run_001044.BSREAD.h5
# -rw-r--r--.  1 root p18387  626M Feb 20 04:05 run_001043.BSREAD.IMAGES.h5
# -rw-r--r--.  1 root p18387  531M Feb 20 04:05 run_001043.BSREAD.h5
# ra-c-003.psi.ch
# There are 945 files in the folder /sf/alvra/data/p18387/raw/scan_data/XAS-L-cystine-monoscan/

# %%
# First we load the first images of a file to check if everything is fine with the pedestal &  files (check high True or False)
# We can see also how the ROIs look like (will be useful later)
clock = Clock()

#fileName = "run_001381.JF02T09V02.h5"
fileName = "run002119.JF02T09V02.h5"
#fileName = "run_000786.JF02T09V02.h5"

#fileName = "CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0015.JF02T09V01.h5"

print(DIR + fileName)

nframes = 10
#nframes = images.shape[0]
total = 0
total_thr = 0

with ju.File(DIR + fileName, pedestal_file=pedestal_file) as juf:
    pulse_ids = juf["pulse_id"][:]

    for i in range(nframes):
        image = juf[i, :]
        image_thr = image.copy()
        image_thr[image < 1] = 0
        total_thr += image_thr
        total += image
        #total /= nframes
    
print (total_thr.shape)
print ("It took", clock.tick(), "seconds to process this file")

#roi = [[225, 325], [6950, 7075]]
#roi = [[225, 325], [7900, 8450]]
#roi = [[0, total_corr.shape[0]], [0, total_corr.shape[1]]]

plt.figure()
plt.subplots_adjust(wspace=0.5)
plt.subplot(121)
plt.imshow(total_thr, origin="lower", aspect='auto', vmin=0, vmax=1)
plt.title("with threshold")
plt.colorbar()
plt.subplot(122)
plt.imshow(total, origin="lower", aspect='auto', vmin=0, vmax=1)
plt.title("without threshold")
plt.colorbar()
plt.show()
# Out:
# /sf/alvra/data/p18387/raw/scan_data/XAS-L-cystine-monoscan/run002119.JF02T09V02.h5
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-39-b40074148c74> in <module>
#      16 total_thr = 0
#      17
# ---> 18 with ju.File(DIR + fileName, pedestal_file=pedestal_file) as juf:
#      19     pulse_ids = juf["pulse_id"][:]
#      20
#
# /das/work/p18/p18387/anaconda/alvra-analysis-p18387/lib/python3.6/site-packages/jungfrau_utils/file_adapter.py in __init__(self, file_path, gain_file, pedestal_file, conversion, gap_pixels, geometry, parallel)
#      48         self.file_path = Path(file_path)
#      49
# ---> 50         self.file = h5py.File(self.file_path, "r")
#      51         self.handler = JFDataHandler(self.file["/general/detector_name"][()].decode())
#      52
#
# /das/work/p18/p18387/anaconda/alvra-analysis-p18387/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# /das/work/p18/p18387/anaconda/alvra-analysis-p18387/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = '/sf/alvra/data/p18387/raw/scan_data/XAS-L-cystine-monoscan/run002119.JF02T09V02.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
plt.figure()
plt.imshow(total_thr, origin="lower", aspect='auto', vmin=0, vmax=0.1)
plt.title(fileName)
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
projection = total_thr[:,5000:5100].sum(axis = 0)

plt.figure()
plt.plot(projection)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # New script in the next cell (single file)

# %%
files = ["run_002159"]
#files = ["run_003179"]
#files = ["run_000042"]

#roi1 = (5000, 5200, 220, 290) # Ru ROIs
#roi2 = (5000, 5200, 290, 360)
roi1 = (6450, 6550, 220, 300)
roi2 = (5450, 5700, 220, 300)

threshold_low = 2.0
threshold_high = 10

Timezero = 194.6   # position of Timezero on PP delay (in mm!)
######################################################################################
start_time = time.time()
spectrum_ON_roi1 = 0
spectrum_OFF_roi1 = 0
spectrum_ON_roi2 = 0
spectrum_OFF_roi2 = 0
energy_eV = 0
Delay_mm_single = 0
        
for f in files:
    JF_single_file = DIR + f + ".JF02T09V02.h5"
    BS_single_file = DIR + f + ".BSREAD.h5"
    print("Processing file %s" % (JF_single_file))
    
#    photon_range = (6, 7)

    nshots = 10000  # put this to None for ALL images
    #nshots = None

    images_ON_roi1, images_ON_roi2, pids_ON, images_OFF_roi1, images_OFF_roi2, pids_OFF = \
    load_crop_JF_data_on_off(JF_single_file, roi1, roi2, 50, 25, pedestal_file=pedestal_file, nshots=nshots)
    
    delay, pids = load_single_channel_pulseID(BS_single_file, channel_delay, 50)
    delay = [x for x in delay if (x > 0)]
    Delay_mm_single = np.mean(delay)
    Delay_ps_single = (Delay_mm_single - Timezero)*2/(3e8*1e3*1e-12) # in ps, change to right t0 !
    
#    Izero_pump, Izero_unpump, energy_eV, pulseIDs = \
#    load_FEL_pp_pulseID(BS_single_file, channel_energy, 50, 25, 50)  
    
    images_ON_roi1_thr = images_ON_roi1.copy()
    images_ON_roi1_thr[images_ON_roi1 < threshold_low] = 0
    images_ON_roi1_thr[images_ON_roi1 > threshold_high] = 0
#   images_ON_roi1 = convert_to_photon_num_range(images_ON_roi1)

    images_ON_roi2_thr = images_ON_roi2.copy()
    images_ON_roi2[images_ON_roi2 < threshold_low] = 0
    images_ON_roi2[images_ON_roi2 > threshold_high] = 0
#   images_ON_roi2 = convert_to_photon_num_range(images_ON_roi2)

    images_OFF_roi1_thr = images_OFF_roi1.copy()
    images_OFF_roi1_thr[images_OFF_roi1 < threshold_low] = 0
    images_OFF_roi1_thr[images_OFF_roi1 > threshold_high] = 0
#   images_OFF_roi1 = convert_to_photon_num_range(images_OFF_roi1)

    images_OFF_roi2_thr = images_OFF_roi2.copy()
    images_OFF_roi2[images_OFF_roi2 < threshold_low] = 0
    images_OFF_roi2[images_OFF_roi2 > threshold_high] = 0
#   images_OFF_roi2 = convert_to_photon_num_range(images_OFF_roi2)

    spectrum_ON_roi1  = images_ON_roi1_thr.sum(axis = 1).sum(axis = 0)
    spectrum_OFF_roi1 = images_OFF_roi1_thr.sum(axis = 1).sum(axis = 0)
    spectrum_ON_roi2  = images_ON_roi2.sum(axis = 1).sum(axis = 0)
    spectrum_OFF_roi2 = images_OFF_roi2.sum(axis = 1).sum(axis = 0)
    
print ("Job done! It took", round((time.time() - start_time), 2), "seconds to process", len(files), "file" if len(files) == 1 else "files")
# Out:
# Processing file /sf/alvra/data/p18387/raw/scan_data/XAS-L-cystine-monoscan/run_002159.JF02T09V02.h5
# Auto-located gain file: /sf/alvra/config/jungfrau/gainMaps/JF02T09V02/gains.h5
# Auto-located pedestal file: /sf/alvra/data/p18387/res/JF_pedestals/pedestal_20200223_0716.JF02T09V02.res.h5
#     mtime difference: 4:59:23.267237
# Job done! It took 19.88 seconds to process 1 file

# %%
def edge_removal(module_edge, roi_removal, array):
    index_edge = module_edge - roi_removal[0]
    array_input = array.copy()
    print (array[index_edge-1:index_edge+3])
    array[index_edge] = array[index_edge-1]/2
    array[index_edge-1] = array[index_edge-1]/2

    array[index_edge+1] = array[index_edge+2]/2
    array[index_edge+2] = array[index_edge+2]/2 
    print (array[index_edge-1:index_edge+3])
    return array, array_input

# %%
spectrum_ON_roi1, spectrum_ON_roi1_orig = edge_removal(6472, roi1, spectrum_ON_roi1) 
spectrum_OFF_roi1, spectrum_OFF_roi1_orig = edge_removal(6472, roi1, spectrum_OFF_roi1)
# Out:
# [2.1248114 0.        0.        6.826867 ]
# [1.0624057 1.0624057 3.4134336 3.4134336]
# [2.1855292 0.        0.        7.2446613]
# [1.0927646 1.0927646 3.6223307 3.6223307]

# %% [markdown]
# ### ROI1

# %%
bin_ = 1   # change the bin size if wanted, 1 is every pixel

spectra_on = spectrum_ON_roi1.copy()
spectra_off = spectrum_OFF_roi1.copy()

x_axis = np.arange(roi1[0], roi1[1])

spectra_on_rebin1  = bin_sum(spectra_on,  bin_)
spectra_off_rebin1 = bin_sum(spectra_off, bin_)
x_axis_rebin1 = bin_mean(x_axis, bin_)

spectra_on_err1  = np.sqrt(spectra_on_rebin1)
spectra_off_err1 = np.sqrt(spectra_off_rebin1)

#spectrumAllOutFoc=spectra_on_rebin1 + spectra_off_rebin1
plt.figure()
plt.subplot(211)
plt.title(scan_name + ", delay = {} ps".format(str(np.round(Delay_ps_single,3))))
plt.plot(x_axis_rebin1, spectra_on_rebin1, label="ON", marker='.')
plt.plot(x_axis_rebin1, spectra_off_rebin1, label="OFF", marker='.')
plt.legend(loc="best")
plt.grid()

#plt.title(jf_file)

low_err= (spectra_on_rebin1 - spectra_off_rebin1)-np.sqrt(spectra_on_err1**2+spectra_off_err1**2)
high_err= (spectra_on_rebin1 - spectra_off_rebin1)+np.sqrt(spectra_on_err1**2+spectra_off_err1**2)
#x_axis_rebin1,
plt.subplot(212)
plt.plot(x_axis_rebin1,spectra_on_rebin1 - spectra_off_rebin1, label="ON - OFF",marker='.')
#plt.plot(spectra_on_rebin1 - spectra_off_rebin1, label="ON - OFF",marker='.')
plt.xlabel("JF pixel")
plt.grid()


plt.legend(loc="best")
plt.fill_between(x_axis_rebin1, low_err, high_err, color='lightblue')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### ROI2

# %%
bin_ = 2 # change the bin size if wanted, 1 is every pixel

spectra_on = spectrum_ON_roi2.copy()
spectra_off = spectrum_OFF_roi2.copy()

x_axis = np.arange(roi2[0], roi2[1])

spectra_on_rebin2  = bin_sum(spectra_on,  bin_)
spectra_off_rebin2 = bin_sum(spectra_off, bin_)
x_axis_rebin2 = bin_mean(x_axis, bin_)

spectra_on_err2  = np.sqrt(spectra_on_rebin2)
spectra_off_err2 = np.sqrt(spectra_off_rebin2)

#spectrumAllOutFoc=spectra_on_rebin1 + spectra_off_rebin1
plt.figure()
plt.subplot(211)
plt.title(scan_name + ", delay = {} ps".format(str(np.round(Delay_ps_single,3))))
plt.plot(x_axis_rebin2, spectra_on_rebin2, label="ON", marker='.')
plt.plot(x_axis_rebin2, spectra_off_rebin2, label="OFF", marker='.')
plt.legend(loc="best")
plt.grid()

#plt.title(jf_file)

low_err= (spectra_on_rebin2 - spectra_off_rebin2)-np.sqrt(spectra_on_err2**2+spectra_off_err2**2)
high_err= (spectra_on_rebin2 - spectra_off_rebin2)+np.sqrt(spectra_on_err2**2+spectra_off_err2**2)
#x_axis_rebin1,
plt.subplot(212)
plt.plot(x_axis_rebin2,spectra_on_rebin2 - spectra_off_rebin2, label="ON - OFF",marker='.')
plt.xlabel("JF pixel")
plt.grid()

#plt.plot(spectra_on_rebin1 - spectra_off_rebin1, label="ON - OFF",marker='.')

plt.legend(loc="best")
plt.fill_between(x_axis_rebin2, low_err, high_err, color='lightblue')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # New script in the next cell (scans)

# %%
print (DIR_json + scan_name + scan_range + ".json")
# Out:
# /sf/alvra/data/p18387/res/scan_info/XAS-L-cystine-monoscan.run002119-002167.json

# %%
scan_name = "XAS-L-cystine-monoscan"          # you need to change only this name

#roi1 = (5000, 5200, 220, 290)
#roi2 = (5000, 5200, 290, 360) #Ru ROIs
roi1 = (6450, 6550, 220, 300)
roi2 = (5450, 5700, 220, 300)
threshold_low = 2.0
threshold_high = 10

######################################################################################

fname_scan = DIR_json + scan_name + scan_range + ".json"
scan_data = load_scan_data(fname_scan)

Energy_eV = []
Delay_mm = []
XAS_roi1 = []
XAS_roi1_on = []
Error_XAS_roi1 = []
XAS_roi2 = []
XAS_roi2_on = []
Error_XAS_roi2 = []
RIXS_transient_roi1 = []
RIXS_transient_roi2 = []
Error_transient_roi1 = []
Error_transient_roi2 = []
RIXS_unpumped_roi1 = []
RIXS_unpumped_roi2 = []
Error_unpumped_roi1 = []
Error_unpumped_roi2 = []
RIXS_pumped_roi1 = []
RIXS_pumped_roi2 = []
Error_pumped_roi1 = []
Error_pumped_roi2 = []
XAS_transient_roi1=[]

XES_transient_roi1 =[]
XES_1D = []

XAS_transient_roi2=[]

XES_transient_roi2 =[]

clock = Clock()
num_scan_files = len(scan_data)
print("\nProcessing", num_scan_files, "total files")

for i, (bs, fn) in enumerate(scan_data):
#for i in range(0,4):
    clear_output(wait=True)
    fn2 = fn.split(".JF06T32V01.h5")[0] + ".JF02T09V02.h5"
    fn = fn.replace(".JF06T32V01.h5", ".JF02T09V02.h5")
    print("\nFile", i+1, "of", num_scan_files, ": Processing:", fn.split("/")[-1])
    
    spectrum_ON_roi1 = 0
    spectrum_OFF_roi1 = 0
    spectrum_ON_roi2 = 0
    spectrum_OFF_roi2 = 0
    
    nshots = 10000  # put this to None for ALL images
    #nshots = None
    
    images_ON_roi1, images_ON_roi2, pids_ON, images_OFF_roi1, images_OFF_roi2, pids_OFF = \
    load_crop_JF_data_on_off(fn, roi1, roi2, 50, 25, pedestal_file=pedestal_file, nshots=nshots)
    
    energy, pids = load_single_channel_pulseID(bs, channel_energy, 50)
    energy = [x for x in energy if (x > 0)]
    Energy_eV.append(np.mean(energy))
    
    delay, pids = load_single_channel_pulseID(bs, channel_delay, 50)
    delay = [x for x in delay if (x > 0)]
    Delay_mm.append(np.mean(delay))
    
    images_ON_roi1_thr = images_ON_roi1.copy()
    images_ON_roi1_thr[images_ON_roi1 < threshold_low] = 0
    images_ON_roi1_thr[images_ON_roi1 > threshold_high] = 0
    
    images_OFF_roi1_thr = images_OFF_roi1.copy()
    images_OFF_roi1_thr[images_OFF_roi1 < threshold_low] = 0
    images_OFF_roi1_thr[images_OFF_roi1 > threshold_high] = 0
    
    images_ON_roi2_thr = images_ON_roi2.copy()
    images_ON_roi2_thr[images_ON_roi2 < threshold_low] = 0
    images_ON_roi2_thr[images_ON_roi2 > threshold_high] = 0
    
    images_OFF_roi2_thr = images_OFF_roi2.copy()
    images_OFF_roi2_thr[images_OFF_roi2 < threshold_low] = 0
    images_OFF_roi2_thr[images_OFF_roi2 > threshold_high] = 0
    
    spectrum_ON_roi1 = images_ON_roi1_thr.sum(axis = 1).sum(axis = 0)
    spectrum_OFF_roi1 = images_OFF_roi1_thr.sum(axis = 1).sum(axis = 0)
    spectrum_ON_roi2 = images_ON_roi2_thr.sum(axis = 1).sum(axis = 0)
    spectrum_OFF_roi2 = images_OFF_roi2_thr.sum(axis = 1).sum(axis = 0)
    
    XAS_roi1.append(np.abs(spectrum_OFF_roi1.sum()))
    XAS_roi1_on.append(np.abs(spectrum_ON_roi1.sum()))
    RIXS_unpumped_roi1.append(spectrum_OFF_roi1)
    Error_unpumped_roi1.append(np.sqrt(spectrum_OFF_roi1))
    RIXS_pumped_roi1.append(spectrum_ON_roi1)
    Error_pumped_roi1.append(np.sqrt(spectrum_ON_roi1))
    RIXS_transient_roi1.append(spectrum_ON_roi1 - spectrum_OFF_roi1)
    Error_transient_roi1.append(np.sqrt((np.sqrt(spectrum_ON_roi1))**2 + (np.sqrt(spectrum_OFF_roi1))**2))
    
    XES_transient_roi1.append(np.abs(spectrum_ON_roi1 - spectrum_OFF_roi1))
 #   XES_1D.append(np.sum(XES_transient_roi1, axis = 1))
    
    XAS_transient_roi1.append(np.abs(np.sum(RIXS_transient_roi1)))
    
    
    XAS_roi2.append(np.abs(spectrum_OFF_roi2.sum()))
    XAS_roi2_on.append(np.abs(spectrum_ON_roi2.sum()))
    RIXS_unpumped_roi2.append(spectrum_OFF_roi2)
    Error_unpumped_roi2.append(np.sqrt(spectrum_OFF_roi2))
    RIXS_pumped_roi2.append(spectrum_ON_roi2)
    Error_pumped_roi2.append(np.sqrt(spectrum_ON_roi2))
    RIXS_transient_roi2.append(spectrum_ON_roi2 - spectrum_OFF_roi2)
    Error_transient_roi2.append(np.sqrt((np.sqrt(spectrum_ON_roi2))**2 + (np.sqrt(spectrum_OFF_roi2))**2))
    
    XES_transient_roi2.append(np.abs(spectrum_ON_roi2 - spectrum_OFF_roi2))
 #   XES_1D.append(np.sum(XES_transient_roi1, axis = 1))
    
    XAS_transient_roi2.append(np.abs(np.sum(RIXS_transient_roi2)))
    
    
    print ("It took", clock.tick(), "seconds to process this file")

Energy_eV = np.array(Energy_eV)
Delay_mm = np.array(Delay_mm)
XAS_roi1 = np.array(XAS_roi1)
XAS_roi1_on = np.array(XAS_roi1_on)
RIXS_unpumped_roi1 = np.array(RIXS_unpumped_roi1)
Error_unpumped_roi1 = np.array(Error_unpumped_roi1)
RIXS_pumped_roi1 = np.array(RIXS_pumped_roi1)
Error_pumped_roi1 = np.array(Error_pumped_roi1)
RIXS_transient_roi1 = np.array(RIXS_transient_roi1)
Error_transient_roi1 = np.array(Error_transient_roi1)
XAS_transient_roi1=np.array(RIXS_transient_roi1)
XES_transient_roi1=np.array(XES_transient_roi1)
XES_1D=np.array(XES_1D)

XAS_roi2 = np.array(XAS_roi2)
XAS_roi2_on = np.array(XAS_roi2_on)
RIXS_unpumped_roi2 = np.array(RIXS_unpumped_roi2)
Error_unpumped_roi2 = np.array(Error_unpumped_roi2)
RIXS_pumped_roi2 = np.array(RIXS_pumped_roi2)
Error_pumped_roi2 = np.array(Error_pumped_roi2)
RIXS_transient_roi2 = np.array(RIXS_transient_roi2)
Error_transient_roi2 = np.array(Error_transient_roi2)
XAS_transient_roi2=np.array(RIXS_transient_roi2)
XES_transient_roi2=np.array(XES_transient_roi2)


print ("\nJob done! It took", clock.tock(), "seconds to process", num_scan_files, "file(s)")
# Out:
# Processing 38 total files
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-5ffaace84160> in <module>
#      46 print("\nProcessing", num_scan_files, "total files")
#      47
# ---> 48 for i, (bs, fn) in enumerate(scan_data):
#      49 #for i in range(0,4):
#      50     clear_output(wait=True)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
Timezero = 194.6   # position of Timezero on PP delay (in mm!)
Delay_ps = (Delay_mm - Timezero)*2/(3e8*1e3*1e-12) # change to right t0 !

plt.figure(figsize=(8,4))
#plt.plot(Delay_ps, XES_transient_roi1.sum(axis = 1), marker ='.')
plt.plot(Delay_ps, XES_transient_roi2.sum(axis = 1), marker ='.')
plt.xlabel("Emission energy (pixel)")
plt.ylabel("Incident energy (eV)")

plt.title(scan_name)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
Timezero = 194.6   # position of Timezero on PP delay (in mm!)
Delay_ps = (Delay_mm - Timezero)*2/(3e8*1e3*1e-12) # change to right t0 !

plt.figure()
#plt.plot(Energy_eV,RIXS_transient_roi1, label="", marker='.')
plt.plot(Delay_ps,XES_1D, label="", marker='.')
plt.xlabel("Delay (ps)")
plt.ylabel("Counts")
plt.show
# Out:
# <div id='14b39288-549d-48fb-a8e9-6cd0a008756b'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-465ba75eb2c7> in <module>
#       4 plt.figure()
#       5 #plt.plot(Energy_eV,RIXS_transient_roi1, label="", marker='.')
# ----> 6 plt.plot(Delay_ps,XES_1D, label="", marker='.')
#       7 plt.xlabel("Delay (ps)")
#       8 plt.ylabel("Counts")
#
# /das/work/p18/p18387/anaconda/alvra-analysis-p18387/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# /das/work/p18/p18387/anaconda/alvra-analysis-p18387/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# /das/work/p18/p18387/anaconda/alvra-analysis-p18387/lib/python3.6/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# /das/work/p18/p18387/anaconda/alvra-analysis-p18387/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# /das/work/p18/p18387/anaconda/alvra-analysis-p18387/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (25,) and (0,)

# %%
spectrum_ON_roi1, spectrum_ON_roi1_orig = edge_removal(6472, roi1, spectrum_ON_roi1) 
spectrum_OFF_roi1, spectrum_OFF_roi1_orig = edge_removal(6472, roi1, spectrum_OFF_roi1)

# %%
RIXS_total = RIXS_unpumped_roi2 + RIXS_pumped_roi2

plt.figure(figsize=(8,4))
plt.imshow(RIXS_total, aspect = 'auto', cmap = "bwr", origin ="lower", extent=[roi1[0], roi1[1], Energy_eV[0], Energy_eV[-1]])
plt.xlabel("Emission energy (pixel)")
plt.ylabel("Incident energy (eV)")

plt.title(scan_name)
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure(figsize=(5,9))
plt.subplots_adjust(hspace=0.5)

plt.subplot(311)
plt.imshow(RIXS_unpumped_roi2, aspect = 'auto', cmap = "bwr", origin ="lower", extent=[roi2[0], roi2[1], Energy_eV[0], Energy_eV[-1]])
plt.title("RIXS unpumped")
plt.colorbar()
plt.show()

plt.subplot(312)
plt.imshow(RIXS_pumped_roi2, aspect = 'auto', cmap = "bwr", origin ="lower", extent=[roi2[0], roi2[1], Energy_eV[0], Energy_eV[-1]])#, vmin=-250, vmax=250)
plt.title("RIXS pumped")
plt.colorbar()
plt.show()

plt.subplot(313)
plt.imshow(RIXS_transient_roi2, aspect = 'auto', cmap = "rainbow", origin ="lower", extent=[roi2[0], roi2[1], Energy_eV[0], Energy_eV[-1]])#, vmin=-0.03, vmax=0.03)
plt.title("RIXS transient")
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
plt.figure(figsize=(5,9))
plt.subplots_adjust(hspace=0.5)

plt.subplot(311)
plt.imshow(RIXS_unpumped_roi1, aspect = 'auto', cmap = "bwr", origin ="lower", extent=[roi1[0], roi1[1], Energy_eV[0], Energy_eV[-1]])
plt.title("RIXS unpumped")
plt.colorbar()
plt.show()

plt.subplot(312)
plt.imshow(RIXS_pumped_roi1, aspect = 'auto', cmap = "bwr", origin ="lower", extent=[roi1[0], roi1[1], Energy_eV[0], Energy_eV[-1]])#, vmin=-250, vmax=250)
plt.title("RIXS pumped")
plt.colorbar()
plt.show()

plt.subplot(313)
plt.imshow(RIXS_transient_roi1, aspect = 'auto', cmap = "rainbow", origin ="lower", extent=[roi1[0], roi1[1], Energy_eV[0], Energy_eV[-1]])#, vmin=-0.03, vmax=0.03)
plt.title("RIXS transient")
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">
# /das/work/p18/p18387/anaconda/alvra-analysis-p18387/lib/python3.6/site-packages/ipykernel/__main__.py:5: UserWarning: Attempting to set identical bottom == top == 2609.619835999909 results in singular transformations; automatically expanding.
# /das/work/p18/p18387/anaconda/alvra-analysis-p18387/lib/python3.6/site-packages/ipykernel/__main__.py:11: UserWarning: Attempting to set identical bottom == top == 2609.619835999909 results in singular transformations; automatically expanding.
# /das/work/p18/p18387/anaconda/alvra-analysis-p18387/lib/python3.6/site-packages/ipykernel/__main__.py:17: UserWarning: Attempting to set identical bottom == top == 2609.619835999909 results in singular transformations; automatically expanding.

# %%
plt.figure()
plt.plot(Energy_eV,XAS_roi1, label="laser off", marker='.')
plt.plot(Energy_eV,XAS_roi1_on, label="laser on", marker='.')
plt.xlabel("Incident energy (eV)")
plt.ylabel("Counts")
plt.show

# %%
np.sum(np.abs(RIXS_transient_roi1))

# %%
plt.figure()
#plt.plot(Energy_eV,RIXS_transient_roi1, label="", marker='.')
plt.plot(Energy_eV,XAS_roi1_on-XAS_roi1, label="", marker='.')
plt.xlabel("Incident energy (eV)")
plt.ylabel("Counts")
plt.show

plt.figure()
plt.plot(x_axis,RIXS_transient_roi1.sum(axis=0), label="", marker='.')
plt.xlabel("Pixels")
plt.ylabel("Counts")
plt.show

plt.figure()
plt.plot(Delay_ps,np.abs(RIXS_transient_roi1).sum(axis=1), label="", marker='.')
plt.xlabel("Delay ps")
plt.ylabel("Counts")
plt.show

# %%
Timezero = 194.6   # position of Timezero on PP delay (in mm!)
Delay_ps = (Delay_mm - Timezero)*2/(3e8*1e3*1e-12) # change to right t0 !

plt.figure()
#plt.plot(Energy_eV,RIXS_transient_roi1, label="", marker='.')
plt.plot(Delay_ps,XAS_roi1_on-XAS_roi1, label="", marker='.')
plt.xlabel("Delay (ps)")
plt.ylabel("Counts")
plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(5,9))
plt.subplots_adjust(hspace=0.5)


plt.subplot(311)
plt.imshow(np.log(RIXS_unpumped_roi1), aspect = 'auto', cmap = "bwr", origin ="lower", extent=[roi1[0], roi1[1], Energy_eV[0], Energy_eV[-1]])
plt.title("Log RIXS unpumped")
#plt.pcolor(extent, RIXS_unpumped_roi1, cmap=cm, vmin=-4, vmax=4)
plt.colorbar()
plt.show()


plt.subplot(312)
plt.imshow(np.log(RIXS_pumped_roi1), aspect = 'auto', cmap = "bwr", origin ="lower", extent=[roi1[0], roi1[1], Energy_eV[0], Energy_eV[-1]])#, vmin=-250, vmax=250)
plt.title("Log RIXS pumped")
plt.colorbar()
plt.show()

plt.subplot(313)
plt.imshow(RIXS_transient_roi1, aspect = 'auto', cmap = "rainbow", origin ="lower", extent=[roi1[0], roi1[1], Energy_eV[0], Energy_eV[-1]])#, vmin=-0.03, vmax=0.03)
plt.title("RIXS transient")
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(5,9))
plt.subplots_adjust(hspace=0.5)

plt.subplot(311)
plt.imshow(RIXS_unpumped_roi1, aspect = 'auto', cmap = "bwr", origin ="lower", extent=[roi1[0], roi1[1], Delay_mm[0], Energy_eV[-1]])
plt.title("RIXS unpumped")
plt.colorbar()
plt.show()

plt.subplot(312)
plt.imshow(RIXS_pumped_roi1, aspect = 'auto', cmap = "bwr", origin ="lower", extent=[roi1[0], roi1[1], Delay_mm[0], Energy_eV[-1]])#, vmin=-250, vmax=250)
plt.title("RIXS pumped")
plt.colorbar()
plt.show()

plt.subplot(313)
plt.imshow(RIXS_transient_roi1, aspect = 'auto', cmap = "rainbow", origin ="lower", extent=[roi1[0], roi1[1], Delay_mm[0], Energy_eV[-1]])#, vmin=-0.03, vmax=0.03)
plt.title("RIXS transient")
plt.colorbar()
plt.show()

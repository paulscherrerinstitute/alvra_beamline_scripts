# %%
# %matplotlib nbagg
import numpy as np
import json
import h5py
import matplotlib.pyplot as plt
import scipy
from scipy.special import erf
from scipy.optimize import curve_fit
import os

# %%
channel_PIPS_trans = "data/SARES11-GES1:CH1_VAL_GET/data"           #X-ray diode to PRIME Keysight
channel_PIPS_fluo = "data/SARES11-GES1:CH2_VAL_GET/data"           #X-ray diode to PRIME Keysight
channel_Izero = "data/SARES11-LSCP10-FNS:CH2:VAL_GET/data"          #Izero diode to PRIME Ioxos (channel 3)
channel_Izero2 = "data/SARES11-LSCP10-FNS:CH3:VAL_GET/data"          #Izero diode to PRIME Ioxos (channel 0)
channel_Izero3 = "data/SARES11-LSCP10-FNS:CH1:VAL_GET/data"          #Izero diode to PRIME Ioxos (channel 1)
channel_Izero4 = "data/SARES11-LSCP10-FNS:CH2:VAL_GET/data"         #Izero diode to PRIME Ioxos (channel 2)
channel_LaserDiode = "data/SLAAR11-LSCP1-FNS:CH0:VAL_GET/data"      #Laser diode to ESA Laser Ioxos 
channel_Laser_refDiode = "data/SLAAR11-LSCP1-FNS:CH2:VAL_GET/data"  #Laser diode leaking from beampath, to ESA Laser Ioxos 
#channel_LaserDiode = "SARES11-GES1:CH2_VAL_GET/data"          #Laser diode to PRIME Keysight
channel_pulse_ids = "data/SLAAR11-LMOT-M451:ENC_1_BS/pulse_id"      #Pulse ids taken from pump-probe delay stage (100 Hz)
channel_delay = "data/SLAAR11-LMOT-M451:ENC_1_BS/data"              #Delay of pump-probe delay stage
channel_LAM_delaystage = "data/SLAAR11-LTIM01-EVR0:DUMMY_PV2_NBS/data"       #LAM internal stage position in mm
channel_LAM_stepper = "data/SLAAR11-LTIM01-EVR0:DUMMY_PV10_NBS/data"         #LAM stepper motor (used for feedback)
channel_PALM_eTOF = "data/SAROP11-PALMK118:CH2_BUFFER/data"                 #PALM eTof from Ch2

#Position of the stage: Dummy PV1 for x axis, dummy PV3 for y axis
channel_position = "data/SLAAR11-LTIM01-EVR0:DUMMY_PV1_NBS/data"     #Huber stage X position. 
channel_position = "data/SLAAR11-LMOT-M451:ENC_1_BS/data"
channel_energy = "data/SLAAR11-LTIM01-EVR0:DUMMY_PV3_NBS/data"       #Energy from the monochromator

# %%
scan_name ="CytC_Fe3_monoscan_complete_002"
#scan_name ="CytC_Fe2_7122eV_delayscan_002"

# file names of the type below. copy paste for ease:
# FEL_knife_edge_Y_coarse_
# FEL_knife_edge_X_coarse_
# FEL_knife_edge_Y_fine_
# FEL_knife_edge_X_fine_

DIR = "/sf/alvra/data/p17803/raw/scan_data/" + scan_name + "/"
DIR_json = "/sf/alvra/data/p17803/res/scan_info/"

# %%
def LoadData_knife_edge(filename):
    with h5py.File(filename, 'r') as BS_file:
        pulse_ids = BS_file[channel_pulse_ids][:]
        reprate_FEL = ((pulse_ids%4 == 0) & (pulse_ids%8 != 0))                #This is for 25 Hz
        reprate_laser = pulse_ids%8 == 0                                       #This is for 12.5 Hz
        
        Data_pumped = BS_file[channel_PIPS_fluo][:][reprate_laser]
        Data_unpumped = BS_file[channel_PIPS_fluo][:][reprate_FEL]
        
        DataT_pumped = BS_file[channel_PIPS_trans][:][reprate_laser]
        DataT_unpumped = BS_file[channel_PIPS_trans][:][reprate_FEL]
        
        Izero_pump = BS_file[channel_Izero][:][reprate_laser]
        Izero_unpump = BS_file[channel_Izero][:][reprate_FEL]
        
        Energy = BS_file[channel_energy][:][reprate_FEL]
        Position = BS_file[channel_position][:][reprate_FEL]
        
    return Data_pumped, Data_unpumped, Izero_pump, Izero_unpump, Energy, Position, DataT_pumped, DataT_unpumped

def errfunc(x, a, b, c, d):
    return a + b*erf((c-x)*np.sqrt(np.log(2))/(np.abs(d)))

# %%
# !ls -lah -rt $DIR
# !hostname

listfile = os.listdir(DIR)
number_files = len(listfile)
print ("There are",number_files,"files in the folder", DIR)
# Out:
# total 1.6T
# drwxrwsr-x. 48 root p17803 4.0K Jan 23 10:13 ..
# -rw-r--r--.  1 root p17803  18G Jan 23 10:14 CytC_Fe3_monoscan_complete_002_step0000.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 10:15 CytC_Fe3_monoscan_complete_002_step0000.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:16 CytC_Fe3_monoscan_complete_002_step0001.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:16 CytC_Fe3_monoscan_complete_002_step0000.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 10:16 CytC_Fe3_monoscan_complete_002_step0001.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:17 CytC_Fe3_monoscan_complete_002_step0002.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 10:17 CytC_Fe3_monoscan_complete_002_step0002.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:18 CytC_Fe3_monoscan_complete_002_step0001.BSREAD.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:19 CytC_Fe3_monoscan_complete_002_step0003.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:19 CytC_Fe3_monoscan_complete_002_step0002.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 10:19 CytC_Fe3_monoscan_complete_002_step0003.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:20 CytC_Fe3_monoscan_complete_002_step0004.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:20 CytC_Fe3_monoscan_complete_002_step0003.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 10:20 CytC_Fe3_monoscan_complete_002_step0004.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:22 CytC_Fe3_monoscan_complete_002_step0005.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 5.8M Jan 23 10:22 CytC_Fe3_monoscan_complete_002_step0005.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:22 CytC_Fe3_monoscan_complete_002_step0004.BSREAD.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:23 CytC_Fe3_monoscan_complete_002_step0006.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:23 CytC_Fe3_monoscan_complete_002_step0005.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 10:23 CytC_Fe3_monoscan_complete_002_step0006.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:25 CytC_Fe3_monoscan_complete_002_step0007.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:25 CytC_Fe3_monoscan_complete_002_step0006.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 10:25 CytC_Fe3_monoscan_complete_002_step0007.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:26 CytC_Fe3_monoscan_complete_002_step0008.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:26 CytC_Fe3_monoscan_complete_002_step0007.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.9M Jan 23 10:26 CytC_Fe3_monoscan_complete_002_step0008.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:27 CytC_Fe3_monoscan_complete_002_step0009.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:28 CytC_Fe3_monoscan_complete_002_step0008.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 10:28 CytC_Fe3_monoscan_complete_002_step0009.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:29 CytC_Fe3_monoscan_complete_002_step0010.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:29 CytC_Fe3_monoscan_complete_002_step0009.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 10:29 CytC_Fe3_monoscan_complete_002_step0010.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:30 CytC_Fe3_monoscan_complete_002_step0010.BSREAD.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:33 CytC_Fe3_monoscan_complete_002_step0011.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 10:33 CytC_Fe3_monoscan_complete_002_step0011.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:35 CytC_Fe3_monoscan_complete_002_step0012.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:35 CytC_Fe3_monoscan_complete_002_step0011.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 10:35 CytC_Fe3_monoscan_complete_002_step0012.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:36 CytC_Fe3_monoscan_complete_002_step0013.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:36 CytC_Fe3_monoscan_complete_002_step0012.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 10:37 CytC_Fe3_monoscan_complete_002_step0013.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:38 CytC_Fe3_monoscan_complete_002_step0014.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:38 CytC_Fe3_monoscan_complete_002_step0013.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 10:38 CytC_Fe3_monoscan_complete_002_step0014.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:39 CytC_Fe3_monoscan_complete_002_step0015.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:39 CytC_Fe3_monoscan_complete_002_step0014.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 10:39 CytC_Fe3_monoscan_complete_002_step0015.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:41 CytC_Fe3_monoscan_complete_002_step0016.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:41 CytC_Fe3_monoscan_complete_002_step0015.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 10:41 CytC_Fe3_monoscan_complete_002_step0016.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:42 CytC_Fe3_monoscan_complete_002_step0017.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:42 CytC_Fe3_monoscan_complete_002_step0016.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 10:42 CytC_Fe3_monoscan_complete_002_step0017.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:43 CytC_Fe3_monoscan_complete_002_step0018.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:44 CytC_Fe3_monoscan_complete_002_step0017.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 10:44 CytC_Fe3_monoscan_complete_002_step0018.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:45 CytC_Fe3_monoscan_complete_002_step0019.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:45 CytC_Fe3_monoscan_complete_002_step0018.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.8M Jan 23 10:45 CytC_Fe3_monoscan_complete_002_step0019.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:46 CytC_Fe3_monoscan_complete_002_step0020.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:46 CytC_Fe3_monoscan_complete_002_step0019.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.9M Jan 23 10:47 CytC_Fe3_monoscan_complete_002_step0020.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:48 CytC_Fe3_monoscan_complete_002_step0021.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:48 CytC_Fe3_monoscan_complete_002_step0020.BSREAD.h5
# -rw-r--r--.  1 root p17803 7.0M Jan 23 10:48 CytC_Fe3_monoscan_complete_002_step0021.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:49 CytC_Fe3_monoscan_complete_002_step0022.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:49 CytC_Fe3_monoscan_complete_002_step0021.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.7M Jan 23 10:49 CytC_Fe3_monoscan_complete_002_step0022.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:51 CytC_Fe3_monoscan_complete_002_step0023.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:51 CytC_Fe3_monoscan_complete_002_step0022.BSREAD.h5
# -rw-r--r--.  1 root p17803 7.0M Jan 23 10:51 CytC_Fe3_monoscan_complete_002_step0023.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:52 CytC_Fe3_monoscan_complete_002_step0024.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:52 CytC_Fe3_monoscan_complete_002_step0023.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.9M Jan 23 10:52 CytC_Fe3_monoscan_complete_002_step0024.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:54 CytC_Fe3_monoscan_complete_002_step0025.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:54 CytC_Fe3_monoscan_complete_002_step0024.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.7M Jan 23 10:54 CytC_Fe3_monoscan_complete_002_step0025.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:55 CytC_Fe3_monoscan_complete_002_step0026.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:55 CytC_Fe3_monoscan_complete_002_step0025.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.8M Jan 23 10:55 CytC_Fe3_monoscan_complete_002_step0026.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:57 CytC_Fe3_monoscan_complete_002_step0027.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:57 CytC_Fe3_monoscan_complete_002_step0026.BSREAD.h5
# -rw-r--r--.  1 root p17803 7.0M Jan 23 10:57 CytC_Fe3_monoscan_complete_002_step0027.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:58 CytC_Fe3_monoscan_complete_002_step0028.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 10:58 CytC_Fe3_monoscan_complete_002_step0028.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 10:58 CytC_Fe3_monoscan_complete_002_step0027.BSREAD.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 10:59 CytC_Fe3_monoscan_complete_002_step0029.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:00 CytC_Fe3_monoscan_complete_002_step0028.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.8M Jan 23 11:00 CytC_Fe3_monoscan_complete_002_step0029.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:01 CytC_Fe3_monoscan_complete_002_step0030.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:01 CytC_Fe3_monoscan_complete_002_step0029.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.9M Jan 23 11:01 CytC_Fe3_monoscan_complete_002_step0030.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:02 CytC_Fe3_monoscan_complete_002_step0031.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 11:02 CytC_Fe3_monoscan_complete_002_step0031.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:03 CytC_Fe3_monoscan_complete_002_step0030.BSREAD.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:04 CytC_Fe3_monoscan_complete_002_step0031.BSREAD.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:37 CytC_Fe3_monoscan_complete_002_step0032.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 11:38 CytC_Fe3_monoscan_complete_002_step0032.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:39 CytC_Fe3_monoscan_complete_002_step0033.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:39 CytC_Fe3_monoscan_complete_002_step0032.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 11:39 CytC_Fe3_monoscan_complete_002_step0033.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:40 CytC_Fe3_monoscan_complete_002_step0034.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:40 CytC_Fe3_monoscan_complete_002_step0033.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 11:40 CytC_Fe3_monoscan_complete_002_step0034.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:41 CytC_Fe3_monoscan_complete_002_step0035.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:42 CytC_Fe3_monoscan_complete_002_step0034.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 11:42 CytC_Fe3_monoscan_complete_002_step0035.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:43 CytC_Fe3_monoscan_complete_002_step0036.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:43 CytC_Fe3_monoscan_complete_002_step0035.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.9M Jan 23 11:43 CytC_Fe3_monoscan_complete_002_step0036.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:44 CytC_Fe3_monoscan_complete_002_step0037.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:45 CytC_Fe3_monoscan_complete_002_step0036.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 11:45 CytC_Fe3_monoscan_complete_002_step0037.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:46 CytC_Fe3_monoscan_complete_002_step0038.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:46 CytC_Fe3_monoscan_complete_002_step0037.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 11:46 CytC_Fe3_monoscan_complete_002_step0038.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:47 CytC_Fe3_monoscan_complete_002_step0039.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:47 CytC_Fe3_monoscan_complete_002_step0038.BSREAD.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:49 CytC_Fe3_monoscan_complete_002_step0040.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:49 CytC_Fe3_monoscan_complete_002_step0039.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 11:49 CytC_Fe3_monoscan_complete_002_step0040.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:50 CytC_Fe3_monoscan_complete_002_step0041.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:50 CytC_Fe3_monoscan_complete_002_step0040.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 11:50 CytC_Fe3_monoscan_complete_002_step0041.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:52 CytC_Fe3_monoscan_complete_002_step0042.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:52 CytC_Fe3_monoscan_complete_002_step0041.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 11:52 CytC_Fe3_monoscan_complete_002_step0042.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:53 CytC_Fe3_monoscan_complete_002_step0043.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:53 CytC_Fe3_monoscan_complete_002_step0042.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 11:53 CytC_Fe3_monoscan_complete_002_step0043.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:55 CytC_Fe3_monoscan_complete_002_step0044.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:55 CytC_Fe3_monoscan_complete_002_step0043.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 11:55 CytC_Fe3_monoscan_complete_002_step0044.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:56 CytC_Fe3_monoscan_complete_002_step0045.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:56 CytC_Fe3_monoscan_complete_002_step0044.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 11:56 CytC_Fe3_monoscan_complete_002_step0045.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:57 CytC_Fe3_monoscan_complete_002_step0046.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:58 CytC_Fe3_monoscan_complete_002_step0045.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 11:58 CytC_Fe3_monoscan_complete_002_step0046.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 11:59 CytC_Fe3_monoscan_complete_002_step0047.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 11:59 CytC_Fe3_monoscan_complete_002_step0046.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 11:59 CytC_Fe3_monoscan_complete_002_step0047.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:00 CytC_Fe3_monoscan_complete_002_step0048.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:00 CytC_Fe3_monoscan_complete_002_step0047.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 12:01 CytC_Fe3_monoscan_complete_002_step0048.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:02 CytC_Fe3_monoscan_complete_002_step0049.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:02 CytC_Fe3_monoscan_complete_002_step0048.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 12:02 CytC_Fe3_monoscan_complete_002_step0049.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:03 CytC_Fe3_monoscan_complete_002_step0050.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:03 CytC_Fe3_monoscan_complete_002_step0049.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 12:03 CytC_Fe3_monoscan_complete_002_step0050.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:05 CytC_Fe3_monoscan_complete_002_step0051.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:05 CytC_Fe3_monoscan_complete_002_step0050.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 12:05 CytC_Fe3_monoscan_complete_002_step0051.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:06 CytC_Fe3_monoscan_complete_002_step0052.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:06 CytC_Fe3_monoscan_complete_002_step0051.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 12:06 CytC_Fe3_monoscan_complete_002_step0052.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:08 CytC_Fe3_monoscan_complete_002_step0053.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:08 CytC_Fe3_monoscan_complete_002_step0052.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 12:08 CytC_Fe3_monoscan_complete_002_step0053.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:09 CytC_Fe3_monoscan_complete_002_step0054.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:09 CytC_Fe3_monoscan_complete_002_step0053.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 12:09 CytC_Fe3_monoscan_complete_002_step0054.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:11 CytC_Fe3_monoscan_complete_002_step0055.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:11 CytC_Fe3_monoscan_complete_002_step0054.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 12:11 CytC_Fe3_monoscan_complete_002_step0055.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:12 CytC_Fe3_monoscan_complete_002_step0056.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:12 CytC_Fe3_monoscan_complete_002_step0055.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.9M Jan 23 12:12 CytC_Fe3_monoscan_complete_002_step0056.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:13 CytC_Fe3_monoscan_complete_002_step0057.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:14 CytC_Fe3_monoscan_complete_002_step0056.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 12:14 CytC_Fe3_monoscan_complete_002_step0057.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:15 CytC_Fe3_monoscan_complete_002_step0058.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:15 CytC_Fe3_monoscan_complete_002_step0057.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 12:15 CytC_Fe3_monoscan_complete_002_step0058.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:16 CytC_Fe3_monoscan_complete_002_step0059.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:17 CytC_Fe3_monoscan_complete_002_step0058.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 12:17 CytC_Fe3_monoscan_complete_002_step0059.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:18 CytC_Fe3_monoscan_complete_002_step0060.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:18 CytC_Fe3_monoscan_complete_002_step0059.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 12:18 CytC_Fe3_monoscan_complete_002_step0060.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:19 CytC_Fe3_monoscan_complete_002_step0061.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:19 CytC_Fe3_monoscan_complete_002_step0060.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 12:19 CytC_Fe3_monoscan_complete_002_step0061.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:21 CytC_Fe3_monoscan_complete_002_step0062.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:21 CytC_Fe3_monoscan_complete_002_step0061.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 12:21 CytC_Fe3_monoscan_complete_002_step0062.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:22 CytC_Fe3_monoscan_complete_002_step0063.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:22 CytC_Fe3_monoscan_complete_002_step0062.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 12:22 CytC_Fe3_monoscan_complete_002_step0063.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:24 CytC_Fe3_monoscan_complete_002_step0064.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:24 CytC_Fe3_monoscan_complete_002_step0063.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 12:24 CytC_Fe3_monoscan_complete_002_step0064.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:25 CytC_Fe3_monoscan_complete_002_step0065.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:25 CytC_Fe3_monoscan_complete_002_step0064.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 12:25 CytC_Fe3_monoscan_complete_002_step0065.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:27 CytC_Fe3_monoscan_complete_002_step0066.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:27 CytC_Fe3_monoscan_complete_002_step0065.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 12:27 CytC_Fe3_monoscan_complete_002_step0066.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:28 CytC_Fe3_monoscan_complete_002_step0067.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:28 CytC_Fe3_monoscan_complete_002_step0066.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 12:28 CytC_Fe3_monoscan_complete_002_step0067.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:29 CytC_Fe3_monoscan_complete_002_step0068.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:30 CytC_Fe3_monoscan_complete_002_step0067.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 12:30 CytC_Fe3_monoscan_complete_002_step0068.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:31 CytC_Fe3_monoscan_complete_002_step0069.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:31 CytC_Fe3_monoscan_complete_002_step0068.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 12:31 CytC_Fe3_monoscan_complete_002_step0069.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:32 CytC_Fe3_monoscan_complete_002_step0070.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:32 CytC_Fe3_monoscan_complete_002_step0069.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 12:33 CytC_Fe3_monoscan_complete_002_step0070.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:34 CytC_Fe3_monoscan_complete_002_step0071.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:34 CytC_Fe3_monoscan_complete_002_step0070.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 12:34 CytC_Fe3_monoscan_complete_002_step0071.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:35 CytC_Fe3_monoscan_complete_002_step0072.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:35 CytC_Fe3_monoscan_complete_002_step0071.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 12:35 CytC_Fe3_monoscan_complete_002_step0072.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:37 CytC_Fe3_monoscan_complete_002_step0073.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:37 CytC_Fe3_monoscan_complete_002_step0072.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 12:37 CytC_Fe3_monoscan_complete_002_step0073.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:38 CytC_Fe3_monoscan_complete_002_step0074.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:38 CytC_Fe3_monoscan_complete_002_step0073.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 12:38 CytC_Fe3_monoscan_complete_002_step0074.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:40 CytC_Fe3_monoscan_complete_002_step0075.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:40 CytC_Fe3_monoscan_complete_002_step0074.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 12:40 CytC_Fe3_monoscan_complete_002_step0075.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:41 CytC_Fe3_monoscan_complete_002_step0076.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:41 CytC_Fe3_monoscan_complete_002_step0075.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.5M Jan 23 12:42 CytC_Fe3_monoscan_complete_002_step0076.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:42 CytC_Fe3_monoscan_complete_002_step0077.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:43 CytC_Fe3_monoscan_complete_002_step0076.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 12:43 CytC_Fe3_monoscan_complete_002_step0077.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:44 CytC_Fe3_monoscan_complete_002_step0078.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:44 CytC_Fe3_monoscan_complete_002_step0077.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.9M Jan 23 12:44 CytC_Fe3_monoscan_complete_002_step0078.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:45 CytC_Fe3_monoscan_complete_002_step0079.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:45 CytC_Fe3_monoscan_complete_002_step0078.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 12:46 CytC_Fe3_monoscan_complete_002_step0079.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:47 CytC_Fe3_monoscan_complete_002_step0080.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:47 CytC_Fe3_monoscan_complete_002_step0079.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.5M Jan 23 12:47 CytC_Fe3_monoscan_complete_002_step0080.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:48 CytC_Fe3_monoscan_complete_002_step0081.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:48 CytC_Fe3_monoscan_complete_002_step0080.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 12:48 CytC_Fe3_monoscan_complete_002_step0081.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:50 CytC_Fe3_monoscan_complete_002_step0082.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:50 CytC_Fe3_monoscan_complete_002_step0081.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.5M Jan 23 12:50 CytC_Fe3_monoscan_complete_002_step0082.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:51 CytC_Fe3_monoscan_complete_002_step0083.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:51 CytC_Fe3_monoscan_complete_002_step0082.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 12:51 CytC_Fe3_monoscan_complete_002_step0083.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:53 CytC_Fe3_monoscan_complete_002_step0084.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:53 CytC_Fe3_monoscan_complete_002_step0083.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 12:53 CytC_Fe3_monoscan_complete_002_step0084.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:54 CytC_Fe3_monoscan_complete_002_step0084.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 12:54 CytC_Fe3_monoscan_complete_002_step0085.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:55 CytC_Fe3_monoscan_complete_002_step0085.JF02T09V01.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 12:56 CytC_Fe3_monoscan_complete_002_step0086.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:56 CytC_Fe3_monoscan_complete_002_step0085.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.5M Jan 23 12:56 CytC_Fe3_monoscan_complete_002_step0086.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 12:57 CytC_Fe3_monoscan_complete_002_step0086.BSREAD.h5
# drwxrwsr-x.  2 root p17803  32K Jan 23 12:57 .
# ra-c-004.psi.ch
# There are 260 files in the folder /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/

# %%
json_file = DIR_json + scan_name + "_scan_info.json"
print (json_file)

with open(json_file) as file:
    data = json.load(file)
numFiles = len(data['scan_files'])
#numFiles = 1

print ("Processing",numFiles,"files")

Signal_pump = []
Signal_unpump = []
err_signal = []

SignalT_pump = []
SignalT_unpump = []
err_signalT = []

Izero_pump = []
Izero_unpump = []
err_Izero = []
Izero_loop = []

Position_mm = []
Energy_eV = []

for i in range(0,numFiles):
    filename = str(data['scan_files'][i][0])    
    exists = os.path.isfile(filename)
    if exists:
        print("step",i+1,"of",numFiles,": Processing %s" % (str(data['scan_files'][i][0])))
        (signal_pump_loop,signal_unpump_loop,Izero_pump_loop, Izero_unpump_loop,energy_loop,position_loop,\
         signalT_pump_loop,signalT_unpump_loop) = LoadData_knife_edge(str(data['scan_files'][i][0]))
        Signal_pump.append(np.mean(signal_pump_loop))
        Signal_unpump.append(signal_unpump_loop.mean())
        err_signal.append(signal_pump_loop.std()/np.sqrt(signal_pump_loop.size))
        
        SignalT_pump.append(np.mean(signalT_pump_loop))
        SignalT_unpump.append(signalT_unpump_loop.mean())
        err_signalT.append(signalT_pump_loop.std()/np.sqrt(signalT_pump_loop.size))
        
        Izero_pump.append(Izero_pump_loop.mean())
        Izero_unpump.append(Izero_unpump_loop.mean())
       # err_Izero.append(Izero_loop.std()/np.sqrt(Izero_loop.size))
    
        energy_loop = [x for x in energy_loop if (np.abs(x) > 0)]
        Energy_eV.append(np.mean(energy_loop))
        Position_mm.append(np.mean(position_loop))
        
        print (signal_pump_loop.size,signal_unpump_loop.size)
    
Signal_pump = np.asarray(Signal_pump)
Signal_unpump = np.asarray(Signal_unpump)
err_signal = np.asarray(err_signal)

SignalT_pump = np.asarray(SignalT_pump)
SignalT_unpump = np.asarray(SignalT_unpump)
err_signalT = np.asarray(err_signalT)

Izero_pump = np.asarray(Izero_pump)
Izero_unpump = np.asarray(Izero_unpump)
err_Izero = np.asarray(err_Izero)

Energy_eV = np.asarray(Energy_eV)
Position_mm = np.asarray(Position_mm)
print ("Job done!")
# Out:
# /sf/alvra/data/p17803/res/scan_info/CytC_Fe3_monoscan_complete_002_scan_info.json
# Processing 87 files
# step 1 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0000.BSREAD.h5
# 1000 1000
# step 2 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0001.BSREAD.h5
# 1000 1000
# step 3 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0002.BSREAD.h5
# 1000 1000
# step 4 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0003.BSREAD.h5
# 1000 1000
# step 5 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0004.BSREAD.h5
# 1000 1000
# step 6 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0005.BSREAD.h5
# 1000 1000
# step 7 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0006.BSREAD.h5
# 1000 1000
# step 8 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0007.BSREAD.h5
# 1000 1000
# step 9 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0008.BSREAD.h5
# 1000 1000
# step 10 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0009.BSREAD.h5
# 1000 1000
# step 11 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0010.BSREAD.h5
# 1000 1000
# step 12 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0011.BSREAD.h5
# 1000 1000
# step 13 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0012.BSREAD.h5
# 1000 1000
# step 14 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0013.BSREAD.h5
# 1000 1000
# step 15 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0014.BSREAD.h5
# 1000 1000
# step 16 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0015.BSREAD.h5
# 1000 1000
# step 17 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0016.BSREAD.h5
# 1000 1000
# step 18 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0017.BSREAD.h5
# 1000 1000
# step 19 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0018.BSREAD.h5
# 1000 1000
# step 20 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0019.BSREAD.h5
# 1000 1000
# step 21 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0020.BSREAD.h5
# 1000 1000
# step 22 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0021.BSREAD.h5
# 1000 1000
# step 23 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0022.BSREAD.h5
# 1000 1000
# step 24 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0023.BSREAD.h5
# 1000 1000
# step 25 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0024.BSREAD.h5
# 1000 1000
# step 26 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0025.BSREAD.h5
# 1000 1000
# step 27 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0026.BSREAD.h5
# 1000 1000
# step 28 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0027.BSREAD.h5
# 1000 1000
# step 29 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0028.BSREAD.h5
# 1000 1000
# step 30 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0029.BSREAD.h5
# 1000 1000
# step 31 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0030.BSREAD.h5
# 1000 1000
# step 32 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0031.BSREAD.h5
# 1000 1000
# step 33 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0032.BSREAD.h5
# 1000 1000
# step 34 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0033.BSREAD.h5
# 1000 1000
# step 35 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0034.BSREAD.h5
# 1000 1000
# step 36 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0035.BSREAD.h5
# 1000 1000
# step 37 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0036.BSREAD.h5
# 1000 1000
# step 38 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0037.BSREAD.h5
# 1000 1000
# step 39 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0038.BSREAD.h5
# 1000 1000
# step 40 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0039.BSREAD.h5
# 1000 1000
# step 41 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0040.BSREAD.h5
# 1000 1000
# step 42 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0041.BSREAD.h5
# 1000 1000
# step 43 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0042.BSREAD.h5
# 1000 1000
# step 44 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0043.BSREAD.h5
# 1000 1000
# step 45 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0044.BSREAD.h5
# 1000 1000
# step 46 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0045.BSREAD.h5
# 1000 1000
# step 47 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0046.BSREAD.h5
# 1000 1000
# step 48 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0047.BSREAD.h5
# 1000 1000
# step 49 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0048.BSREAD.h5
# 1000 1000
# step 50 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0049.BSREAD.h5
# 1000 1000
# step 51 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0050.BSREAD.h5
# 1000 1000
# step 52 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0051.BSREAD.h5
# 1000 1000
# step 53 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0052.BSREAD.h5
# 1000 1000
# step 54 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0053.BSREAD.h5
# 1000 1000
# step 55 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0054.BSREAD.h5
# 1000 1000
# step 56 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0055.BSREAD.h5
# 1000 1000
# step 57 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0056.BSREAD.h5
# 1000 1000
# step 58 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0057.BSREAD.h5
# 1000 1000
# step 59 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0058.BSREAD.h5
# 1000 1000
# step 60 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0059.BSREAD.h5
# 1000 1000
# step 61 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0060.BSREAD.h5
# 1000 1000
# step 62 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0061.BSREAD.h5
# 1000 1000
# step 63 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0062.BSREAD.h5
# 1000 1000
# step 64 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0063.BSREAD.h5
# 1000 1000
# step 65 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0064.BSREAD.h5
# 1000 1000
# step 66 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0065.BSREAD.h5
# 1000 1000
# step 67 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0066.BSREAD.h5
# 1000 1000
# step 68 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0067.BSREAD.h5
# 1000 1000
# step 69 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0068.BSREAD.h5
# 1000 1000
# step 70 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0069.BSREAD.h5
# 1000 1000
# step 71 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0070.BSREAD.h5
# 1000 1000
# step 72 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0071.BSREAD.h5
# 1000 1000
# step 73 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0072.BSREAD.h5
# 1000 1000
# step 74 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0073.BSREAD.h5
# 1000 1000
# step 75 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0074.BSREAD.h5
# 1000 1000
# step 76 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0075.BSREAD.h5
# 1000 1000
# step 77 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0076.BSREAD.h5
# 1000 1000
# step 78 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0077.BSREAD.h5
# 1000 1000
# step 79 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0078.BSREAD.h5
# 1000 1000
# step 80 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0079.BSREAD.h5
# 1000 1000
# step 81 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0080.BSREAD.h5
# 1000 1000
# step 82 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0081.BSREAD.h5
# 1000 1000
# step 83 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0082.BSREAD.h5
# 1000 1000
# step 84 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0083.BSREAD.h5
# 1000 1000
# step 85 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0084.BSREAD.h5
# 1000 1000
# step 86 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0085.BSREAD.h5
# 1000 1000
# step 87 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_complete_002/CytC_Fe3_monoscan_complete_002_step0086.BSREAD.h5
# 1000 1000
# Job done!

# %%
print (signal_pump_loop.mean())
print (signal_unpump_loop.shape)
plt.figure()

plt.plot(Izero_pump_loop, label="FEL+Laser",marker='.')
plt.plot(Izero_unpump_loop, label="FEL+Laser",marker='.')
plt.plot(Izero_unpump_loop-Izero_pump_loop, label="FEL+Laser",marker='.')

print (Izero_pump_loop.mean()- Izero_unpump_loop.mean())
# Out:
# 1.1973076055281067
# (1000, 1)
# <img src="data:image/png;base64,..." width="640">
# 40.317277227723025

# %%
plt.figure()

plt.plot(Izero_pump, label="FEL+Laser",marker='.')
plt.plot(Izero_unpump, label="FEL+Laser",marker='.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Signal_pump_norm = Signal_pump / Izero_pump
Signal_unpump_norm = Signal_unpump / Izero_unpump

SignalT_pump_norm = SignalT_pump / Izero_pump
SignalT_unpump_norm = SignalT_unpump / Izero_unpump

#Signal_pump_norm = np.log(-(Signal_pump / Izero_pump))
#Signal_unpump_norm = np.log(-(Signal_unpump / Izero_unpump))


#Signal_pump = Signal_pump 
#Signal_unpump_norm = Signal_unpump 

err_signal_norm = err_signal / Izero_pump
err_signalT_norm = err_signalT / Izero_pump

# %%
# Optional to run --> it returns the maximum value of the trace

m=max(Signal_pump_norm-Signal_unpump_norm)
print(m)
[i for i, j in enumerate(Signal_pump_norm-Signal_unpump_norm) if j==m] # returns the location in x axis indexes of the max
print(Energy_eV[42])
print(Position_mm)
# Out:
# 1.3986067959654192e-08
# 7122.053831885034
# [150.54999945 150.55000225 150.54999885 150.55000345 150.54999825
#  150.54999945 150.55000075 150.54999945 150.55000025 150.54999815
#  150.55000105 150.55000305 150.55000185 150.54999905 150.54999715
#  150.54999885 150.54999825 150.54999785 150.54999585 150.55000035
#  150.55000425 150.55000055 150.54999805 150.54999605 150.55000115
#  150.54999755 150.55000065 150.55000565 150.54999935 150.54999705
#  150.54999895 150.55000015 150.55000165 150.54999915 150.54999655
#  150.54999755 150.55000125 150.54999445 150.54999795 150.54999965
#  150.55000255 150.54999745 150.55000165 150.55000265 150.54999985
#  150.55000075 150.54999895 150.54999805 150.55000535 150.54999945
#  150.54999505 150.54999995 150.55000295 150.54999725 150.55000095
#  150.55000295 150.54999835 150.54999955 150.55000175 150.55000065
#  150.55000145 150.55000185 150.55000005 150.55000415 150.54999725
#  150.55000065 150.55000145 150.54999545 150.55000175 150.54999975
#  150.55000005 150.54999815 150.55000315 150.55000385 150.55000195
#  150.55000055 150.54999655 150.55000405 150.55000135 150.54999895
#  150.54999915 150.55000055 150.55000045 150.54999655 150.54999995
#  150.55000305 150.55000085]

# %%
plt.figure(figsize = (10,5))

plt.subplot(2,2,1)
plt.plot(Energy_eV, Signal_pump_norm, label="ON",marker='o')
plt.plot(Energy_eV, Signal_unpump_norm, label="OFF",marker='+')
low_err= Signal_pump_norm - err_signal_norm
high_err= Signal_pump_norm + err_signal_norm
#plt.fill_between(Energy_eV, low_err, high_err, color='lightblue')


plt.subplot(2,2,2)
plt.plot(Energy_eV,(Signal_pump_norm-Signal_unpump_norm), label="OFF",marker='.')
#plt.plot(Position_mm, [-0.0000004]*len(Position_mm) , label="OFF")

plt.title(DIR,horizontalalignment='right')


plt.subplot(2,2,3)
plt.plot(Energy_eV, SignalT_pump_norm, label="ON",marker='o')
plt.plot(Energy_eV, SignalT_unpump_norm, label="OFF",marker='+')
#plt.fill_between(Energy_eV, low_err, high_err, color='lightblue')

plt.subplot(2,2,4)
plt.plot(Energy_eV, SignalT_pump_norm-SignalT_unpump_norm, label="OFF",marker='.')


#plt.xlabel("Position (mm)")
plt.xlabel("Energy (eV)")
plt.legend(loc="best")
plt.subplots_adjust(wspace = 0.3,hspace = 0.3) 
plt.show()

#plt.savefig('Timescan_7_diode')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
scan_name ="CytC_Fe2_monoscan_complete_009"
#scan_name ="CytC_Fe2_7122eV_delayscan_002"

# file names of the type below. copy paste for ease:
# FEL_knife_edge_Y_coarse_
# FEL_knife_edge_X_coarse_
# FEL_knife_edge_Y_fine_
# FEL_knife_edge_X_fine_

DIR = "/sf/alvra/data/p17803/raw/scan_data/" + scan_name + "/"
DIR_json = "/sf/alvra/data/p17803/res/scan_info/"

# %%
def LoadData_knife_edge(filename):
    with h5py.File(filename, 'r') as BS_file:
        pulse_ids = BS_file[channel_pulse_ids][:]
        reprate_FEL = ((pulse_ids%4 == 0) & (pulse_ids%8 != 0))                #This is for 25 Hz
        reprate_laser = pulse_ids%8 == 0                                       #This is for 12.5 Hz
        
        Data_pumped = BS_file[channel_PIPS_fluo][:][reprate_laser]
        Data_unpumped = BS_file[channel_PIPS_fluo][:][reprate_FEL]
        
        DataT_pumped = BS_file[channel_PIPS_trans][:][reprate_laser]
        DataT_unpumped = BS_file[channel_PIPS_trans][:][reprate_FEL]
        
        Izero_pump = BS_file[channel_Izero][:][reprate_laser]
        Izero_unpump = BS_file[channel_Izero][:][reprate_FEL]
        
        Energy = BS_file[channel_energy][:][reprate_FEL]
        Position = BS_file[channel_position][:][reprate_FEL]
        
    return Data_pumped, Data_unpumped, Izero_pump, Izero_unpump, Energy, Position, DataT_pumped, DataT_unpumped

def errfunc(x, a, b, c, d):
    return a + b*erf((c-x)*np.sqrt(np.log(2))/(np.abs(d)))

# %%
# !ls -lah -rt $DIR
# !hostname

listfile = os.listdir(DIR)
number_files = len(listfile)
print ("There are",number_files,"files in the folder", DIR)
# Out:
# total 1.6T
# -rw-r--r--.  1 root p17803  18G Jan 23 01:06 CytC_Fe2_monoscan_complete_009_step0000.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 01:06 CytC_Fe2_monoscan_complete_009_step0000.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:08 CytC_Fe2_monoscan_complete_009_step0001.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 5.8M Jan 23 01:08 CytC_Fe2_monoscan_complete_009_step0001.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:08 CytC_Fe2_monoscan_complete_009_step0000.BSREAD.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:09 CytC_Fe2_monoscan_complete_009_step0002.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:09 CytC_Fe2_monoscan_complete_009_step0001.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 01:09 CytC_Fe2_monoscan_complete_009_step0002.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:10 CytC_Fe2_monoscan_complete_009_step0003.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:11 CytC_Fe2_monoscan_complete_009_step0002.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 01:11 CytC_Fe2_monoscan_complete_009_step0003.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:12 CytC_Fe2_monoscan_complete_009_step0004.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:12 CytC_Fe2_monoscan_complete_009_step0003.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 01:12 CytC_Fe2_monoscan_complete_009_step0004.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:13 CytC_Fe2_monoscan_complete_009_step0005.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:14 CytC_Fe2_monoscan_complete_009_step0004.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 01:14 CytC_Fe2_monoscan_complete_009_step0005.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:15 CytC_Fe2_monoscan_complete_009_step0006.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:15 CytC_Fe2_monoscan_complete_009_step0005.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 01:15 CytC_Fe2_monoscan_complete_009_step0006.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:16 CytC_Fe2_monoscan_complete_009_step0007.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:16 CytC_Fe2_monoscan_complete_009_step0006.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 01:16 CytC_Fe2_monoscan_complete_009_step0007.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:18 CytC_Fe2_monoscan_complete_009_step0008.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:18 CytC_Fe2_monoscan_complete_009_step0007.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 01:18 CytC_Fe2_monoscan_complete_009_step0008.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:19 CytC_Fe2_monoscan_complete_009_step0009.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:19 CytC_Fe2_monoscan_complete_009_step0008.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 01:19 CytC_Fe2_monoscan_complete_009_step0009.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:21 CytC_Fe2_monoscan_complete_009_step0010.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:21 CytC_Fe2_monoscan_complete_009_step0009.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 01:21 CytC_Fe2_monoscan_complete_009_step0010.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:22 CytC_Fe2_monoscan_complete_009_step0011.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:22 CytC_Fe2_monoscan_complete_009_step0010.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 01:22 CytC_Fe2_monoscan_complete_009_step0011.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:24 CytC_Fe2_monoscan_complete_009_step0012.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:24 CytC_Fe2_monoscan_complete_009_step0011.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 01:24 CytC_Fe2_monoscan_complete_009_step0012.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:25 CytC_Fe2_monoscan_complete_009_step0013.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:25 CytC_Fe2_monoscan_complete_009_step0012.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 01:25 CytC_Fe2_monoscan_complete_009_step0013.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:26 CytC_Fe2_monoscan_complete_009_step0014.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:27 CytC_Fe2_monoscan_complete_009_step0013.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 01:27 CytC_Fe2_monoscan_complete_009_step0014.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:28 CytC_Fe2_monoscan_complete_009_step0015.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:28 CytC_Fe2_monoscan_complete_009_step0014.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 01:28 CytC_Fe2_monoscan_complete_009_step0015.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:29 CytC_Fe2_monoscan_complete_009_step0016.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:29 CytC_Fe2_monoscan_complete_009_step0015.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.6M Jan 23 01:30 CytC_Fe2_monoscan_complete_009_step0016.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:31 CytC_Fe2_monoscan_complete_009_step0017.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:31 CytC_Fe2_monoscan_complete_009_step0016.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.7M Jan 23 01:31 CytC_Fe2_monoscan_complete_009_step0017.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:32 CytC_Fe2_monoscan_complete_009_step0018.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:32 CytC_Fe2_monoscan_complete_009_step0017.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.5M Jan 23 01:32 CytC_Fe2_monoscan_complete_009_step0018.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:34 CytC_Fe2_monoscan_complete_009_step0019.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:34 CytC_Fe2_monoscan_complete_009_step0018.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.6M Jan 23 01:34 CytC_Fe2_monoscan_complete_009_step0019.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:35 CytC_Fe2_monoscan_complete_009_step0019.BSREAD.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:37 CytC_Fe2_monoscan_complete_009_step0020.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 01:37 CytC_Fe2_monoscan_complete_009_step0020.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:38 CytC_Fe2_monoscan_complete_009_step0021.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:38 CytC_Fe2_monoscan_complete_009_step0020.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.3M Jan 23 01:38 CytC_Fe2_monoscan_complete_009_step0021.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:40 CytC_Fe2_monoscan_complete_009_step0022.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:40 CytC_Fe2_monoscan_complete_009_step0021.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 01:40 CytC_Fe2_monoscan_complete_009_step0022.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:41 CytC_Fe2_monoscan_complete_009_step0023.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:41 CytC_Fe2_monoscan_complete_009_step0022.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 01:41 CytC_Fe2_monoscan_complete_009_step0023.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:43 CytC_Fe2_monoscan_complete_009_step0024.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:43 CytC_Fe2_monoscan_complete_009_step0023.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 01:43 CytC_Fe2_monoscan_complete_009_step0024.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:44 CytC_Fe2_monoscan_complete_009_step0025.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:44 CytC_Fe2_monoscan_complete_009_step0024.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.4M Jan 23 01:44 CytC_Fe2_monoscan_complete_009_step0025.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:45 CytC_Fe2_monoscan_complete_009_step0026.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:46 CytC_Fe2_monoscan_complete_009_step0025.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.5M Jan 23 01:46 CytC_Fe2_monoscan_complete_009_step0026.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:47 CytC_Fe2_monoscan_complete_009_step0027.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:47 CytC_Fe2_monoscan_complete_009_step0026.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 01:47 CytC_Fe2_monoscan_complete_009_step0027.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:48 CytC_Fe2_monoscan_complete_009_step0028.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:48 CytC_Fe2_monoscan_complete_009_step0027.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 01:49 CytC_Fe2_monoscan_complete_009_step0028.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:50 CytC_Fe2_monoscan_complete_009_step0029.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:50 CytC_Fe2_monoscan_complete_009_step0028.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.9M Jan 23 01:50 CytC_Fe2_monoscan_complete_009_step0029.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:51 CytC_Fe2_monoscan_complete_009_step0030.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:51 CytC_Fe2_monoscan_complete_009_step0029.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.8M Jan 23 01:51 CytC_Fe2_monoscan_complete_009_step0030.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:53 CytC_Fe2_monoscan_complete_009_step0031.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:53 CytC_Fe2_monoscan_complete_009_step0030.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 01:53 CytC_Fe2_monoscan_complete_009_step0031.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:54 CytC_Fe2_monoscan_complete_009_step0032.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:54 CytC_Fe2_monoscan_complete_009_step0031.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 01:54 CytC_Fe2_monoscan_complete_009_step0032.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:56 CytC_Fe2_monoscan_complete_009_step0033.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:56 CytC_Fe2_monoscan_complete_009_step0032.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.7M Jan 23 01:56 CytC_Fe2_monoscan_complete_009_step0033.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:57 CytC_Fe2_monoscan_complete_009_step0034.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:57 CytC_Fe2_monoscan_complete_009_step0033.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.7M Jan 23 01:57 CytC_Fe2_monoscan_complete_009_step0034.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 01:58 CytC_Fe2_monoscan_complete_009_step0035.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 01:59 CytC_Fe2_monoscan_complete_009_step0034.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.6M Jan 23 01:59 CytC_Fe2_monoscan_complete_009_step0035.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:00 CytC_Fe2_monoscan_complete_009_step0036.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:00 CytC_Fe2_monoscan_complete_009_step0035.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.7M Jan 23 02:00 CytC_Fe2_monoscan_complete_009_step0036.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:01 CytC_Fe2_monoscan_complete_009_step0037.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:01 CytC_Fe2_monoscan_complete_009_step0036.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.5M Jan 23 02:02 CytC_Fe2_monoscan_complete_009_step0037.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:03 CytC_Fe2_monoscan_complete_009_step0038.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:03 CytC_Fe2_monoscan_complete_009_step0037.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.7M Jan 23 02:03 CytC_Fe2_monoscan_complete_009_step0038.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:04 CytC_Fe2_monoscan_complete_009_step0039.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:04 CytC_Fe2_monoscan_complete_009_step0038.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.6M Jan 23 02:04 CytC_Fe2_monoscan_complete_009_step0039.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:06 CytC_Fe2_monoscan_complete_009_step0040.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:06 CytC_Fe2_monoscan_complete_009_step0039.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 02:06 CytC_Fe2_monoscan_complete_009_step0040.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:07 CytC_Fe2_monoscan_complete_009_step0041.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:07 CytC_Fe2_monoscan_complete_009_step0040.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 02:07 CytC_Fe2_monoscan_complete_009_step0041.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:09 CytC_Fe2_monoscan_complete_009_step0042.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:09 CytC_Fe2_monoscan_complete_009_step0041.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.7M Jan 23 02:09 CytC_Fe2_monoscan_complete_009_step0042.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:10 CytC_Fe2_monoscan_complete_009_step0043.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:10 CytC_Fe2_monoscan_complete_009_step0042.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.7M Jan 23 02:10 CytC_Fe2_monoscan_complete_009_step0043.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:11 CytC_Fe2_monoscan_complete_009_step0044.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:12 CytC_Fe2_monoscan_complete_009_step0043.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.7M Jan 23 02:12 CytC_Fe2_monoscan_complete_009_step0044.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:13 CytC_Fe2_monoscan_complete_009_step0045.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:13 CytC_Fe2_monoscan_complete_009_step0044.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.1M Jan 23 02:13 CytC_Fe2_monoscan_complete_009_step0045.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:15 CytC_Fe2_monoscan_complete_009_step0045.BSREAD.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:16 CytC_Fe2_monoscan_complete_009_step0046.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 5.7M Jan 23 02:16 CytC_Fe2_monoscan_complete_009_step0046.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:18 CytC_Fe2_monoscan_complete_009_step0047.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:18 CytC_Fe2_monoscan_complete_009_step0046.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.9M Jan 23 02:18 CytC_Fe2_monoscan_complete_009_step0047.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:19 CytC_Fe2_monoscan_complete_009_step0048.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:19 CytC_Fe2_monoscan_complete_009_step0047.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.7M Jan 23 02:19 CytC_Fe2_monoscan_complete_009_step0048.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:21 CytC_Fe2_monoscan_complete_009_step0049.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:21 CytC_Fe2_monoscan_complete_009_step0048.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.8M Jan 23 02:21 CytC_Fe2_monoscan_complete_009_step0049.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:22 CytC_Fe2_monoscan_complete_009_step0050.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:22 CytC_Fe2_monoscan_complete_009_step0049.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 02:23 CytC_Fe2_monoscan_complete_009_step0050.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:24 CytC_Fe2_monoscan_complete_009_step0051.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:24 CytC_Fe2_monoscan_complete_009_step0050.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.9M Jan 23 02:24 CytC_Fe2_monoscan_complete_009_step0051.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:25 CytC_Fe2_monoscan_complete_009_step0052.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:25 CytC_Fe2_monoscan_complete_009_step0051.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.7M Jan 23 02:25 CytC_Fe2_monoscan_complete_009_step0052.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:26 CytC_Fe2_monoscan_complete_009_step0053.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:27 CytC_Fe2_monoscan_complete_009_step0052.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 02:27 CytC_Fe2_monoscan_complete_009_step0053.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:28 CytC_Fe2_monoscan_complete_009_step0054.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:28 CytC_Fe2_monoscan_complete_009_step0053.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.8M Jan 23 02:28 CytC_Fe2_monoscan_complete_009_step0054.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:29 CytC_Fe2_monoscan_complete_009_step0055.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:30 CytC_Fe2_monoscan_complete_009_step0054.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 02:30 CytC_Fe2_monoscan_complete_009_step0055.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:31 CytC_Fe2_monoscan_complete_009_step0056.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:31 CytC_Fe2_monoscan_complete_009_step0055.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.8M Jan 23 02:31 CytC_Fe2_monoscan_complete_009_step0056.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:32 CytC_Fe2_monoscan_complete_009_step0057.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:32 CytC_Fe2_monoscan_complete_009_step0056.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.8M Jan 23 02:32 CytC_Fe2_monoscan_complete_009_step0057.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:34 CytC_Fe2_monoscan_complete_009_step0058.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:34 CytC_Fe2_monoscan_complete_009_step0057.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.8M Jan 23 02:34 CytC_Fe2_monoscan_complete_009_step0058.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:35 CytC_Fe2_monoscan_complete_009_step0059.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:35 CytC_Fe2_monoscan_complete_009_step0058.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.9M Jan 23 02:35 CytC_Fe2_monoscan_complete_009_step0059.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:37 CytC_Fe2_monoscan_complete_009_step0060.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:37 CytC_Fe2_monoscan_complete_009_step0059.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.8M Jan 23 02:37 CytC_Fe2_monoscan_complete_009_step0060.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:38 CytC_Fe2_monoscan_complete_009_step0061.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:38 CytC_Fe2_monoscan_complete_009_step0060.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.9M Jan 23 02:38 CytC_Fe2_monoscan_complete_009_step0061.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:39 CytC_Fe2_monoscan_complete_009_step0062.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:40 CytC_Fe2_monoscan_complete_009_step0061.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 02:40 CytC_Fe2_monoscan_complete_009_step0062.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:41 CytC_Fe2_monoscan_complete_009_step0063.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:41 CytC_Fe2_monoscan_complete_009_step0062.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.9M Jan 23 02:41 CytC_Fe2_monoscan_complete_009_step0063.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:42 CytC_Fe2_monoscan_complete_009_step0064.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:43 CytC_Fe2_monoscan_complete_009_step0063.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 02:43 CytC_Fe2_monoscan_complete_009_step0064.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:44 CytC_Fe2_monoscan_complete_009_step0065.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:44 CytC_Fe2_monoscan_complete_009_step0064.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.2M Jan 23 02:44 CytC_Fe2_monoscan_complete_009_step0065.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:45 CytC_Fe2_monoscan_complete_009_step0066.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:45 CytC_Fe2_monoscan_complete_009_step0065.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.7M Jan 23 02:45 CytC_Fe2_monoscan_complete_009_step0066.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:47 CytC_Fe2_monoscan_complete_009_step0067.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:47 CytC_Fe2_monoscan_complete_009_step0066.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.8M Jan 23 02:47 CytC_Fe2_monoscan_complete_009_step0067.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:48 CytC_Fe2_monoscan_complete_009_step0068.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:48 CytC_Fe2_monoscan_complete_009_step0067.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.8M Jan 23 02:48 CytC_Fe2_monoscan_complete_009_step0068.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:50 CytC_Fe2_monoscan_complete_009_step0069.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:50 CytC_Fe2_monoscan_complete_009_step0068.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.7M Jan 23 02:50 CytC_Fe2_monoscan_complete_009_step0069.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:51 CytC_Fe2_monoscan_complete_009_step0070.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:51 CytC_Fe2_monoscan_complete_009_step0069.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 02:51 CytC_Fe2_monoscan_complete_009_step0070.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:52 CytC_Fe2_monoscan_complete_009_step0071.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:53 CytC_Fe2_monoscan_complete_009_step0070.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 02:53 CytC_Fe2_monoscan_complete_009_step0071.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:54 CytC_Fe2_monoscan_complete_009_step0072.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:54 CytC_Fe2_monoscan_complete_009_step0071.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.9M Jan 23 02:54 CytC_Fe2_monoscan_complete_009_step0072.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:55 CytC_Fe2_monoscan_complete_009_step0073.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:55 CytC_Fe2_monoscan_complete_009_step0072.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.7M Jan 23 02:56 CytC_Fe2_monoscan_complete_009_step0073.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:57 CytC_Fe2_monoscan_complete_009_step0074.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:57 CytC_Fe2_monoscan_complete_009_step0073.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.5M Jan 23 02:57 CytC_Fe2_monoscan_complete_009_step0074.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 02:58 CytC_Fe2_monoscan_complete_009_step0075.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 02:58 CytC_Fe2_monoscan_complete_009_step0074.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.7M Jan 23 02:58 CytC_Fe2_monoscan_complete_009_step0075.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 03:00 CytC_Fe2_monoscan_complete_009_step0076.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 03:00 CytC_Fe2_monoscan_complete_009_step0075.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.8M Jan 23 03:00 CytC_Fe2_monoscan_complete_009_step0076.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 03:01 CytC_Fe2_monoscan_complete_009_step0077.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 03:01 CytC_Fe2_monoscan_complete_009_step0076.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.9M Jan 23 03:01 CytC_Fe2_monoscan_complete_009_step0077.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 03:03 CytC_Fe2_monoscan_complete_009_step0078.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 03:03 CytC_Fe2_monoscan_complete_009_step0077.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.9M Jan 23 03:03 CytC_Fe2_monoscan_complete_009_step0078.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 03:04 CytC_Fe2_monoscan_complete_009_step0079.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 03:04 CytC_Fe2_monoscan_complete_009_step0078.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.1M Jan 23 03:04 CytC_Fe2_monoscan_complete_009_step0079.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 03:06 CytC_Fe2_monoscan_complete_009_step0080.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 03:06 CytC_Fe2_monoscan_complete_009_step0079.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.9M Jan 23 03:06 CytC_Fe2_monoscan_complete_009_step0080.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 03:07 CytC_Fe2_monoscan_complete_009_step0081.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 03:07 CytC_Fe2_monoscan_complete_009_step0080.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.8M Jan 23 03:07 CytC_Fe2_monoscan_complete_009_step0081.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 03:08 CytC_Fe2_monoscan_complete_009_step0082.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 03:09 CytC_Fe2_monoscan_complete_009_step0081.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.9M Jan 23 03:09 CytC_Fe2_monoscan_complete_009_step0082.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 03:10 CytC_Fe2_monoscan_complete_009_step0083.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 03:10 CytC_Fe2_monoscan_complete_009_step0082.BSREAD.h5
# -rw-r--r--.  1 root p17803 6.0M Jan 23 03:10 CytC_Fe2_monoscan_complete_009_step0083.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 03:11 CytC_Fe2_monoscan_complete_009_step0084.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 03:11 CytC_Fe2_monoscan_complete_009_step0083.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.9M Jan 23 03:11 CytC_Fe2_monoscan_complete_009_step0084.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 03:13 CytC_Fe2_monoscan_complete_009_step0085.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 03:13 CytC_Fe2_monoscan_complete_009_step0084.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.8M Jan 23 03:13 CytC_Fe2_monoscan_complete_009_step0085.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803  18G Jan 23 03:14 CytC_Fe2_monoscan_complete_009_step0086.JF02T09V01.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 03:14 CytC_Fe2_monoscan_complete_009_step0085.BSREAD.h5
# -rw-r--r--.  1 root p17803 5.7M Jan 23 03:14 CytC_Fe2_monoscan_complete_009_step0086.BSREAD_CA.h5
# -rw-r--r--.  1 root p17803 827M Jan 23 03:16 CytC_Fe2_monoscan_complete_009_step0086.BSREAD.h5
# drwxrwsr-x.  2 root p17803  32K Jan 23 03:16 .
# drwxrwsr-x. 48 root p17803 4.0K Jan 23 10:13 ..
# ra-c-004.psi.ch
# There are 261 files in the folder /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/

# %%
json_file = DIR_json + scan_name + "_scan_info.json"
print (json_file)

with open(json_file) as file:
    data = json.load(file)
numFiles = len(data['scan_files'])
#numFiles = 1

print ("Processing",numFiles,"files")

Signal_pump1 = []
Signal_unpump1 = []
err_signal1 = []

SignalT_pump1 = []
SignalT_unpump1 = []
err_signalT1 = []

Izero_pump1 = []
Izero_unpump1 = []
err_Izero1 = []
Izero_loop1 = []

Position_mm = []
Energy_eV = []

for i in range(0,numFiles):
    filename = str(data['scan_files'][i][0])    
    exists = os.path.isfile(filename)
    if exists:
        print("step",i+1,"of",numFiles,": Processing %s" % (str(data['scan_files'][i][0])))
        (signal_pump1_loop,signal_unpump1_loop,Izero_pump1_loop, Izero_unpump1_loop,energy_loop,position_loop,\
         signalT_pump1_loop,signalT_unpump1_loop) = LoadData_knife_edge(str(data['scan_files'][i][0]))
        Signal_pump1.append(np.mean(signal_pump1_loop))
        Signal_unpump1.append(signal_unpump1_loop.mean())
        err_signal1.append(signal_pump1_loop.std()/np.sqrt(signal_pump1_loop.size))
        
        #SignalT_pump.append(np.mean(signalT_pump_loop))
        #SignalT_unpump.append(signalT_unpump_loop.mean())
        #err_signalT.append(signalT_pump_loop.std()/np.sqrt(signalT_pump_loop.size))
        
        Izero_pump1.append(Izero_pump1_loop.mean())
        Izero_unpump1.append(Izero_unpump1_loop.mean())
       # err_Izero.append(Izero_loop.std()/np.sqrt(Izero_loop.size))
    
        energy_loop = [x for x in energy_loop if (np.abs(x) > 0)]
        Energy_eV.append(np.mean(energy_loop))
        Position_mm.append(np.mean(position_loop))
        
        print (signal_pump1_loop.size,signal_unpump1_loop.size)
    
Signal_pump1 = np.asarray(Signal_pump1)
Signal_unpump1 = np.asarray(Signal_unpump1)
err_signal1 = np.asarray(err_signal1)

#SignalT_pump = np.asarray(SignalT_pump)
#SignalT_unpump = np.asarray(SignalT_unpump)
#err_signalT = np.asarray(err_signalT)

Izero_pump1 = np.asarray(Izero_pump1)
Izero_unpump1 = np.asarray(Izero_unpump1)
err_Izero1 = np.asarray(err_Izero1)

Energy_eV = np.asarray(Energy_eV)
Position_mm = np.asarray(Position_mm)
print ("Job done!")
# Out:
# /sf/alvra/data/p17803/res/scan_info/CytC_Fe2_monoscan_complete_009_scan_info.json
# Processing 87 files
# step 1 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0000.BSREAD.h5
# 1000 1000
# step 2 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0001.BSREAD.h5
# 1000 1000
# step 3 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0002.BSREAD.h5
# 1000 1000
# step 4 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0003.BSREAD.h5
# 1000 1000
# step 5 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0004.BSREAD.h5
# 1000 1000
# step 6 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0005.BSREAD.h5
# 1000 1000
# step 7 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0006.BSREAD.h5
# 1000 1000
# step 8 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0007.BSREAD.h5
# 1000 1000
# step 9 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0008.BSREAD.h5
# 1000 1000
# step 10 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0009.BSREAD.h5
# 1000 1000
# step 11 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0010.BSREAD.h5
# 1000 1000
# step 12 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0011.BSREAD.h5
# 1000 1000
# step 13 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0012.BSREAD.h5
# 1000 1000
# step 14 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0013.BSREAD.h5
# 1000 1000
# step 15 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0014.BSREAD.h5
# 1000 1000
# step 16 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0015.BSREAD.h5
# 1000 1000
# step 17 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0016.BSREAD.h5
# 1000 1000
# step 18 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0017.BSREAD.h5
# 1000 1000
# step 19 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0018.BSREAD.h5
# 1000 1000
# step 20 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0019.BSREAD.h5
# 1000 1000
# step 21 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0020.BSREAD.h5
# 1000 1000
# step 22 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0021.BSREAD.h5
# 1000 1000
# step 23 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0022.BSREAD.h5
# 1000 1000
# step 24 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0023.BSREAD.h5
# 1000 1000
# step 25 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0024.BSREAD.h5
# 1000 1000
# step 26 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0025.BSREAD.h5
# 1000 1000
# step 27 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0026.BSREAD.h5
# 1000 1000
# step 28 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0027.BSREAD.h5
# 1000 1000
# step 29 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0028.BSREAD.h5
# 1000 1000
# step 30 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0029.BSREAD.h5
# 1000 1000
# step 31 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0030.BSREAD.h5
# 1000 1000
# step 32 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0031.BSREAD.h5
# 1000 1000
# step 33 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0032.BSREAD.h5
# 1000 1000
# step 34 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0033.BSREAD.h5
# 1000 1000
# step 35 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0034.BSREAD.h5
# 1000 1000
# step 36 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0035.BSREAD.h5
# 1000 1000
# step 37 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0036.BSREAD.h5
# 1000 1000
# step 38 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0037.BSREAD.h5
# 1000 1000
# step 39 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0038.BSREAD.h5
# 1000 1000
# step 40 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0039.BSREAD.h5
# 1000 1000
# step 41 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0040.BSREAD.h5
# 1000 1000
# step 42 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0041.BSREAD.h5
# 1000 1000
# step 43 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0042.BSREAD.h5
# 1000 1000
# step 44 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0043.BSREAD.h5
# 1000 1000
# step 45 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0044.BSREAD.h5
# 1000 1000
# step 46 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0045.BSREAD.h5
# 1000 1000
# step 47 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0046.BSREAD.h5
# 1000 1000
# step 48 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0047.BSREAD.h5
# 1000 1000
# step 49 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0048.BSREAD.h5
# 1000 1000
# step 50 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0049.BSREAD.h5
# 1000 1000
# step 51 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0050.BSREAD.h5
# 1000 1000
# step 52 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0051.BSREAD.h5
# 1000 1000
# step 53 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0052.BSREAD.h5
# 1000 1000
# step 54 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0053.BSREAD.h5
# 1000 1000
# step 55 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0054.BSREAD.h5
# 1000 1000
# step 56 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0055.BSREAD.h5
# 1000 1000
# step 57 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0056.BSREAD.h5
# 1000 1000
# step 58 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0057.BSREAD.h5
# 1000 1000
# step 59 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0058.BSREAD.h5
# 1000 1000
# step 60 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0059.BSREAD.h5
# 1000 1000
# step 61 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0060.BSREAD.h5
# 1000 1000
# step 62 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0061.BSREAD.h5
# 1000 1000
# step 63 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0062.BSREAD.h5
# 1000 1000
# step 64 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0063.BSREAD.h5
# 1000 1000
# step 65 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0064.BSREAD.h5
# 1000 1000
# step 66 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0065.BSREAD.h5
# 1000 1000
# step 67 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0066.BSREAD.h5
# 1000 1000
# step 68 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0067.BSREAD.h5
# 1000 1000
# step 69 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0068.BSREAD.h5
# 1000 1000
# step 70 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0069.BSREAD.h5
# 1000 1000
# step 71 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0070.BSREAD.h5
# 1000 1000
# step 72 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0071.BSREAD.h5
# 1000 1000
# step 73 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0072.BSREAD.h5
# 1000 1000
# step 74 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0073.BSREAD.h5
# 1000 1000
# step 75 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0074.BSREAD.h5
# 1000 1000
# step 76 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0075.BSREAD.h5
# 1000 1000
# step 77 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0076.BSREAD.h5
# 1000 1000
# step 78 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0077.BSREAD.h5
# 1000 1000
# step 79 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0078.BSREAD.h5
# 1000 1000
# step 80 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0079.BSREAD.h5
# 1000 1000
# step 81 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0080.BSREAD.h5
# 1000 1000
# step 82 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0081.BSREAD.h5
# 1000 1000
# step 83 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0082.BSREAD.h5
# 1000 1000
# step 84 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0083.BSREAD.h5
# 1000 1000
# step 85 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0084.BSREAD.h5
# 1000 1000
# step 86 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0085.BSREAD.h5
# 1000 1000
# step 87 of 87 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe2_monoscan_complete_009/CytC_Fe2_monoscan_complete_009_step0086.BSREAD.h5
# 1000 1000
# Job done!

# %%
Signal_unpump_norm = Signal_unpump / Izero_unpump
Signal_unpump_norm1 = Signal_unpump1 / Izero_unpump1
Signal_pump_norm1 = Signal_pump1 / Izero_pump1


#SignalT_pump_norm = SignalT_pump / Izero_pump
#SignalT_unpump_norm = SignalT_unpump / Izero_unpump

#Signal_pump_norm = np.log(-(Signal_pump / Izero_pump))
#Signal_unpump_norm = np.log(-(Signal_unpump / Izero_unpump))


#Signal_pump = Signal_pump 
#Signal_unpump_norm = Signal_unpump 

#err_signal_norm1 = err_signal1 / Izero_pump1
#err_signalT_norm1 = err_signalT1 / Izero_pump1

# %%
plt.figure(figsize = (10,5))

plt.subplot(2,2,1)
plt.plot(Energy_eV, Signal_unpump_norm, label="Fe3OFF",marker='+')
plt.plot(Energy_eV, Signal_unpump_norm1, label="Fe2OFF",marker='+')

plt.subplot(2,2,2)
plt.plot(Energy_eV, Signal_pump_norm1, label="Fe2ON",marker='o')
plt.plot(Energy_eV, Signal_unpump_norm1, label="Fe2OFF",marker='+')

plt.subplot(2,2,3)
plt.plot(Energy_eV, Signal_pump_norm, label="Fe3ON",marker='o')
plt.plot(Energy_eV, Signal_unpump_norm, label="Fe3OFF",marker='+')





#plt.xlabel("Position (mm)")
plt.xlabel("Energy (eV)")
plt.legend(loc="best")
plt.subplots_adjust(wspace = 0.3,hspace = 0.3) 
plt.show()

#plt.savefig('Timescan_7_diode')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib widget
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import json, os, math, glob
import importlib
from matplotlib import pyplot as plt
from scipy.optimize import curve_fit
from IPython.display import clear_output, display

from alvra_tools.utils import *
from alvra_tools.channels import *
from alvra_tools.analysis_apo import *
from alvra_tools.alvra_widgets import Rebin_widget, RunSelectorUI, scan_runs
from IPython.display import display

import warnings
warnings.filterwarnings('ignore')

# %%
pgroup = 'p22591'
runlist = [11]

data, meta = merge_multiple_runs(pgroup, runlist)
# Out:
# Processing run 11
# 100%|██████████| 21/21 [00:05<00:00,  3.92it/s]

# %%
#plot_merged_data(data, meta, Signal='laser', Izero='Izero122', TT='124', withTT=True, bins=100, figsize=(10, 3))

# %%
ui, out  = Rebin_widget(data=data)
ui
# Out:
# VBox(children=(HTML(value='<h3>Rebin Parameters</h3>'), ToggleButtons(description='Mode:', options=(('Scan', '…

# %%
data_plot1 = {"results": out['results1'], "params": out['params'], "which": "signal1"}
fig, axes = plotter.fit_risetime(data_plot1, meta)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

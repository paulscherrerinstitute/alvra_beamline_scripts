# %%
# %matplotlib nbagg
import jungfrau_utils as ju
import numpy as np
import json
import h5py
import matplotlib.pyplot as plt
import scipy
from scipy.ndimage.filters import gaussian_filter
from scipy.special import erf
from scipy.optimize import curve_fit
import os
import time

# %%
#Following lines are to define a couple of functions that will be used later.

def rebin_sum(a):
    if a.size%bin_ != 0:
        a = a[0:a.size//bin_ * bin_]

    return a.reshape((-1, bin_)).sum(axis=1)

def rebin_mean(a):
    if a.size%bin_ != 0:
        a = a[0:a.size//bin_ * bin_]

    return a.reshape((-1, bin_)).mean(axis=1)

# Convert energy to a number of photons counting values falling within a particular range.
# This will always return integer photon counts.
def convert_to_photon_num_range(image):
    return np.ceil(np.divide(image - photon_range[0], np.mean(photon_range)))

# Convert energy to a number of photons using the central energy of a single photon.
# This can return fractional number of photons.`
def convert_to_photon_num_mean(image):
    return image / np.mean(photon_range)

# %%
# Take the correct pedestal file (usually located in /sf/alvra/data/*pgroup*/res/JF_pedestals)
# Take the correct gains.h5 file (usually located in /sf/alvra/config/jungfrau/gainMaps/JF02T09V01/)

#pede_file = "/sf/alvra/data/res/p16581/pedestal_20180307_2303_res.h5"
pede_file = "/sf/alvra/data/p17803/res/JF_pedestals/pedestal_20190121_1514.JF02T09V01.res.h5"
#pede_file = "/sf/alvra/data/p17803/res/JF_pedestals/pedestal_20190124_2035.JF02T09V01.res.h5"
gain_file = "/sf/alvra/config/jungfrau/gainMaps/JF02T09V01/gains.h5"

with h5py.File(gain_file, "r") as file: 
    G = file["gains"][:]
    
with h5py.File(pede_file, "r") as file: 
    P = file["gains"][:]
    mask = file["pixel_mask"][:]
    
print("Dimensions of G: ", G.shape)

channel_JFimages = "data/JF02T09V01/data"
channel_pulse_idsJF = "data/JF02T09V01/pulse_id"

channel_delay = "data/SLAAR11-LMOT-M451:ENC_1_BS/data"              #Delay of pump-probe delay stage
channel_energy = "data/SLAAR11-LTIM01-EVR0:DUMMY_PV3_NBS/data"      #Mono energy in eV
channel_pulse_idsBS = "data/SLAAR11-LMOT-M451:ENC_1_BS/pulse_id"      #Pulse ids taken from pump-probe delay stage (100 Hz)

#channel_PIPS_trans = "data/SARES11-GES1:CH1_VAL_GET/data"           #X-ray TRANS diode to PRIME Keysight (channel 1)
#channel_PIPS_fluo = "data/SARES11-GES1:CH2_VAL_GET/data"            #X-ray FLUO diode to PRIME Keysight (channel 2)
channel_Izero = "data/SARES11-LSCP10-FNS:CH1:VAL_GET/data"          #Izero diode to PRIME Ioxos (channel 1)
#channel_Izero2 = "data/SARES11-LSCP10-FNS:CH0:VAL_GET/data"          #Izero diode to PRIME Ioxos (channel 0)
#channel_Izero3 = "data/SARES11-LSCP10-FNS:CH3:VAL_GET/data"          #Izero diode to PRIME Ioxos (channel 3)
#channel_Izero4 = "data/SARES11-LSCP10-FNS:CH2:VAL_GET/data"         #Izero diode to PRIME Ioxos (channel 2)
#channel_LaserDiode = "data/SLAAR11-LSCP1-FNS:CH0:VAL_GET/data"      #Laser diode to ESA Laser Ioxos 
#channel_Laser_refDiode = "data/SLAAR11-LSCP1-FNS:CH2:VAL_GET/data"  #Laser diode leaking from beampath, to ESA Laser Ioxos 
#channel_LAM_delaystage = "data/SLAAR11-LTIM01-EVR0:DUMMY_PV2_NBS/data"       #LAM internal stage position in mm
#channel_LAM_stepper = "data/SLAAR11-LTIM01-EVR0:DUMMY_PV10_NBS/data"         #LAM stepper motor (used for feedback)
#channel_PALM_eTOF = "data/SAROP11-PALMK118:CH2_BUFFER/data"                 #PALM eTof from Ch2
#channel_PALM_drift = "data/SAROP11-PALMK118:CH2_VAL_GET/data"               #PALM drift
# Out:
# Dimensions of G:  (4, 512, 9216)

# %%
def LoadData_JF(filename):
    with h5py.File(filename, 'r') as JF_file:
        pulse_ids = JF_file[channel_pulse_idsJF][:]
        pulse_ids = np.reshape(pulse_ids, (pulse_ids.size,))
        
        #reprate_FEL = ((pulse_ids%10 == 0) & (pulse_ids%20 != 0))              #This is for 10 Hz
        #reprate_laser = pulse_ids%20 == 0                                      #This is for 5 Hz
        reprate_FEL = ((pulse_ids%4 == 0) & (pulse_ids%8 != 0))                #This is for 25 Hz
        reprate_laser = pulse_ids%8 == 0                                       #This is for 12.5 Hz
        
        image_JF_ON = JF_file[channel_JFimages][:,:,:][reprate_laser]
        image_JF_OFF = JF_file[channel_JFimages][:,:,:][reprate_FEL]
        
        image_roi1_ON = image_JF_ON[:, roi1[0][0]:roi1[0][1], roi1[1][0]:roi1[1][1]]
        image_roi2_ON = image_JF_ON[:, roi2[0][0]:roi2[0][1], roi2[1][0]:roi2[1][1]]
        
        image_roi1_OFF = image_JF_OFF[:, roi1[0][0]:roi1[0][1], roi1[1][0]:roi1[1][1]]
        image_roi2_OFF = image_JF_OFF[:, roi2[0][0]:roi2[0][1], roi2[1][0]:roi2[1][1]]
        
    return image_roi1_ON, image_roi1_OFF, image_roi2_ON, image_roi2_OFF

def LoadData_BS(filename):
    with h5py.File(filename, 'r') as BS_file:
        pulse_ids = BS_file[channel_pulse_idsBS][:]
        pulse_ids = np.reshape(pulse_ids, (pulse_ids.size,))
        
        #reprate_FEL = ((pulse_ids%10 == 0) & (pulse_ids%20 != 0))              #This is for 10 Hz
        #reprate_laser = pulse_ids%20 == 0                                      #This is for 5 Hz
        reprate_FEL = ((pulse_ids%4 == 0) & (pulse_ids%8 != 0))                #This is for 25 Hz
        reprate_laser = pulse_ids%8 == 0                                       #This is for 12.5 Hz
        
        Izero_pump = BS_file[channel_Izero][:][reprate_laser]
        Izero_unpump = BS_file[channel_Izero][:][reprate_FEL]      
        
        delay = BS_file[channel_delay][:][reprate_FEL]
        energy = BS_file[channel_energy][:][reprate_FEL]
        
    return delay, energy, Izero_pump, Izero_unpump

def errfunc(x, a, b, c, d):
    return a + b*erf((c-x)*np.sqrt(np.log(2))/(np.abs(d)))

# %%
DIR = "/sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/"
#DIR = "/sf/alvra/data/p17803/raw/"

DIR_json = "/sf/alvra/data/p17803/res/scan_info/"

# !ls -lah -t /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/
#!ls -lah -t /sf/alvra/data/p17803/raw/


# !hostname

listfile = os.listdir(DIR)
number_files = len(listfile)
print ("There are",number_files,"files in the folder", DIR)
# Out:
# total 479G
# drwxrwsr-x. 147 root p17803  32K Jan 31 15:28 ..
# drwxrwsr-x.   2 root p17803  32K Jan 31 14:36 .
# -rw-r--r--.   1 root p17803 827M Jan 31 14:36 FeBpy_monoscan_350nm_5uJ_1ps_001_step0025.BSREAD.h5
# -rw-r--r--.   1 root p17803 6.4M Jan 31 14:35 FeBpy_monoscan_350nm_5uJ_1ps_001_step0025.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:35 FeBpy_monoscan_350nm_5uJ_1ps_001_step0024.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:34 FeBpy_monoscan_350nm_5uJ_1ps_001_step0025.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.2M Jan 31 14:33 FeBpy_monoscan_350nm_5uJ_1ps_001_step0024.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:33 FeBpy_monoscan_350nm_5uJ_1ps_001_step0023.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:33 FeBpy_monoscan_350nm_5uJ_1ps_001_step0024.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.4M Jan 31 14:32 FeBpy_monoscan_350nm_5uJ_1ps_001_step0023.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:32 FeBpy_monoscan_350nm_5uJ_1ps_001_step0022.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:31 FeBpy_monoscan_350nm_5uJ_1ps_001_step0023.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.3M Jan 31 14:30 FeBpy_monoscan_350nm_5uJ_1ps_001_step0022.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:30 FeBpy_monoscan_350nm_5uJ_1ps_001_step0021.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:30 FeBpy_monoscan_350nm_5uJ_1ps_001_step0022.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.1M Jan 31 14:29 FeBpy_monoscan_350nm_5uJ_1ps_001_step0021.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:29 FeBpy_monoscan_350nm_5uJ_1ps_001_step0020.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:29 FeBpy_monoscan_350nm_5uJ_1ps_001_step0021.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.3M Jan 31 14:27 FeBpy_monoscan_350nm_5uJ_1ps_001_step0020.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:27 FeBpy_monoscan_350nm_5uJ_1ps_001_step0019.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:27 FeBpy_monoscan_350nm_5uJ_1ps_001_step0020.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.3M Jan 31 14:26 FeBpy_monoscan_350nm_5uJ_1ps_001_step0019.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:26 FeBpy_monoscan_350nm_5uJ_1ps_001_step0018.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:26 FeBpy_monoscan_350nm_5uJ_1ps_001_step0019.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.2M Jan 31 14:24 FeBpy_monoscan_350nm_5uJ_1ps_001_step0018.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:24 FeBpy_monoscan_350nm_5uJ_1ps_001_step0017.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:24 FeBpy_monoscan_350nm_5uJ_1ps_001_step0018.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.2M Jan 31 14:23 FeBpy_monoscan_350nm_5uJ_1ps_001_step0017.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:23 FeBpy_monoscan_350nm_5uJ_1ps_001_step0016.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:23 FeBpy_monoscan_350nm_5uJ_1ps_001_step0017.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.0M Jan 31 14:22 FeBpy_monoscan_350nm_5uJ_1ps_001_step0016.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:21 FeBpy_monoscan_350nm_5uJ_1ps_001_step0015.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:21 FeBpy_monoscan_350nm_5uJ_1ps_001_step0016.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.3M Jan 31 14:20 FeBpy_monoscan_350nm_5uJ_1ps_001_step0015.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:20 FeBpy_monoscan_350nm_5uJ_1ps_001_step0014.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:20 FeBpy_monoscan_350nm_5uJ_1ps_001_step0015.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.0M Jan 31 14:19 FeBpy_monoscan_350nm_5uJ_1ps_001_step0014.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:18 FeBpy_monoscan_350nm_5uJ_1ps_001_step0013.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:18 FeBpy_monoscan_350nm_5uJ_1ps_001_step0014.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.1M Jan 31 14:17 FeBpy_monoscan_350nm_5uJ_1ps_001_step0013.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:17 FeBpy_monoscan_350nm_5uJ_1ps_001_step0012.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:17 FeBpy_monoscan_350nm_5uJ_1ps_001_step0013.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.1M Jan 31 14:16 FeBpy_monoscan_350nm_5uJ_1ps_001_step0012.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:16 FeBpy_monoscan_350nm_5uJ_1ps_001_step0011.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:15 FeBpy_monoscan_350nm_5uJ_1ps_001_step0012.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.3M Jan 31 14:15 FeBpy_monoscan_350nm_5uJ_1ps_001_step0011.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:14 FeBpy_monoscan_350nm_5uJ_1ps_001_step0010.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:14 FeBpy_monoscan_350nm_5uJ_1ps_001_step0011.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 5.8M Jan 31 14:13 FeBpy_monoscan_350nm_5uJ_1ps_001_step0010.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:13 FeBpy_monoscan_350nm_5uJ_1ps_001_step0009.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:13 FeBpy_monoscan_350nm_5uJ_1ps_001_step0010.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.1M Jan 31 14:11 FeBpy_monoscan_350nm_5uJ_1ps_001_step0009.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:11 FeBpy_monoscan_350nm_5uJ_1ps_001_step0008.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:11 FeBpy_monoscan_350nm_5uJ_1ps_001_step0009.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.2M Jan 31 14:10 FeBpy_monoscan_350nm_5uJ_1ps_001_step0008.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:10 FeBpy_monoscan_350nm_5uJ_1ps_001_step0007.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:10 FeBpy_monoscan_350nm_5uJ_1ps_001_step0008.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.0M Jan 31 14:08 FeBpy_monoscan_350nm_5uJ_1ps_001_step0007.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:08 FeBpy_monoscan_350nm_5uJ_1ps_001_step0006.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:08 FeBpy_monoscan_350nm_5uJ_1ps_001_step0007.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.1M Jan 31 14:07 FeBpy_monoscan_350nm_5uJ_1ps_001_step0006.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:07 FeBpy_monoscan_350nm_5uJ_1ps_001_step0005.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:07 FeBpy_monoscan_350nm_5uJ_1ps_001_step0006.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 6.0M Jan 31 14:06 FeBpy_monoscan_350nm_5uJ_1ps_001_step0005.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:05 FeBpy_monoscan_350nm_5uJ_1ps_001_step0004.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:05 FeBpy_monoscan_350nm_5uJ_1ps_001_step0005.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 5.7M Jan 31 14:04 FeBpy_monoscan_350nm_5uJ_1ps_001_step0004.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:04 FeBpy_monoscan_350nm_5uJ_1ps_001_step0003.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:04 FeBpy_monoscan_350nm_5uJ_1ps_001_step0004.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 5.8M Jan 31 14:03 FeBpy_monoscan_350nm_5uJ_1ps_001_step0003.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:03 FeBpy_monoscan_350nm_5uJ_1ps_001_step0002.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:02 FeBpy_monoscan_350nm_5uJ_1ps_001_step0003.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 5.6M Jan 31 14:01 FeBpy_monoscan_350nm_5uJ_1ps_001_step0002.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:01 FeBpy_monoscan_350nm_5uJ_1ps_001_step0001.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 14:01 FeBpy_monoscan_350nm_5uJ_1ps_001_step0002.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 5.8M Jan 31 14:00 FeBpy_monoscan_350nm_5uJ_1ps_001_step0001.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803 827M Jan 31 14:00 FeBpy_monoscan_350nm_5uJ_1ps_001_step0000.BSREAD.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 13:59 FeBpy_monoscan_350nm_5uJ_1ps_001_step0001.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 5.8M Jan 31 13:58 FeBpy_monoscan_350nm_5uJ_1ps_001_step0000.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  18G Jan 31 13:58 FeBpy_monoscan_350nm_5uJ_1ps_001_step0000.JF02T09V01.h5
# ra-c-032.psi.ch
# There are 78 files in the folder /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/

# %%
# First we load the first images of a file to check if everything is fine with the pedestal & gain files (check highgain True or False)
# We can see also how the ROIs look like (will be useful later)

fileName = "FeBpy_monoscan_350nm_5uJ_1ps_001_step0025.JF02T09V01.h5"
#fileName = "CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0015.JF02T09V01.h5"

jf_file = h5py.File(DIR + fileName)

print(jf_file)

images = jf_file[channel_JFimages]
pulse_ids = jf_file[channel_pulse_idsJF]
print (images.shape)

nframes = 100

#nframes=images.shape(0)

total = 0
threshold_low = 3
threshold_high = 7

#roi = [[225, 325], [6950, 7075]]
#roi = [[225, 325], [7900, 8450]]
roi = [[0, images.shape[1]], [0, images.shape[2]]]

for i in range(nframes):
    image = images[i][:]
    total += ju.apply_gain_pede(image, G=G, P=P, pixel_mask=mask, highgain=False)[roi[0][0]:roi[0][1], roi[1][0]:roi[1][1]]

total /= nframes


plt.figure()
plt.imshow(total, origin="lower", extent = [roi[1][0],roi[1][-1],roi[0][0],roi[0][-1]], aspect='auto', vmin=0, vmax=0.4)
plt.colorbar()
plt.show()
# Out:
# <HDF5 file "FeBpy_monoscan_350nm_5uJ_1ps_001_step0025.JF02T09V01.h5" (mode r)>
# (2000, 512, 9216)
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
totalImage = total * nframes
background = totalImage.sum(axis = 0)
plt.figure()

plt.plot(background, label="Full", marker='.')
plt.ylim((-100000,100000))
plt.legend(loc="best")
plt.title(jf_file)
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# Text(0.5,1,'<HDF5 file "FeBpy_monoscan_350nm_5uJ_1ps_001_step0025.JF02T09V01.h5" (mode r)>')

# %% [markdown]
# # Set the ROIs (roi1 & roi2 in pixels) in the next cell

# %%
# Ka emission 
roi1 = [[200, 300], [6900, 7100]] # change these numbers, here they are for both crystals1 (up & down) overlapped
#roi1 = [[7030, 7130], [220, 290]]
# Kb emission 
roi2 = [[200, 300], [8300, 8450]] # change these numbers, here they are for both crystals2 (up & down) overlapped

##################################################################

P_r_roi2 = P[:, roi2[0][0]:roi2[0][1], roi2[1][0]:roi2[1][1]]
G_r_roi2 = G[:, roi2[0][0]:roi2[0][1], roi2[1][0]:roi2[1][1]]
mask_r_roi2 = mask[roi2[0][0]:roi2[0][1], roi2[1][0]:roi2[1][1]]

P_r_roi1 = P[:, roi1[0][0]:roi1[0][1], roi1[1][0]:roi1[1][1]]
G_r_roi1 = G[:, roi1[0][0]:roi1[0][1], roi1[1][0]:roi1[1][1]]
mask_r_roi1 = mask[roi1[0][0]:roi1[0][1], roi1[1][0]:roi1[1][1]]

# %% [markdown]
# # The next cell is to analyse a single file within a files of a scan

# %%
#files = ["Kalpha_Fe_foil_8keV_0.1trans_3"]          # you need to change only this name
#files = ["CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0019","CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0020","CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0022","CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0023"]

scan_name = "CytC_Fe3_monoscan_350nm_5uJ_500fs_004"
file_name = "CytC_Fe3_monoscan_350nm_5uJ_500fs_004_step0055"
step_number = 55

######################################################################################
start_time = time.time()
spectrum_ON_roi1 = 0
spectrum_OFF_roi1 = 0
spectrum_ON_roi2 = 0
spectrum_OFF_roi2 = 0

json_file = DIR_json + scan_name + "_scan_info.json"
print (json_file)

with open(json_file) as file:
    data = json.load(file)
numFiles = len(data['scan_files'])
numFiles = 1
print ("Processing",numFiles,"files")

JF_single_file = DIR + file_name + ".JF02T09V01.h5"
BS_single_file = DIR + file_name + ".BSREAD.h5"

print("Processing file %s" % (JF_single_file))

(image_roi1_ON,image_roi1_OFF,image_roi2_ON,image_roi2_OFF) = LoadData_JF(str(data['scan_files'][step_number][1]))
(Delay_mm,Energy_eV,Izero_pump,Izero_unpump) = LoadData_BS(str(data['scan_files'][step_number][0]))

meanI0pump = np.median(Izero_pump)
sigmaI0pump = np.std(Izero_pump)
meanI0unpump = np.median(Izero_unpump)
sigmaI0unpump = np.std(Izero_unpump) 

nframes_ON = np.ma.size(image_roi1_ON,0)
nframes_OFF = np.ma.size(image_roi1_OFF,0)
print (nframes_ON, nframes_OFF)
threshold = 2
threshold_low = 3 
threshold_high = 8
photon_range = (6, 7)

for j in range(nframes_ON):
        image_ON_2D_roi1 = image_roi1_ON[j,:,:]
        image_ON_2D_roi1= ju.apply_gain_pede(image_ON_2D_roi1, G=G_r_roi1, P=P_r_roi1, pixel_mask=mask_r_roi1, highgain=False)
        image_ON_2D_roi1[image_ON_2D_roi1 < threshold_low] = 0
        image_ON_2D_roi1[image_ON_2D_roi1 > threshold_high] = 0
#         image_ON_2D_roi1 = convert_to_photon_num_range(image_ON_2D_roi1)
        #if Izero_pump[j]>(meanI0pump-1.2*sigmaI0pump) and Izero_pump[j]<(meanI0pump+1.2*sigmaI0pump):
        spectrum_ON_roi1 += image_ON_2D_roi1.sum(axis=0)#/Izero_pump[j]
        
        image_OFF_2D_roi1 = image_roi1_OFF[j,:,:]
        image_OFF_2D_roi1= ju.apply_gain_pede(image_OFF_2D_roi1, G=G_r_roi1, P=P_r_roi1, pixel_mask=mask_r_roi1, highgain=False)
        image_OFF_2D_roi1[image_OFF_2D_roi1 < threshold_low] = 0
        image_OFF_2D_roi1[image_OFF_2D_roi1 > threshold_high] = 0
#         image_OFF_2D_roi1 = convert_to_photon_num_range(image_OFF_2D_roi1)
        #if Izero_unpump[j]>(meanI0unpump-1.2*sigmaI0unpump) and Izero_unpump[j]<(meanI0unpump+1.2*sigmaI0unpump):
        spectrum_OFF_roi1 += image_OFF_2D_roi1.sum(axis=0)#/Izero_unpump[j]
        
        image_ON_2D_roi2 = image_roi2_ON[j,:,:]
        image_ON_2D_roi2= ju.apply_gain_pede(image_ON_2D_roi2, G=G_r_roi2, P=P_r_roi2, pixel_mask=mask_r_roi2, highgain=False)
        image_ON_2D_roi2[image_ON_2D_roi2 < threshold_low] = 0
        image_ON_2D_roi2[image_ON_2D_roi2 > threshold_high] = 0
#         image_ON_2D_roi2 = convert_to_photon_num_range(image_ON_2D_roi2)
        #if Izero_pump[j]>(meanI0pump-1.2*sigmaI0pump) and Izero_pump[j]<(meanI0pump+1.2*sigmaI0pump):
        spectrum_ON_roi2 += image_ON_2D_roi2.sum(axis=0)#/Izero_pump[j]
        
        image_OFF_2D_roi2 = image_roi2_OFF[j,:,:]
        image_OFF_2D_roi2= ju.apply_gain_pede(image_OFF_2D_roi2, G=G_r_roi2, P=P_r_roi2, pixel_mask=mask_r_roi2, highgain=False)
        image_OFF_2D_roi2[image_OFF_2D_roi2 < threshold_low] = 0
        image_OFF_2D_roi2[image_OFF_2D_roi2 > threshold_high] = 0
#         image_OFF_2D_roi2 = convert_to_photon_num_range(image_OFF_2D_roi2)
        #if Izero_unpump[j]>(meanI0unpump-1.2*sigmaI0unpump) and Izero_unpump[j]<(meanI0unpump+1.2*sigmaI0unpump):
        spectrum_OFF_roi2 += image_OFF_2D_roi2.sum(axis=0)#/Izero_unpump[j]
        
print ("Job done! It took",round((time.time() - start_time),2),"seconds to process the file")
# Out:
# /sf/alvra/data/p17803/res/scan_info/CytC_Fe3_monoscan_350nm_5uJ_500fs_004_scan_info.json
# Processing 1 files
# Processing file /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_350nm_5uJ_500fs_004/CytC_Fe3_monoscan_350nm_5uJ_500fs_004_step0055.JF02T09V01.h5
# 2000 2000
# Job done! It took 62.12 seconds to process the file

# %% [markdown]
# # The next cell is to analyse a single file or a series of identical ones to be summed up

# %%
#files = ["Kalpha_Fe_foil_8keV_0.1trans_3"]          # you need to change only this name
#files = ["CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0019","CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0020","CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0022","CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0023"]

files = ["CytC_Fe3_monoscan_350nm_5uJ_500fs_004_step0019"]
######################################################################################
start_time = time.time()
spectrum_ON_roi1 = 0
spectrum_OFF_roi1 = 0
spectrum_ON_roi2 = 0
spectrum_OFF_roi2 = 0
        
for f in files:
    
    JF_single_file = DIR + f + ".JF02T09V01.h5"
    BS_single_file = DIR + f + ".BSREAD.h5"
    print("Processing file %s" % (JF_single_file))
    
    (image_roi1_ON,image_roi1_OFF,image_roi2_ON,image_roi2_OFF,pulse_ids) = LoadData_JF(str(JF_single_file))
    (Delay_mm,Energy_eV,Izero_pump,Izero_unpump) = LoadData_BS(str(BS_single_file))
    
    meanI0pump = np.median(Izero_pump)
    sigmaI0pump = np.std(Izero_pump)
    meanI0unpump = np.median(Izero_unpump)
    sigmaI0unpump = np.std(Izero_unpump) 
    
    nframes_ON = np.ma.size(image_roi1_ON,0)
    nframes_OFF = np.ma.size(image_roi1_OFF,0)
    print (nframes_ON, nframes_OFF)
    threshold = 2
    threshold_low = 3 
    threshold_high = 7
    #photon_range = (6, 7)
    
    for j in range(nframes_ON):
        image_ON_2D_roi1 = image_roi1_ON[j,:,:]
        image_ON_2D_roi1= ju.apply_gain_pede(image_ON_2D_roi1, G=G_r_roi1, P=P_r_roi1, pixel_mask=mask_r_roi1, highgain=False)
        image_ON_2D_roi1[image_ON_2D_roi1 < threshold_low] = 0
        image_ON_2D_roi1[image_ON_2D_roi1 > threshold_high] = 0
#         image_ON_2D_roi1 = convert_to_photon_num_range(image_ON_2D_roi1)
        if Izero_pump[j]>(meanI0pump-1.2*sigmaI0pump) and Izero_pump[j]<(meanI0pump+1.2*sigmaI0pump):
                spectrum_ON_roi1 += image_ON_2D_roi1.sum(axis=0)/Izero_pump[j]
        
        image_OFF_2D_roi1 = image_roi1_OFF[j,:,:]
        image_OFF_2D_roi1= ju.apply_gain_pede(image_OFF_2D_roi1, G=G_r_roi1, P=P_r_roi1, pixel_mask=mask_r_roi1, highgain=False)
        image_OFF_2D_roi1[image_OFF_2D_roi1 < threshold_low] = 0
        image_OFF_2D_roi1[image_OFF_2D_roi1 > threshold_high] = 0
#         image_OFF_2D_roi1 = convert_to_photon_num_range(image_OFF_2D_roi1)
        if Izero_unpump[j]>(meanI0unpump-1.2*sigmaI0unpump) and Izero_unpump[j]<(meanI0unpump+1.2*sigmaI0unpump):
                spectrum_OFF_roi1 += image_OFF_2D_roi1.sum(axis=0)/Izero_unpump[j]
        
        image_ON_2D_roi2 = image_roi2_ON[j,:,:]
        image_ON_2D_roi2= ju.apply_gain_pede(image_ON_2D_roi2, G=G_r_roi2, P=P_r_roi2, pixel_mask=mask_r_roi2, highgain=False)
        image_ON_2D_roi2[image_ON_2D_roi2 < threshold_low] = 0
        image_ON_2D_roi2[image_ON_2D_roi2 > threshold_high] = 0
#         image_ON_2D_roi2 = convert_to_photon_num_range(image_ON_2D_roi2)
        if Izero_pump[j]>(meanI0pump-1.2*sigmaI0pump) and Izero_pump[j]<(meanI0pump+1.2*sigmaI0pump):
                spectrum_ON_roi2 += image_ON_2D_roi2.sum(axis=0)/Izero_pump[j]
        
        image_OFF_2D_roi2 = image_roi2_OFF[j,:,:]
        image_OFF_2D_roi2= ju.apply_gain_pede(image_OFF_2D_roi2, G=G_r_roi2, P=P_r_roi2, pixel_mask=mask_r_roi2, highgain=False)
        image_OFF_2D_roi2[image_OFF_2D_roi2 < threshold_low] = 0
        image_OFF_2D_roi2[image_OFF_2D_roi2 > threshold_high] = 0
#         image_OFF_2D_roi2 = convert_to_photon_num_range(image_OFF_2D_roi2)
        if Izero_unpump[j]>(meanI0unpump-1.2*sigmaI0unpump) and Izero_unpump[j]<(meanI0unpump+1.2*sigmaI0unpump):
                spectrum_OFF_roi2 += image_OFF_2D_roi2.sum(axis=0)/Izero_unpump[j]
        
print ("Job done! It took",round((time.time() - start_time),2),"seconds to process",np.size(files),"file(s)")
# Out:
# Processing file /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_monoscan_350nm_5uJ_500fs_004/CytC_Fe3_monoscan_350nm_5uJ_500fs_004_step0019.JF02T09V01.h5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-84b88753b8fa> in <module>()
#      16     print("Processing file %s" % (JF_single_file))
#      17
# ---> 18     (image_roi1_ON,image_roi1_OFF,image_roi2_ON,image_roi2_OFF,pulse_ids) = LoadData_JF(str(JF_single_file))
#      19     (Delay_mm,Energy_eV,Izero_pump,Izero_unpump) = LoadData_BS(str(BS_single_file))
#      20
#
# ValueError: not enough values to unpack (expected 5, got 4)

# %%
spectrum_total_roi1 = spectrum_OFF_roi1 + spectrum_ON_roi1
spectrum_total_roi2 = spectrum_OFF_roi2 + spectrum_ON_roi2

# %%
x_axis = np.arange(roi1[1][0], roi1[1][1])
plt.figure()

plt.subplot(211)
plt.plot(x_axis,spectrum_total_roi1, label="ROI1", marker='.')
plt.legend(loc="best")
plt.title(jf_file)
x_axis = np.arange(roi2[1][0], roi2[1][1])
plt.subplot(212)
plt.plot(x_axis,spectrum_total_roi2,label="ROI2",marker='.')
plt.legend(loc="best")
# Out:
# <div id='a9c07b15-e56f-44b7-821c-3ed7e0373988'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-81fce98d0334> in <module>()
#       3
#       4 plt.subplot(211)
# ----> 5 plt.plot(x_axis,spectrum_total_roi1, label="ROI1", marker='.')
#       6 plt.legend(loc="best")
#       7 plt.title(jf_file)
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1370         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1371
# -> 1372         for line in self._get_lines(*args, **kwargs):
#    1373             self.add_line(line)
#    1374             lines.append(line)
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     402                 this += args[0],
#     403                 args = args[1:]
# --> 404             for seg in self._plot_args(this, kwargs):
#     405                 yield seg
#     406
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     382             x, y = index_of(tup[-1])
#     383
# --> 384         x, y = self._xy_from_xy(x, y)
#     385
#     386         if self.command == 'plot':
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     241         if x.shape[0] != y.shape[0]:
#     242             raise ValueError("x and y must have same first dimension, but "
# --> 243                              "have shapes {} and {}".format(x.shape, y.shape))
#     244         if x.ndim > 2 or y.ndim > 2:
#     245             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (200,) and (1,)

# %%
# Let's check if everything worked out fine, plotting one spectrum for instance the spectra with laser OFF.
# This is for ROI1

x_axis = np.arange(roi1[1][0], roi1[1][1])
plt.figure()

plt.subplot(211)
plt.plot(x_axis,spectrum_OFF_roi1, label="ROI1, Spectra OFF", marker='.')
plt.legend(loc="best")
plt.title(jf_file)
x_axis = np.arange(roi2[1][0], roi2[1][1])
plt.subplot(212)
plt.plot(x_axis,spectrum_OFF_roi2,label="ROI2, Spectra OFF",marker='.')
plt.legend(loc="best")
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-56e278a3aaee> in <module>()
#       6
#       7 plt.subplot(211)
# ----> 8 plt.plot(x_axis,spectrum_OFF_roi1, label="ROI1, Spectra OFF", marker='.')
#       9 plt.legend(loc="best")
#      10 plt.title(jf_file)
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1370         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1371
# -> 1372         for line in self._get_lines(*args, **kwargs):
#    1373             self.add_line(line)
#    1374             lines.append(line)
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     402                 this += args[0],
#     403                 args = args[1:]
# --> 404             for seg in self._plot_args(this, kwargs):
#     405                 yield seg
#     406
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     382             x, y = index_of(tup[-1])
#     383
# --> 384         x, y = self._xy_from_xy(x, y)
#     385
#     386         if self.command == 'plot':
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     241         if x.shape[0] != y.shape[0]:
#     242             raise ValueError("x and y must have same first dimension, but "
# --> 243                              "have shapes {} and {}".format(x.shape, y.shape))
#     244         if x.ndim > 2 or y.ndim > 2:
#     245             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (200,) and (1,)

# %%
# # # This is for plotting laser on-off spectra from Roi1 to look for pump-probe

bin_ = 1   # change the bin size if wanted, 1 is every pixel

spectra_on = spectrum_ON_roi1.copy()
spectra_off = spectrum_OFF_roi1.copy()

x_axis = np.arange(roi1[1][0], roi1[1][1])

spectra_on_rebin1 = rebin_sum(spectra_on)
spectra_off_rebin1 = rebin_sum(spectra_off)
x_axis_rebin1 = rebin_mean(x_axis)

spectra_on_err1=np.sqrt(spectra_on_rebin1)
spectra_off_err1=np.sqrt(spectra_off_rebin1)

plt.figure()
plt.subplot(211)
plt.plot(x_axis_rebin1,spectra_on_rebin1, label="ON",marker='.')
plt.plot(x_axis_rebin1,spectra_off_rebin1, label="OFF",marker='.')
plt.legend(loc="best")
plt.title(jf_file)

low_err= (spectra_on_rebin1 - spectra_off_rebin1)-np.sqrt(spectra_on_err1**2+spectra_off_err1**2)
high_err= (spectra_on_rebin1 - spectra_off_rebin1)+np.sqrt(spectra_on_err1**2+spectra_off_err1**2)
#x_axis_rebin1,
plt.subplot(212)
plt.plot(spectra_on_rebin1 - spectra_off_rebin1, label="ON - OFF",marker='.')
plt.legend(loc="best")
#plt.fill_between(x_axis_rebin1, low_err, high_err, color='lightblue')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# # # This is for plotting laser on-off spectra from Roi2 to look for pump-probe

bin_ = 2     # change the bin size if wanted, 1 is every pixel

spectra_on = spectrum_ON_roi2.copy()
spectra_off = spectrum_OFF_roi2.copy()

x_axis = np.arange(roi2[1][0], roi2[1][1])

spectra_on_rebin2 = rebin_sum(spectra_on)
spectra_off_rebin2 = rebin_sum(spectra_off)
x_axis_rebin2 = rebin_mean(x_axis)

spectra_on_err2=np.sqrt(spectra_on_rebin2)
spectra_off_err2=np.sqrt(spectra_off_rebin2)
plt.figure()
plt.subplot(211)
plt.plot(x_axis_rebin2,spectra_on_rebin2, label="ON",marker='.')
plt.plot(x_axis_rebin2,spectra_off_rebin2, label="OFF",marker='.')
plt.legend(loc="best")
plt.title(jf_file)

low_err= (spectra_on_rebin2 - spectra_off_rebin2)-np.sqrt(spectra_on_err2**2+spectra_off_err2**2)
high_err= (spectra_on_rebin2 - spectra_off_rebin2)+np.sqrt(spectra_on_err2**2+spectra_off_err2**2)

plt.subplot(212)
plt.plot(x_axis_rebin2,spectra_on_rebin2 - spectra_off_rebin2, label="ON - OFF",marker='.')
plt.legend(loc="best")
plt.fill_between(x_axis_rebin2, low_err, high_err, color='lightblue')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# # The next cell is for looping over several files of a scan.

# %%
scan_name ="FeBpy_monoscan_350nm_5uJ_1ps_001"          # you need to change only this name

######################################################################################
start_time = time.time()
intermediate_time = time.time()
json_file = DIR_json + scan_name + "_scan_info.json"
print (json_file)

with open(json_file) as file:
    data = json.load(file)
numFiles = len(data['scan_files'])
#numFiles = 1
looptime0 = time.time()
print ("Processing",numFiles,"files")

threshold = 2
photon_range = (1, 3)

Energy_eV = []
Delay_mm = []
XAS_trans_roi1 = []
Error_XAS_roi1 = []
XAS_trans_roi2 = []
Error_XAS_roi2 = []
RIXS_transient_roi1 = []
RIXS_transient_roi2 = []
Error_transient_roi1 = []
Error_transient_roi2 = []
RIXS_unpumped_roi1 = []
RIXS_unpumped_roi2 = []
Error_unpumped_roi1 = []
Error_unpumped_roi2 = []
RIXS_pumped_roi1 = []
RIXS_pumped_roi2 = []
Error_pumped_roi1 = []
Error_pumped_roi2 = []

for i in range(0,numFiles):
    print("step",i+1,"of",numFiles,": Processing %s" % (str(data['scan_files'][i][1])))
    
    spectrum_ON_roi1 = 0
    spectrum_OFF_roi1 = 0
    spectrum_ON_roi2 = 0
    spectrum_OFF_roi2 = 0

    (delay_loop, energy_loop, Izero_pump, Izero_unpump) = LoadData_BS(str(data['scan_files'][i][0]))    
    looptime1 = time.time() - looptime0
    print("t1 = " + str(looptime1) + "  time after load data BS ")
    
    energy_loop = [x for x in energy_loop if (x > 0)]     #This is to prevent that some occasional zeros screw up the mean value calculated below
    delay_loop = [x for x in delay_loop if (x > 0)]       #This is to prevent that some occasional zeros screw up the mean value calculated below
    Delay_mm.append(np.mean(delay_loop))
    Energy_eV.append(np.mean(energy_loop))
    
    meanI0pump = np.median(Izero_pump)
    sigmaI0pump = np.std(Izero_pump)
    meanI0unpump = np.median(Izero_unpump)
    sigmaI0unpump = np.std(Izero_unpump) 
    
    (image_ON_single_roi1,image_OFF_single_roi1,image_ON_single_roi2,image_OFF_single_roi2) = LoadData_JF(str(data['scan_files'][i][1]))
    looptime2 = time.time() - looptime0
    print("t2 = " + str(looptime2)+ "  time after load data JF")  
    
    nframes_ON = np.ma.size(image_ON_single_roi1,0)
    nframes_OFF = np.ma.size(image_OFF_single_roi1,0)
    print (nframes_ON, nframes_OFF)
    
    for j in range(nframes_ON):
        image_ON_2D_roi1 = image_ON_single_roi1[j,:,:]
        image_ON_2D_roi1= ju.apply_gain_pede(image_ON_2D_roi1, G=G_r_roi1, P=P_r_roi1, pixel_mask=mask_r_roi1, highgain=False) 
        image_ON_2D_roi1[image_ON_2D_roi1 < threshold_low] = 0
        image_ON_2D_roi1[image_ON_2D_roi1 > threshold_high] = 0
#         image_ON_2D_roi1 = convert_to_photon_num_range(image_ON_2D_roi1)
        if Izero_pump[j] != 0.: #I0 correction
            spectrum_ON_roi1 += image_ON_2D_roi1.sum(axis=0)/Izero_pump[j]
        
        image_OFF_2D_roi1 = image_OFF_single_roi1[j,:,:]
        image_OFF_2D_roi1= ju.apply_gain_pede(image_OFF_2D_roi1, G=G_r_roi1, P=P_r_roi1, pixel_mask=mask_r_roi1, highgain=False)
        image_OFF_2D_roi1[image_OFF_2D_roi1 < threshold_low] = 0
        image_OFF_2D_roi1[image_OFF_2D_roi1 > threshold_high] = 0
#         image_OFF_2D_roi1 = convert_to_photon_num_range(image_OFF_2D_roi1)
        if Izero_unpump[j] != 0.: #I0 correction
            spectrum_OFF_roi1 += image_OFF_2D_roi1.sum(axis=0)/Izero_unpump[j]
        
        image_ON_2D_roi2 = image_ON_single_roi2[j,:,:]
        image_ON_2D_roi2= ju.apply_gain_pede(image_ON_2D_roi2, G=G_r_roi2, P=P_r_roi2, pixel_mask=mask_r_roi2, highgain=False)
        image_ON_2D_roi2[image_ON_2D_roi2 < threshold_low] = 0
        image_ON_2D_roi2[image_ON_2D_roi2 > threshold_high] = 0
#         image_ON_2D_roi2 = convert_to_photon_num_range(image_ON_2D_roi2)
        if Izero_pump[j] != 0.: #I0 correction
            spectrum_ON_roi2 += image_ON_2D_roi2.sum(axis=0)/Izero_pump[j]
        
        image_OFF_2D_roi2 = image_OFF_single_roi2[j,:,:]
        image_OFF_2D_roi2= ju.apply_gain_pede(image_OFF_2D_roi2, G=G_r_roi2, P=P_r_roi2, pixel_mask=mask_r_roi2, highgain=False)
        image_OFF_2D_roi2[image_OFF_2D_roi2 < threshold_low] = 0
        image_OFF_2D_roi2[image_OFF_2D_roi2 > threshold_high] = 0
#         image_OFF_2D_roi2 = convert_to_photon_num_range(image_OFF_2D_roi2)
        if Izero_unpump[j] != 0.: #I0 correction
            spectrum_OFF_roi2 += image_OFF_2D_roi2.sum(axis=0)/Izero_unpump[j]
    
    #difference_roi1 = spectrum_ON_roi1.sum() - spectrum_OFF_roi1.sum()

    # we do a baseline substraction, then difference btw spectrum ON and OFF
    # and finally we sum the abs of the difference over a ROI in energy to avoid accumulating abs(noise)
    spectrum_ON_roi1_baseline = spectrum_ON_roi1 - spectrum_ON_roi1[0:5:1].mean()
    spectrum_OFF_roi1_baseline = spectrum_OFF_roi1- spectrum_OFF_roi1[0:5:1].mean()
    difference_roi1 = (spectrum_ON_roi1_baseline - spectrum_OFF_roi1_baseline)
    difference_roi1 = np.abs(difference_roi1)[70:95:1].sum()
    
    XAS_trans_roi1.append(difference_roi1)
    error_ON_roi1 = np.sum(np.sqrt(spectrum_ON_roi1))
    error_OFF_roi1 = np.sum(np.sqrt(spectrum_OFF_roi1))
    

    Error_XAS_roi1.append(np.sqrt(error_ON_roi1**2 + error_OFF_roi1**2))
    RIXS_unpumped_roi1.append(spectrum_OFF_roi1)
    Error_unpumped_roi1.append(np.sqrt(spectrum_OFF_roi1))
    RIXS_pumped_roi1.append(spectrum_ON_roi1)
    Error_pumped_roi1.append(np.sqrt(spectrum_ON_roi1))
    RIXS_transient_roi1.append(spectrum_ON_roi1 - spectrum_OFF_roi1)
    Error_transient_roi1.append(np.sqrt(np.sqrt(spectrum_ON_roi1)**2 + np.sqrt(spectrum_OFF_roi1)**2))
    
    difference_roi2 = spectrum_ON_roi2.sum() - spectrum_OFF_roi2.sum()
    XAS_trans_roi2.append(difference_roi2)
    error_ON_roi2 = np.sum(np.sqrt(spectrum_ON_roi2))
    error_OFF_roi2 = np.sum(np.sqrt(spectrum_OFF_roi2))
    
    Error_XAS_roi2.append(np.sqrt(error_ON_roi2**2 + error_OFF_roi2**2))
    RIXS_unpumped_roi2.append(spectrum_OFF_roi2)
    Error_unpumped_roi2.append(np.sqrt(spectrum_OFF_roi2))
    RIXS_pumped_roi2.append(spectrum_ON_roi2)
    Error_pumped_roi2.append(np.sqrt(spectrum_ON_roi2))
    RIXS_transient_roi2.append(difference_roi2)
    Error_transient_roi2.append(np.sqrt(np.sqrt(spectrum_ON_roi2)**2 + np.sqrt(spectrum_OFF_roi2)**2))
    
    print ("It took",round((time.time() - intermediate_time),2),"s to process this file")
    intermediate_time = time.time()
    
Energy_eV = np.array(Energy_eV)
Delay_mm = np.array(Delay_mm)

XAS_trans_roi1 = np.array(XAS_trans_roi1)
Error_XAS_roi1 = np.array(Error_XAS_roi1)
RIXS_unpumped_roi1 = np.array(RIXS_unpumped_roi1)
Error_unpumped_roi1 = np.array(Error_unpumped_roi1)
RIXS_pumped_roi1 = np.array(RIXS_pumped_roi1)
Error_pumped_roi1 = np.array(Error_pumped_roi1)
RIXS_transient_roi1 = np.array(RIXS_transient_roi1)
Error_transient_roi1 = np.array(Error_transient_roi1)

XAS_trans_roi2 = np.array(XAS_trans_roi2)
Error_XAS_roi2 = np.array(Error_XAS_roi2)
RIXS_unpumped_roi2 = np.array(RIXS_unpumped_roi2)
Error_unpumped_roi2 = np.array(Error_unpumped_roi2)
RIXS_pumped_roi2 = np.array(RIXS_pumped_roi2)
Error_pumped_roi2 = np.array(Error_pumped_roi2)
RIXS_transient_roi2 = np.array(RIXS_transient_roi2)
Error_transient_roi2 = np.array(Error_transient_roi2)

print ("Job done! It took",round((time.time() - start_time),2),"seconds to process",numFiles,"file(s)")
# Out:
# /sf/alvra/data/p17803/res/scan_info/FeBpy_monoscan_350nm_5uJ_1ps_001_scan_info.json
# Processing 26 files
# step 1 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0000.JF02T09V01.h5
# t1 = 0.4250609874725342  time after load data BS
# t2 = 52.30657076835632  time after load data JF
# 1000 1000
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/ipykernel/__main__.py:126: RuntimeWarning: invalid value encountered in sqrt
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/ipykernel/__main__.py:130: RuntimeWarning: invalid value encountered in sqrt
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/ipykernel/__main__.py:134: RuntimeWarning: invalid value encountered in sqrt
# It took 52.83 s to process this file
# step 2 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0001.JF02T09V01.h5
# t1 = 52.96298789978027  time after load data BS
# t2 = 90.45349955558777  time after load data JF
# 1000 1000
# It took 38.14 s to process this file
# step 3 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0002.JF02T09V01.h5
# t1 = 91.11364078521729  time after load data BS
# t2 = 130.9174063205719  time after load data JF
# 1000 1000
# It took 40.47 s to process this file
# step 4 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0003.JF02T09V01.h5
# t1 = 131.74063277244568  time after load data BS
# t2 = 199.45753073692322  time after load data JF
# 1000 1000
# It took 68.53 s to process this file
# step 5 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0004.JF02T09V01.h5
# t1 = 200.40524983406067  time after load data BS
# t2 = 237.94935512542725  time after load data JF
# 1000 1000
# It took 38.49 s to process this file
# step 6 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0005.JF02T09V01.h5
# t1 = 238.67515993118286  time after load data BS
# t2 = 277.46920680999756  time after load data JF
# 1000 1000
# It took 39.52 s to process this file
# step 7 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0006.JF02T09V01.h5
# t1 = 278.1990191936493  time after load data BS
# t2 = 327.22396206855774  time after load data JF
# 1000 1000
# It took 49.84 s to process this file
# step 8 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0007.JF02T09V01.h5
# t1 = 328.2402229309082  time after load data BS
# t2 = 386.6114857196808  time after load data JF
# 1000 1000
# It took 59.3 s to process this file
# step 9 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0008.JF02T09V01.h5
# t1 = 387.2542655467987  time after load data BS
# t2 = 426.58135509490967  time after load data JF
# 1000 1000
# It took 39.97 s to process this file
# step 10 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0009.JF02T09V01.h5
# t1 = 427.4640827178955  time after load data BS
# t2 = 470.1556496620178  time after load data JF
# 1000 1000
# It took 43.57 s to process this file
# step 11 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0010.JF02T09V01.h5
# t1 = 471.04007029533386  time after load data BS
# t2 = 541.2712790966034  time after load data JF
# 1000 1000
# It took 71.12 s to process this file
# step 12 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0011.JF02T09V01.h5
# t1 = 542.0139238834381  time after load data BS
# t2 = 582.3011109828949  time after load data JF
# 1000 1000
# It took 41.03 s to process this file
# step 13 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0012.JF02T09V01.h5
# t1 = 582.9760248661041  time after load data BS
# t2 = 623.62926197052  time after load data JF
# 1000 1000
# It took 41.35 s to process this file
# step 14 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0013.JF02T09V01.h5
# t1 = 624.4781007766724  time after load data BS
# t2 = 676.9509918689728  time after load data JF
# 1000 1000
# It took 53.3 s to process this file
# step 15 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0014.JF02T09V01.h5
# t1 = 678.0584921836853  time after load data BS
# t2 = 730.1857478618622  time after load data JF
# 1000 1000
# It took 53.24 s to process this file
# step 16 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0015.JF02T09V01.h5
# t1 = 730.8599326610565  time after load data BS
# t2 = 769.8206577301025  time after load data JF
# 1000 1000
# It took 39.62 s to process this file
# step 17 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0016.JF02T09V01.h5
# t1 = 770.7822093963623  time after load data BS
# t2 = 815.1548862457275  time after load data JF
# 1000 1000
# It took 45.34 s to process this file
# step 18 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0017.JF02T09V01.h5
# t1 = 815.8565034866333  time after load data BS
# t2 = 875.3275933265686  time after load data JF
# 1000 1000
# It took 60.18 s to process this file
# step 19 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0018.JF02T09V01.h5
# t1 = 876.1172995567322  time after load data BS
# t2 = 917.7785305976868  time after load data JF
# 1000 1000
# It took 42.48 s to process this file
# step 20 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0019.JF02T09V01.h5
# t1 = 918.8119671344757  time after load data BS
# t2 = 963.7728128433228  time after load data JF
# 1000 1000
# It took 46.09 s to process this file
# step 21 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0020.JF02T09V01.h5
# t1 = 964.5301201343536  time after load data BS
# t2 = 1026.6105077266693  time after load data JF
# 1000 1000
# It took 62.72 s to process this file
# step 22 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0021.JF02T09V01.h5
# t1 = 1027.4617466926575  time after load data BS
# t2 = 1067.9584786891937  time after load data JF
# 1000 1000
# It took 41.34 s to process this file
# step 23 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0022.JF02T09V01.h5
# t1 = 1068.8630657196045  time after load data BS
# t2 = 1113.9491958618164  time after load data JF
# 1000 1000
# It took 46.02 s to process this file
# step 24 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0023.JF02T09V01.h5
# t1 = 1114.8359713554382  time after load data BS
# t2 = 1169.1684708595276  time after load data JF
# 1000 1000
# It took 55.19 s to process this file
# step 25 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0024.JF02T09V01.h5
# t1 = 1170.367912054062  time after load data BS
# t2 = 1218.2780797481537  time after load data JF
# 1000 1000
# It took 49.12 s to process this file
# step 26 of 26 : Processing /sf/alvra/data/p17803/raw/scan_data/FeBpy_monoscan_350nm_5uJ_1ps_001/FeBpy_monoscan_350nm_5uJ_1ps_001_step0025.JF02T09V01.h5
# t1 = 1219.1728887557983  time after load data BS
# t2 = 1256.4231972694397  time after load data JF
# 1000 1000
# It took 38.15 s to process this file
# Job done! It took 1256.95 seconds to process 26 file(s)

# %%
error_high = XAS_trans_roi1 + Error_XAS_roi1
error_low = XAS_trans_roi1 - Error_XAS_roi1

plt.figure(figsize=(9,5))
plt.subplots_adjust(wspace=0.5)

plt.subplot(211)
plt.title("XAS")
#plt.plot(Energy_eV, XAS_trans_roi1,label="Energy scan",marker='.') #This is the meaningful plot if it is a monoscan
#plt.fill_between(np.squeeze(Energy_eV), error_low, error_high, color='lightblue')
plt.subplot(212)
plt.title("Delay scan")
plt.plot(Delay_mm[0:len(XAS_trans_roi1)], XAS_trans_roi1,label="Delay scan",marker='.') #This is the meaningful plot if it is a delay scan
#plt.fill_between(np.squeeze(Delay_mm), error_low, error_high, color='lightblue')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="899.2500000000001">

# %%
#test= gaussian_filter(RIXS_transient_roi1,10)
#print(RIXS_transient_roi1)

# %%
Delay_mm_14 = Delay_mm
XAS_trans_roi1_14 = XAS_trans_roi1
RIXS_unpumped_roi1_14 = RIXS_unpumped_roi1
RIXS_pumped_roi1_14 = RIXS_pumped_roi1
RIXS_transient_roi1_14 = RIXS_transient_roi1

# %%
plt.figure(figsize=(9,5))
plt.subplots_adjust(wspace=0.5)

plt.subplot(211)
plt.title("XAS")
#plt.plot(Energy_eV, XAS_trans_roi1,label="Energy scan",marker='.') #This is the meaningful plot if it is a monoscan
#plt.fill_between(np.squeeze(Energy_eV), error_low, error_high, color='lightblue')
plt.subplot(212)
plt.title("Delay scan")
plt.plot(Delay_mm_14[0:len(XAS_trans_roi1_14)], XAS_trans_roi1_14,label="Delay scan",marker='.') #This is the meaningful plot if it is a delay scan
#plt.fill_between(np.squeeze(Delay_mm), error_low, error_high, color='lightblue')
plt.show()
# Out:
# <div id='58e4cbfe-faff-4087-bdc6-bd50d02655a0'></div>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-27d1c9b4e459> in <module>()
#       8 plt.subplot(212)
#       9 plt.title("Delay scan")
# ---> 10 plt.plot(Delay_mm_14[0:len(XAS_trans_roi1_14)], XAS_trans_roi1_14,label="Delay scan",marker='.') #This is the meaningful plot if it is a delay scan
#      11 #plt.fill_between(np.squeeze(Delay_mm), error_low, error_high, color='lightblue')
#      12 plt.show()
#
# NameError: name 'Delay_mm_14' is not defined

# %%
#extent = [roi[1][0],roi[1][-1],roi[0][0],roi[0][-1]]

plt.figure(figsize=(5,9))
plt.subplots_adjust(hspace=0.5)

plt.subplot(311)
plt.imshow(RIXS_unpumped_roi1_14, aspect = 'auto', cmap = "bwr", origin ="lower")
plt.title("RIXS unpumped")
plt.colorbar()
plt.show()

plt.subplot(312)
plt.imshow(RIXS_pumped_roi1_14, aspect = 'auto', cmap = "bwr", origin ="lower")#, vmin=-250, vmax=250)
plt.title("RIXS pumped")
plt.colorbar()
plt.show()

plt.subplot(313)
plt.imshow(RIXS_transient_roi1_14, aspect = 'auto', cmap = "rainbow", origin ="lower", vmin=-0.01, vmax=0.008)
plt.title("RIXS transient")
plt.colorbar()
plt.show()

#fig.savefig('RIXS_unpumped')
# Out:
# <img src="data:image/png;base64,..." width="499.58333333333337">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6746feb59d94> in <module>()
#       5
#       6 plt.subplot(311)
# ----> 7 plt.imshow(RIXS_unpumped_roi1_14, aspect = 'auto', cmap = "bwr", origin ="lower")
#       8 plt.title("RIXS unpumped")
#       9 plt.colorbar()
#
# NameError: name 'RIXS_unpumped_roi1_14' is not defined

# %%
#### This is to save h5 data ####

savedir = "/das/work/p17/p17803/Processed_files/"

h5f = h5py.File(savedir + 'Scan_14_XES_CytCFe3','w') 
#h5f = h5py.File(savedir + 'timeScan_4.h5','w')     
#h5f = h5py.File(savedir + 'RIXS_144.h5','w')

h5f.create_dataset('Delay_mm', data = Delay_mm)
#h5f.create_dataset('Energy_BS', data = Energy_eV)
h5f.create_dataset('XAS_transient', data = XAS_trans_roi1)
#h5f.create_dataset('Err_XAS_transient', data = Error_XAS_roi1)
h5f.create_dataset('RIXS_unpumped', data = RIXS_unpumped_roi1)
#h5f.create_dataset('Err_RIXS_unpumped', data = Error_unpumped_roi1)
h5f.create_dataset('RIXS_pumped', data = RIXS_pumped_roi1)
h5f.create_dataset('RIXS_transient', data = RIXS_transient_roi1)
#h5f.create_dataset('Err_RIXS_transient', data = Error_transient_roi1)

h5f.close()

# %%
Loaddir  = "/das/work/p17/p17803/Processed_files/"
h5f = h5py.File(Loaddir + 'Scan_10_XES_CytCFe3','r')
h5f.  create_dataset('Delay_mm', data = Delay_mm)

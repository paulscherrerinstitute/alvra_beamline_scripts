# %%
# %matplotlib nbagg
import jungfrau_utils as ju
import numpy as np
import json
import h5py
import matplotlib.pyplot as plt
import scipy
from scipy.ndimage.filters import gaussian_filter
from scipy.special import erf
from scipy.optimize import curve_fit
import os
import time
# Out:
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Could not load libcorrections.

# %%
#Following lines are to define a couple of functions that will be used later.

def rebin_sum(a):
    if a.size%bin_ != 0:
        a = a[0:a.size//bin_ * bin_]

    return a.reshape((-1, bin_)).sum(axis=1)

def rebin_mean(a):
    if a.size%bin_ != 0:
        a = a[0:a.size//bin_ * bin_]

    return a.reshape((-1, bin_)).mean(axis=1)

# Convert energy to a number of photons counting values falling within a particular range.
# This will always return integer photon counts.
def convert_to_photon_num_range(image):
    return np.ceil(np.divide(image - photon_range[0], np.mean(photon_range)))

# Convert energy to a number of photons using the central energy of a single photon.
# This can return fractional number of photons.`
def convert_to_photon_num_mean(image):
    return image / np.mean(photon_range)

# %%
# Take the correct pedestal file (usually located in /sf/alvra/data/*pgroup*/res/JF_pedestals)
# Take the correct gains.h5 file (usually located in /sf/alvra/config/jungfrau/gainMaps/JF02T09V01/)

#pede_file = "/sf/alvra/data/res/p16581/pedestal_20180307_2303_res.h5"
pede_file = "/sf/alvra/data/p17803/res/JF_pedestals/pedestal_20190121_1514.JF02T09V01.res.h5"
#pede_file = "/sf/alvra/data/p17803/res/JF_pedestals/pedestal_20190124_2035.JF02T09V01.res.h5"
gain_file = "/sf/alvra/config/jungfrau/gainMaps/JF02T09V01/gains.h5"

with h5py.File(gain_file, "r") as file: 
    G = file["gains"][:]
    
with h5py.File(pede_file, "r") as file: 
    P = file["gains"][:]
    mask = file["pixel_mask"][:]
    
print("Dimensions of G: ", G.shape)

channel_JFimages = "data/JF02T09V01/data"
channel_pulse_idsJF = "data/JF02T09V01/pulse_id"

channel_delay = "data/SLAAR11-LMOT-M451:ENC_1_BS/data"              #Delay of pump-probe delay stage
channel_energy = "data/SLAAR11-LTIM01-EVR0:DUMMY_PV3_NBS/data"      #Mono energy in eV
channel_pulse_idsBS = "data/SLAAR11-LMOT-M451:ENC_1_BS/pulse_id"      #Pulse ids taken from pump-probe delay stage (100 Hz)

#channel_PIPS_trans = "data/SARES11-GES1:CH1_VAL_GET/data"           #X-ray TRANS diode to PRIME Keysight (channel 1)
#channel_PIPS_fluo = "data/SARES11-GES1:CH2_VAL_GET/data"            #X-ray FLUO diode to PRIME Keysight (channel 2)
channel_Izero = "data/SARES11-LSCP10-FNS:CH1:VAL_GET/data"          #Izero diode to PRIME Ioxos (channel 1)
#channel_Izero2 = "data/SARES11-LSCP10-FNS:CH0:VAL_GET/data"          #Izero diode to PRIME Ioxos (channel 0)
#channel_Izero3 = "data/SARES11-LSCP10-FNS:CH3:VAL_GET/data"          #Izero diode to PRIME Ioxos (channel 3)
#channel_Izero4 = "data/SARES11-LSCP10-FNS:CH2:VAL_GET/data"         #Izero diode to PRIME Ioxos (channel 2)
#channel_LaserDiode = "data/SLAAR11-LSCP1-FNS:CH0:VAL_GET/data"      #Laser diode to ESA Laser Ioxos 
#channel_Laser_refDiode = "data/SLAAR11-LSCP1-FNS:CH2:VAL_GET/data"  #Laser diode leaking from beampath, to ESA Laser Ioxos 
#channel_LAM_delaystage = "data/SLAAR11-LTIM01-EVR0:DUMMY_PV2_NBS/data"       #LAM internal stage position in mm
#channel_LAM_stepper = "data/SLAAR11-LTIM01-EVR0:DUMMY_PV10_NBS/data"         #LAM stepper motor (used for feedback)
#channel_PALM_eTOF = "data/SAROP11-PALMK118:CH2_BUFFER/data"                 #PALM eTof from Ch2
#channel_PALM_drift = "data/SAROP11-PALMK118:CH2_VAL_GET/data"               #PALM drift
# Out:
# Dimensions of G:  (4, 512, 9216)

# %%
def LoadData_JF(filename):
    with h5py.File(filename, 'r') as JF_file:
        pulse_ids = JF_file[channel_pulse_idsJF][:]
        pulse_ids = np.reshape(pulse_ids, (pulse_ids.size,))
        
        #reprate_FEL = ((pulse_ids%10 == 0) & (pulse_ids%20 != 0))              #This is for 10 Hz
        #reprate_laser = pulse_ids%20 == 0                                      #This is for 5 Hz
        reprate_FEL = ((pulse_ids%4 == 0) & (pulse_ids%8 != 0))                #This is for 25 Hz
        reprate_laser = pulse_ids%8 == 0                                       #This is for 12.5 Hz
        
        image_JF_ON = JF_file[channel_JFimages][:,:,:][reprate_laser]
        image_JF_OFF = JF_file[channel_JFimages][:,:,:][reprate_FEL]
        
        image_roi1_ON = image_JF_ON[:, roi1[0][0]:roi1[0][1], roi1[1][0]:roi1[1][1]]
        image_roi2_ON = image_JF_ON[:, roi2[0][0]:roi2[0][1], roi2[1][0]:roi2[1][1]]
        
        image_roi1_OFF = image_JF_OFF[:, roi1[0][0]:roi1[0][1], roi1[1][0]:roi1[1][1]]
        image_roi2_OFF = image_JF_OFF[:, roi2[0][0]:roi2[0][1], roi2[1][0]:roi2[1][1]]
        
    return image_roi1_ON, image_roi1_OFF, image_roi2_ON, image_roi2_OFF

def LoadData_BS(filename):
    with h5py.File(filename, 'r') as BS_file:
        pulse_ids = BS_file[channel_pulse_idsBS][:]
        pulse_ids = np.reshape(pulse_ids, (pulse_ids.size,))
        
        #reprate_FEL = ((pulse_ids%10 == 0) & (pulse_ids%20 != 0))              #This is for 10 Hz
        #reprate_laser = pulse_ids%20 == 0                                      #This is for 5 Hz
        reprate_FEL = ((pulse_ids%4 == 0) & (pulse_ids%8 != 0))                #This is for 25 Hz
        reprate_laser = pulse_ids%8 == 0                                       #This is for 12.5 Hz
        
        Izero_pump = BS_file[channel_Izero][:][reprate_laser]
        Izero_unpump = BS_file[channel_Izero][:][reprate_FEL]      
        
        delay = BS_file[channel_delay][:][reprate_FEL]
        energy = BS_file[channel_energy][:][reprate_FEL]
        
    return delay, energy, Izero_pump, Izero_unpump

def errfunc(x, a, b, c, d):
    return a + b*erf((c-x)*np.sqrt(np.log(2))/(np.abs(d)))

# %%
DIR = "/sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/"
#DIR = "/sf/alvra/data/p17803/raw/"

DIR_json = "/sf/alvra/data/p17803/res/scan_info/"

# !ls -lah -t /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/
#!ls -lah -t /sf/alvra/data/p17803/raw/


# !hostname

listfile = os.listdir(DIR)
number_files = len(listfile)
print ("There are",number_files,"files in the folder", DIR)
# Out:
# total 3.6T
# drwxrwsr-x. 159 17803 p17803  32K Jan 31 22:55 ..
# drwxrwsr-x.   2 17803 p17803  32K Jan 26 09:13 .
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 09:13 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0049.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 09:10 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0049.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 09:10 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0049.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 09:08 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0048.BSREAD.h5
# -rw-r--r--.   1 root  p17803  34M Jan 26 09:05 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0048.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 09:04 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0048.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 09:02 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0047.BSREAD.h5
# -rw-r--r--.   1 root  p17803  34M Jan 26 08:59 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0047.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 08:59 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0047.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 08:57 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0046.BSREAD.h5
# -rw-r--r--.   1 root  p17803  34M Jan 26 08:54 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0046.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 08:53 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0046.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 08:51 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0045.BSREAD.h5
# -rw-r--r--.   1 root  p17803  34M Jan 26 08:48 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0045.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 08:48 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0045.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 08:46 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0044.BSREAD.h5
# -rw-r--r--.   1 root  p17803  34M Jan 26 08:43 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0044.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 08:43 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0044.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 08:35 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0043.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 08:32 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0043.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 08:32 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0043.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 08:29 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0042.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 08:27 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0042.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 08:26 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0042.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 08:24 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0041.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 08:21 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0041.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 08:21 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0041.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 08:18 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0040.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 08:16 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0040.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 08:15 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0040.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 08:13 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0039.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 08:10 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0039.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 08:10 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0039.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 08:07 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0038.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 08:05 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0038.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 08:04 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0038.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 08:02 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0037.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 07:59 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0037.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 07:59 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0037.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 07:56 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0036.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 07:54 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0036.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 07:53 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0036.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 07:51 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0035.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 07:48 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0035.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 07:48 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0035.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 07:45 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0034.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 07:43 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0034.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 07:42 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0034.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 07:40 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0033.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 07:37 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0033.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 07:37 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0033.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 07:34 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0032.BSREAD.h5
# -rw-r--r--.   1 root  p17803  29M Jan 26 07:32 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0032.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 07:31 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0032.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 07:29 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0031.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 07:26 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0031.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 07:26 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0031.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 07:18 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0030.BSREAD.h5
# -rw-r--r--.   1 root  p17803  30M Jan 26 07:15 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0030.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 07:15 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0030.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 07:13 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0029.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 07:10 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0029.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 07:09 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0029.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 07:07 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0028.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 07:04 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0028.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 07:04 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0028.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 07:02 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0027.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 06:59 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0027.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 06:58 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0027.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 06:56 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0026.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 06:53 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0026.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 06:53 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0026.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 06:51 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0025.BSREAD.h5
# -rw-r--r--.   1 root  p17803  30M Jan 26 06:48 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0025.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 06:47 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0025.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 06:45 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0024.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 06:42 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0024.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 06:42 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0024.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 06:40 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0023.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 06:37 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0023.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 06:36 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0023.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 06:34 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0022.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 06:31 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0022.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 06:31 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0022.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 06:29 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0021.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 06:26 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0021.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 06:25 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0021.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 06:23 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0020.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 06:21 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0020.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 06:20 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0020.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 06:18 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0019.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 06:15 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0019.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 06:15 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0019.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 06:12 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0018.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 06:10 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0018.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 06:09 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0018.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 06:07 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0017.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 06:04 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0017.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 06:04 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0017.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 05:56 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0016.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 05:53 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0016.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 05:53 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0016.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 05:51 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0015.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 05:48 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0015.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 05:47 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0015.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 05:45 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0014.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 05:42 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0014.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 05:42 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0014.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 05:40 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0013.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 05:37 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0013.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 05:36 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0013.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 05:29 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0012.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 05:26 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0012.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 05:25 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0012.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 05:23 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0011.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 05:20 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0011.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 05:20 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0011.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 05:18 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0010.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 05:15 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0010.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 05:15 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0010.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 05:12 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0009.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 05:10 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0009.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 05:09 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0009.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 05:07 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0008.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 05:04 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0008.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 05:04 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0008.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 05:01 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0007.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 04:59 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0007.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 04:58 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0007.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 04:56 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0006.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 04:53 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0006.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 04:53 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0006.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 04:50 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0005.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 04:48 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0005.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 04:47 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0005.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 04:45 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0004.BSREAD.h5
# -rw-r--r--.   1 root  p17803  33M Jan 26 04:42 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0004.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 04:42 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0004.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 04:28 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0003.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 04:25 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0003.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 04:25 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0003.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 04:22 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0002.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 04:20 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0002.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 04:19 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0002.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 04:17 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0001.BSREAD.h5
# -rw-r--r--.   1 root  p17803  31M Jan 26 04:14 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0001.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 04:14 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0001.JF02T09V01.h5
# -rw-r--r--.   1 root  p17803 3.3G Jan 26 04:11 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0000.BSREAD.h5
# -rw-r--r--.   1 root  p17803  32M Jan 26 04:09 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0000.BSREAD_CA.h5
# -rw-r--r--.   1 17803 p17803  71G Jan 26 04:08 CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0000.JF02T09V01.h5
# ra-c-004.psi.ch
# There are 150 files in the folder /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/

# %%
# First we load the first images of a file to check if everything is fine with the pedestal & gain files (check highgain True or False)
# We can see also how the ROIs look like (will be useful later)

fileName = "CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_011_step0025.JF02T09V01.h5"
#fileName = "CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0015.JF02T09V01.h5"

jf_file = h5py.File(DIR + fileName)

print(jf_file)

images = jf_file[channel_JFimages]
pulse_ids = jf_file[channel_pulse_idsJF]
print (images.shape)

nframes = 100

#nframes=images.shape(0)

total = 0
threshold_low = 3
threshold_high = 7

#roi = [[225, 325], [6950, 7075]]
#roi = [[225, 325], [7900, 8450]]
roi = [[0, images.shape[1]], [0, images.shape[2]]]

for i in range(nframes):
    image = images[i][:]
    total += ju.apply_gain_pede(image, G=G, P=P, pixel_mask=mask, highgain=False)[roi[0][0]:roi[0][1], roi[1][0]:roi[1][1]]

total /= nframes


plt.figure()
plt.imshow(total, origin="lower", extent = [roi[1][0],roi[1][-1],roi[0][0],roi[0][-1]], aspect='auto', vmin=0, vmax=0.4)
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     118         try:
# --> 119             fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#     120         except IOError:
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = '/sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_011_step0025.JF02T09V01.h5', errno = 2, error message = 'No such file or directory', flags = 1, o_flags = 2)
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     121             try:
# --> 122                 fid = h5f.open(name, h5f.ACC_RDONLY, fapl=fapl)
#     123             except IOError:
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = '/sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_011_step0025.JF02T09V01.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-4c479b2378af> in <module>()
#       5 #fileName = "CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0015.JF02T09V01.h5"
#       6
# ----> 7 jf_file = h5py.File(DIR + fileName)
#       8
#       9 print(jf_file)
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     267             with phil:
#     268                 fapl = make_fapl(driver, libver, **kwds)
# --> 269                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     270
#     271                 if swmr_support:
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     122                 fid = h5f.open(name, h5f.ACC_RDONLY, fapl=fapl)
#     123             except IOError:
# --> 124                 fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     125     else:
#     126         raise ValueError("Invalid mode; must be one of r, r+, w, w-, x, a")
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.create()
#
# OSError: Unable to create file (unable to open file: name = '/sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_011_step0025.JF02T09V01.h5', errno = 30, error message = 'Read-only file system', flags = 15, o_flags = c2)

# %%
totalImage = total * nframes
background = totalImage.sum(axis = 0)
plt.figure()

plt.plot(background, label="Full", marker='.')
plt.ylim((-100000,100000))
plt.legend(loc="best")
plt.title(jf_file)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'<HDF5 file "CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_011_step0025.JF02T09V01.h5" (mode r)>')

# %% [markdown]
# # Set the ROIs (roi1 & roi2 in pixels) in the next cell

# %%
# Ka emission 
roi1 = [[200, 300], [6900, 7100]] # change these numbers, here they are for both crystals1 (up & down) overlapped
#roi1 = [[7030, 7130], [220, 290]]
# Kb emission 
roi2 = [[200, 300], [8300, 8450]] # change these numbers, here they are for both crystals2 (up & down) overlapped

##################################################################

P_r_roi2 = P[:, roi2[0][0]:roi2[0][1], roi2[1][0]:roi2[1][1]]
G_r_roi2 = G[:, roi2[0][0]:roi2[0][1], roi2[1][0]:roi2[1][1]]
mask_r_roi2 = mask[roi2[0][0]:roi2[0][1], roi2[1][0]:roi2[1][1]]

P_r_roi1 = P[:, roi1[0][0]:roi1[0][1], roi1[1][0]:roi1[1][1]]
G_r_roi1 = G[:, roi1[0][0]:roi1[0][1], roi1[1][0]:roi1[1][1]]
mask_r_roi1 = mask[roi1[0][0]:roi1[0][1], roi1[1][0]:roi1[1][1]]

# %%
mask_r_roi1.shape
# Out:
# (100, 200)

# %% [markdown]
# # The next cell is to analyse a single file within a files of a scan

# %%
#files = ["Kalpha_Fe_foil_8keV_0.1trans_3"]          # you need to change only this name
#files = ["CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0019","CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0020","CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0022","CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0023"]

scan_name = "CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_011"
file_name = "CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_011_step0020"
step_number = 55

######################################################################################
start_time = time.time()
spectrum_ON_roi1 = 0
spectrum_OFF_roi1 = 0
spectrum_ON_roi2 = 0
spectrum_OFF_roi2 = 0

json_file = DIR_json + scan_name + "_scan_info.json"
print (json_file)

with open(json_file) as file:
    data = json.load(file)
numFiles = len(data['scan_files'])
numFiles = 1
print ("Processing",numFiles,"files")

JF_single_file = DIR + file_name + ".JF02T09V01.h5"
BS_single_file = DIR + file_name + ".BSREAD.h5"

print("Processing file %s" % (JF_single_file))

(image_roi1_ON,image_roi1_OFF,image_roi2_ON,image_roi2_OFF) = LoadData_JF(str(data['scan_files'][step_number][1]))
(Delay_mm,Energy_eV,Izero_pump,Izero_unpump) = LoadData_BS(str(data['scaXESn_files'][step_number][0]))

meanI0pump = np.median(Izero_pump)
sigmaI0pump = np.std(Izero_pump)
meanI0unpump = np.median(Izero_unpump)
sigmaI0unpump = np.std(Izero_unpump) 

nframes_ON = np.ma.size(image_roi1_ON,0)
nframes_OFF = np.ma.size(image_roi1_OFF,0)
print (nframes_ON, nframes_OFF)
threshold = 2
threshold_low = 3 
threshold_high = 8
photon_range = (6, 7)

for j in range(nframes_ON):
        image_ON_2D_roi1 = image_roi1_ON[j,:,:]
        image_ON_2D_roi1= ju.apply_gain_pede(image_ON_2D_roi1, G=G_r_roi1, P=P_r_roi1, pixel_mask=mask_r_roi1, highgain=False)
        image_ON_2D_roi1[image_ON_2D_roi1 < threshold_low] = 0
        image_ON_2D_roi1[image_ON_2D_roi1 > threshold_high] = 0
#         image_ON_2D_roi1 = convert_to_photon_num_range(image_ON_2D_roi1)
        #if Izero_pump[j]>(meanI0pump-1.2*sigmaI0pump) and Izero_pump[j]<(meanI0pump+1.2*sigmaI0pump):
        spectrum_ON_roi1 += image_ON_2D_roi1.sum(axis=0)#/Izero_pump[j]
        
        image_OFF_2D_roi1 = image_roi1_OFF[j,:,:]
        image_OFF_2D_roi1= ju.apply_gain_pede(image_OFF_2D_roi1, G=G_r_roi1, P=P_r_roi1, pixel_mask=mask_r_roi1, highgain=False)
        image_OFF_2D_roi1[image_OFF_2D_roi1 < threshold_low] = 0
        image_OFF_2D_roi1[image_OFF_2D_roi1 > threshold_high] = 0
#         image_OFF_2D_roi1 = convert_to_photon_num_range(image_OFF_2D_roi1)
        #if Izero_unpump[j]>(meanI0unpump-1.2*sigmaI0unpump) and Izero_unpump[j]<(meanI0unpump+1.2*sigmaI0unpump):
        spectrum_OFF_roi1 += image_OFF_2D_roi1.sum(axis=0)#/Izero_unpump[j]
        
        image_ON_2D_roi2 = image_roi2_ON[j,:,:]
        image_ON_2D_roi2= ju.apply_gain_pede(image_ON_2D_roi2, G=G_r_roi2, P=P_r_roi2, pixel_mask=mask_r_roi2, highgain=False)
        image_ON_2D_roi2[image_ON_2D_roi2 < threshold_low] = 0
        image_ON_2D_roi2[image_ON_2D_roi2 > threshold_high] = 0
#         image_ON_2D_roi2 = convert_to_photon_num_range(image_ON_2D_roi2)
        #if Izero_pump[j]>(meanI0pump-1.2*sigmaI0pump) and Izero_pump[j]<(meanI0pump+1.2*sigmaI0pump):
        spectrum_ON_roi2 += image_ON_2D_roi2.sum(axis=0)#/Izero_pump[j]
        
        image_OFF_2D_roi2 = image_roi2_OFF[j,:,:]
        image_OFF_2D_roi2= ju.apply_gain_pede(image_OFF_2D_roi2, G=G_r_roi2, P=P_r_roi2, pixel_mask=mask_r_roi2, highgain=False)
        image_OFF_2D_roi2[image_OFF_2D_roi2 < threshold_low] = 0
        image_OFF_2D_roi2[image_OFF_2D_roi2 > threshold_high] = 0
#         image_OFF_2D_roi2 = convert_to_photon_num_range(image_OFF_2D_roi2)
        #if Izero_unpump[j]>(meanI0unpump-1.2*sigmaI0unpump) and Izero_unpump[j]<(meanI0unpump+1.2*sigmaI0unpump):
        spectrum_OFF_roi2 += image_OFF_2D_roi2.sum(axis=0)#/Izero_unpump[j]
        
print ("Job done! It took",round((time.time() - start_time),2),"seconds to process the file")
# Out:
# /sf/alvra/data/p17803/res/scan_info/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_011_scan_info.json
# Processing 1 files
# Processing file /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_011/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_011_step0020.JF02T09V01.h5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-b7c8262f596d> in <module>()
#      27 print("Processing file %s" % (JF_single_file))
#      28
# ---> 29 (image_roi1_ON,image_roi1_OFF,image_roi2_ON,image_roi2_OFF) = LoadData_JF(str(data['scan_files'][step_number][1]))
#      30 (Delay_mm,Energy_eV,Izero_pump,Izero_unpump) = LoadData_BS(str(data['scaXESn_files'][step_number][0]))
#      31
#
# IndexError: list index out of range

# %% [markdown]
# # The next cell is to analyse a single file or a series of identical ones to be summed up

# %%
#files = ["Kalpha_Fe_foil_8keV_0.1trans_3"]          # you need to change only this name
#files = ["CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0019","CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0020","CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0022","CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0023"]

files = ["CytC_Fe3_monoscan_350nm_5uJ_500fs_004_step0019"]
######################################################################################
start_time = time.time()
spectrum_ON_roi1 = 0
spectrum_OFF_roi1 = 0
spectrum_ON_roi2 = 0
spectrum_OFF_roi2 = 0
        
for f in files:
    
    JF_single_file = DIR + f + ".JF02T09V01.h5"
    BS_single_file = DIR + f + ".BSREAD.h5"
    print("Processing file %s" % (JF_single_file))
    
    (image_roi1_ON,image_roi1_OFF,image_roi2_ON,image_roi2_OFF,pulse_ids) = LoadData_JF(str(JF_single_file))
    (Delay_mm,Energy_eV,Izero_pump,Izero_unpump) = LoadData_BS(str(BS_single_file))
    
    meanI0pump = np.median(Izero_pump)
    sigmaI0pump = np.std(Izero_pump)
    meanI0unpump = np.median(Izero_unpump)
    sigmaI0unpump = np.std(Izero_unpump) 
    
    nframes_ON = np.ma.size(image_roi1_ON,0)
    nframes_OFF = np.ma.size(image_roi1_OFF,0)
    print (nframes_ON, nframes_OFF)
    threshold = 2
    threshold_low = 3 
    threshold_high = 7
    #photon_range = (6, 7)
    
    for j in range(nframes_ON):
        image_ON_2D_roi1 = image_roi1_ON[j,:,:]
        image_ON_2D_roi1= ju.apply_gain_pede(image_ON_2D_roi1, G=G_r_roi1, P=P_r_roi1, pixel_mask=mask_r_roi1, highgain=False)
        image_ON_2D_roi1[image_ON_2D_roi1 < threshold_low] = 0
        image_ON_2D_roi1[image_ON_2D_roi1 > threshold_high] = 0
#         image_ON_2D_roi1 = convert_to_photon_num_range(image_ON_2D_roi1)
        if Izero_pump[j]>(meanI0pump-1.2*sigmaI0pump) and Izero_pump[j]<(meanI0pump+1.2*sigmaI0pump):
                spectrum_ON_roi1 += image_ON_2D_roi1.sum(axis=0)/Izero_pump[j]
        
        image_OFF_2D_roi1 = image_roi1_OFF[j,:,:]
        image_OFF_2D_roi1= ju.apply_gain_pede(image_OFF_2D_roi1, G=G_r_roi1, P=P_r_roi1, pixel_mask=mask_r_roi1, highgain=False)
        image_OFF_2D_roi1[image_OFF_2D_roi1 < threshold_low] = 0
        image_OFF_2D_roi1[image_OFF_2D_roi1 > threshold_high] = 0
#         image_OFF_2D_roi1 = convert_to_photon_num_range(image_OFF_2D_roi1)
        if Izero_unpump[j]>(meanI0unpump-1.2*sigmaI0unpump) and Izero_unpump[j]<(meanI0unpump+1.2*sigmaI0unpump):
                spectrum_OFF_roi1 += image_OFF_2D_roi1.sum(axis=0)/Izero_unpump[j]
        
        image_ON_2D_roi2 = image_roi2_ON[j,:,:]
        image_ON_2D_roi2= ju.apply_gain_pede(image_ON_2D_roi2, G=G_r_roi2, P=P_r_roi2, pixel_mask=mask_r_roi2, highgain=False)
        image_ON_2D_roi2[image_ON_2D_roi2 < threshold_low] = 0
        image_ON_2D_roi2[image_ON_2D_roi2 > threshold_high] = 0
#         image_ON_2D_roi2 = convert_to_photon_num_range(image_ON_2D_roi2)
        if Izero_pump[j]>(meanI0pump-1.2*sigmaI0pump) and Izero_pump[j]<(meanI0pump+1.2*sigmaI0pump):
                spectrum_ON_roi2 += image_ON_2D_roi2.sum(axis=0)/Izero_pump[j]
        
        image_OFF_2D_roi2 = image_roi2_OFF[j,:,:]
        image_OFF_2D_roi2= ju.apply_gain_pede(image_OFF_2D_roi2, G=G_r_roi2, P=P_r_roi2, pixel_mask=mask_r_roi2, highgain=False)
        image_OFF_2D_roi2[image_OFF_2D_roi2 < threshold_low] = 0
        image_OFF_2D_roi2[image_OFF_2D_roi2 > threshold_high] = 0
#         image_OFF_2D_roi2 = convert_to_photon_num_range(image_OFF_2D_roi2)
        if Izero_unpump[j]>(meanI0unpump-1.2*sigmaI0unpump) and Izero_unpump[j]<(meanI0unpump+1.2*sigmaI0unpump):
                spectrum_OFF_roi2 += image_OFF_2D_roi2.sum(axis=0)/Izero_unpump[j]
        
print ("Job done! It took",round((time.time() - start_time),2),"seconds to process",np.size(files),"file(s)")
# Out:
# Processing file /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_011/CytC_Fe3_monoscan_350nm_5uJ_500fs_004_step0019.JF02T09V01.h5
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-21-f1c776b0cc12> in <module>()
#      16     print("Processing file %s" % (JF_single_file))
#      17
# ---> 18     (image_roi1_ON,image_roi1_OFF,image_roi2_ON,image_roi2_OFF,pulse_ids) = LoadData_JF(str(JF_single_file))
#      19     (Delay_mm,Energy_eV,Izero_pump,Izero_unpump) = LoadData_BS(str(BS_single_file))
#      20
#
# <ipython-input-10-2af140669b8a> in LoadData_JF(filename)
#       1 def LoadData_JF(filename):
# ----> 2     with h5py.File(filename, 'r') as JF_file:
#       3         pulse_ids = JF_file[channel_pulse_idsJF][:]
#       4         pulse_ids = np.reshape(pulse_ids, (pulse_ids.size,))
#       5
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     267             with phil:
#     268                 fapl = make_fapl(driver, libver, **kwds)
# --> 269                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     270
#     271                 if swmr_support:
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#      97         if swmr and swmr_support:
#      98             flags |= h5f.ACC_SWMR_READ
# ---> 99         fid = h5f.open(name, flags, fapl=fapl)
#     100     elif mode == 'r+':
#     101         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = '/sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_011/CytC_Fe3_monoscan_350nm_5uJ_500fs_004_step0019.JF02T09V01.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
spectrum_total_roi1 = spectrum_OFF_roi1 + spectrum_ON_roi1
spectrum_total_roi2 = spectrum_OFF_roi2 + spectrum_ON_roi2

# %%
x_axis = np.arange(roi1[1][0], roi1[1][1])
plt.figure()

plt.subplot(211)
plt.plot(x_axis,spectrum_total_roi1, label="ROI1", marker='.')
plt.legend(loc="best")
plt.title(jf_file)
x_axis = np.arange(roi2[1][0], roi2[1][1])
plt.subplot(212)
plt.plot(x_axis,spectrum_total_roi2,label="ROI2",marker='.')
plt.legend(loc="best")
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-81fce98d0334> in <module>()
#       3
#       4 plt.subplot(211)
# ----> 5 plt.plot(x_axis,spectrum_total_roi1, label="ROI1", marker='.')
#       6 plt.legend(loc="best")
#       7 plt.title(jf_file)
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1370         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1371
# -> 1372         for line in self._get_lines(*args, **kwargs):
#    1373             self.add_line(line)
#    1374             lines.append(line)
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     402                 this += args[0],
#     403                 args = args[1:]
# --> 404             for seg in self._plot_args(this, kwargs):
#     405                 yield seg
#     406
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     382             x, y = index_of(tup[-1])
#     383
# --> 384         x, y = self._xy_from_xy(x, y)
#     385
#     386         if self.command == 'plot':
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     241         if x.shape[0] != y.shape[0]:
#     242             raise ValueError("x and y must have same first dimension, but "
# --> 243                              "have shapes {} and {}".format(x.shape, y.shape))
#     244         if x.ndim > 2 or y.ndim > 2:
#     245             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (200,) and (1,)

# %%
# Let's check if everything worked out fine, plotting one spectrum for instance the spectra with laser OFF.
# This is for ROI1

x_axis = np.arange(roi1[1][0], roi1[1][1])
plt.figure()

plt.subplot(211)
plt.plot(x_axis,spectrum_OFF_roi1, label="ROI1, Spectra OFF", marker='.')
plt.legend(loc="best")
plt.title(jf_file)
x_axis = np.arange(roi2[1][0], roi2[1][1])
plt.subplot(212)
plt.plot(x_axis,spectrum_OFF_roi2,label="ROI2, Spectra OFF",marker='.')
plt.legend(loc="best")
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-56e278a3aaee> in <module>()
#       6
#       7 plt.subplot(211)
# ----> 8 plt.plot(x_axis,spectrum_OFF_roi1, label="ROI1, Spectra OFF", marker='.')
#       9 plt.legend(loc="best")
#      10 plt.title(jf_file)
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1370         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1371
# -> 1372         for line in self._get_lines(*args, **kwargs):
#    1373             self.add_line(line)
#    1374             lines.append(line)
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     402                 this += args[0],
#     403                 args = args[1:]
# --> 404             for seg in self._plot_args(this, kwargs):
#     405                 yield seg
#     406
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     382             x, y = index_of(tup[-1])
#     383
# --> 384         x, y = self._xy_from_xy(x, y)
#     385
#     386         if self.command == 'plot':
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     241         if x.shape[0] != y.shape[0]:
#     242             raise ValueError("x and y must have same first dimension, but "
# --> 243                              "have shapes {} and {}".format(x.shape, y.shape))
#     244         if x.ndim > 2 or y.ndim > 2:
#     245             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (200,) and (1,)

# %%
# # # This is for plotting laser on-off spectra from Roi1 to look for pump-probe

bin_ = 1   # change the bin size if wanted, 1 is every pixel

spectra_on = spectrum_ON_roi1.copy()
spectra_off = spectrum_OFF_roi1.copy()

x_axis = np.arange(roi1[1][0], roi1[1][1])

spectra_on_rebin1 = rebin_sum(spectra_on)
spectra_off_rebin1 = rebin_sum(spectra_off)
x_axis_rebin1 = rebin_mean(x_axis)

spectra_on_err1=np.sqrt(spectra_on_rebin1)
spectra_off_err1=np.sqrt(spectra_off_rebin1)

plt.figure()
plt.subplot(211)
plt.plot(x_axis_rebin1,spectra_on_rebin1, label="ON",marker='.')
plt.plot(x_axis_rebin1,spectra_off_rebin1, label="OFF",marker='.')
plt.legend(loc="best")
plt.title(jf_file)

low_err= (spectra_on_rebin1 - spectra_off_rebin1)-np.sqrt(spectra_on_err1**2+spectra_off_err1**2)
high_err= (spectra_on_rebin1 - spectra_off_rebin1)+np.sqrt(spectra_on_err1**2+spectra_off_err1**2)
#x_axis_rebin1,
plt.subplot(212)
plt.plot(spectra_on_rebin1 - spectra_off_rebin1, label="ON - OFF",marker='.')
plt.legend(loc="best")
#plt.fill_between(x_axis_rebin1, low_err, high_err, color='lightblue')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-3b90c842d54e> in <module>()
#       3 bin_ = 1   # change the bin size if wanted, 1 is every pixel
#       4
# ----> 5 spectra_on = spectrum_ON_roi1.copy()
#       6 spectra_off = spectrum_OFF_roi1.copy()
#       7
#
# AttributeError: 'int' object has no attribute 'copy'

# %%
# # # This is for plotting laser on-off spectra from Roi2 to look for pump-probe

bin_ = 2     # change the bin size if wanted, 1 is every pixel

spectra_on = spectrum_ON_roi2.copy()
spectra_off = spectrum_OFF_roi2.copy()

x_axis = np.arange(roi2[1][0], roi2[1][1])

spectra_on_rebin2 = rebin_sum(spectra_on)
spectra_off_rebin2 = rebin_sum(spectra_off)
x_axis_rebin2 = rebin_mean(x_axis)

spectra_on_err2=np.sqrt(spectra_on_rebin2)
spectra_off_err2=np.sqrt(spectra_off_rebin2)
plt.figure()
plt.subplot(211)
plt.plot(x_axis_rebin2,spectra_on_rebin2, label="ON",marker='.')
plt.plot(x_axis_rebin2,spectra_off_rebin2, label="OFF",marker='.')
plt.legend(loc="best")
plt.title(jf_file)

low_err= (spectra_on_rebin2 - spectra_off_rebin2)-np.sqrt(spectra_on_err2**2+spectra_off_err2**2)
high_err= (spectra_on_rebin2 - spectra_off_rebin2)+np.sqrt(spectra_on_err2**2+spectra_off_err2**2)

plt.subplot(212)
plt.plot(x_axis_rebin2,spectra_on_rebin2 - spectra_off_rebin2, label="ON - OFF",marker='.')
plt.legend(loc="best")
plt.fill_between(x_axis_rebin2, low_err, high_err, color='lightblue')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-7acc81f0aed7> in <module>()
#       3 bin_ = 2     # change the bin size if wanted, 1 is every pixel
#       4
# ----> 5 spectra_on = spectrum_ON_roi2.copy()
#       6 spectra_off = spectrum_OFF_roi2.copy()
#       7
#
# AttributeError: 'int' object has no attribute 'copy'

# %% [markdown]
# # The next cell is for looping over several files of a scan.

# %%
scan_name ="CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012"          # you need to change only this name

######################################################################################
start_time = time.time()
intermediate_time = time.time()
json_file = DIR_json + scan_name + "_scan_info.json"
print (json_file)

with open(json_file) as file:
    data = json.load(file)
numFiles = len(data['scan_files'])
#numFiles = 1
looptime0 = time.time()
print ("Processing",numFiles,"files")

threshold = 2
photon_range = (1, 3)

Energy_eV = []
Delay_mm = []
XAS_trans_roi1 = []
Error_XAS_roi1 = []
XAS_trans_roi2 = []
Error_XAS_roi2 = []
RIXS_transient_roi1 = []
RIXS_transient_roi2 = []
Error_transient_roi1 = []
Error_transient_roi2 = []
RIXS_unpumped_roi1 = []
RIXS_unpumped_roi2 = []
Error_unpumped_roi1 = []
Error_unpumped_roi2 = []
RIXS_pumped_roi1 = []
RIXS_pumped_roi2 = []
Error_pumped_roi1 = []
Error_pumped_roi2 = []

for i in range(0,numFiles):
    print("step",i+1,"of",numFiles,": Processing %s" % (str(data['scan_files'][i][1])))
    
    spectrum_ON_roi1 = 0
    spectrum_OFF_roi1 = 0
    spectrum_ON_roi2 = 0
    spectrum_OFF_roi2 = 0

    (delay_loop, energy_loop, Izero_pump, Izero_unpump) = LoadData_BS(str(data['scan_files'][i][0]))    
    looptime1 = time.time() - looptime0
    print("t1 = " + str(looptime1) + "  time after load data BS ")
    
    energy_loop = [x for x in energy_loop if (x > 0)]     #This is to prevent that some occasional zeros screw up the mean value calculated below
    delay_loop = [x for x in delay_loop if (x > 0)]       #This is to prevent that some occasional zeros screw up the mean value calculated below
    Delay_mm.append(np.mean(delay_loop))
    Energy_eV.append(np.mean(energy_loop))
    
    meanI0pump = np.median(Izero_pump)
    sigmaI0pump = np.std(Izero_pump)
    meanI0unpump = np.median(Izero_unpump)
    sigmaI0unpump = np.std(Izero_unpump) 
    
    (image_ON_single_roi1,image_OFF_single_roi1,image_ON_single_roi2,image_OFF_single_roi2) = LoadData_JF(str(data['scan_files'][i][1]))
    looptime2 = time.time() - looptime0
    print("t2 = " + str(looptime2)+ "  time after load data JF")  
    
    nframes_ON = np.ma.size(image_ON_single_roi1,0)
    nframes_OFF = np.ma.size(image_OFF_single_roi1,0)
    print (nframes_ON, nframes_OFF)
    
    for j in range(nframes_ON):
        image_ON_2D_roi1 = image_ON_single_roi1[j,:,:]
        image_ON_2D_roi1= ju.apply_gain_pede(image_ON_2D_roi1, G=G_r_roi1, P=P_r_roi1, pixel_mask=mask_r_roi1, highgain=False) 
        image_ON_2D_roi1[image_ON_2D_roi1 < threshold_low] = 0
        image_ON_2D_roi1[image_ON_2D_roi1 > threshold_high] = 0
#         image_ON_2D_roi1 = convert_to_photon_num_range(image_ON_2D_roi1)
        if Izero_pump[j] != 0.: #I0 correction
            spectrum_ON_roi1 += image_ON_2D_roi1.sum(axis=0)/Izero_pump[j]
        
        image_OFF_2D_roi1 = image_OFF_single_roi1[j,:,:]
        image_OFF_2D_roi1= ju.apply_gain_pede(image_OFF_2D_roi1, G=G_r_roi1, P=P_r_roi1, pixel_mask=mask_r_roi1, highgain=False)
        image_OFF_2D_roi1[image_OFF_2D_roi1 < threshold_low] = 0
        image_OFF_2D_roi1[image_OFF_2D_roi1 > threshold_high] = 0
#         image_OFF_2D_roi1 = convert_to_photon_num_range(image_OFF_2D_roi1)
        if Izero_unpump[j] != 0.: #I0 correction
            spectrum_OFF_roi1 += image_OFF_2D_roi1.sum(axis=0)/Izero_unpump[j]
        
        image_ON_2D_roi2 = image_ON_single_roi2[j,:,:]
        image_ON_2D_roi2= ju.apply_gain_pede(image_ON_2D_roi2, G=G_r_roi2, P=P_r_roi2, pixel_mask=mask_r_roi2, highgain=False)
        image_ON_2D_roi2[image_ON_2D_roi2 < threshold_low] = 0
        image_ON_2D_roi2[image_ON_2D_roi2 > threshold_high] = 0
#         image_ON_2D_roi2 = convert_to_photon_num_range(image_ON_2D_roi2)
        if Izero_pump[j] != 0.: #I0 correction
            spectrum_ON_roi2 += image_ON_2D_roi2.sum(axis=0)/Izero_pump[j]
        
        image_OFF_2D_roi2 = image_OFF_single_roi2[j,:,:]
        image_OFF_2D_roi2= ju.apply_gain_pede(image_OFF_2D_roi2, G=G_r_roi2, P=P_r_roi2, pixel_mask=mask_r_roi2, highgain=False)
        image_OFF_2D_roi2[image_OFF_2D_roi2 < threshold_low] = 0
        image_OFF_2D_roi2[image_OFF_2D_roi2 > threshold_high] = 0
#         image_OFF_2D_roi2 = convert_to_photon_num_range(image_OFF_2D_roi2)
        if Izero_unpump[j] != 0.: #I0 correction
            spectrum_OFF_roi2 += image_OFF_2D_roi2.sum(axis=0)/Izero_unpump[j]
    
    #difference_roi1 = spectrum_ON_roi1.sum() - spectrum_OFF_roi1.sum()

    # we do a baseline substraction, then difference btw spectrum ON and OFF
    # and finally we sum the abs of the difference over a ROI in energy to avoid accumulating abs(noise)
    spectrum_ON_roi1_baseline = spectrum_ON_roi1 - spectrum_ON_roi1[0:5:1].mean()
    spectrum_OFF_roi1_baseline = spectrum_OFF_roi1- spectrum_OFF_roi1[0:5:1].mean()
    difference_roi1 = (spectrum_ON_roi1_baseline - spectrum_OFF_roi1_baseline)
    difference_roi1 = np.abs(difference_roi1)[70:95:1].sum()
    
    XAS_trans_roi1.append(difference_roi1)
    error_ON_roi1 = np.sum(np.sqrt(spectrum_ON_roi1))
    error_OFF_roi1 = np.sum(np.sqrt(spectrum_OFF_roi1))
    

    Error_XAS_roi1.append(np.sqrt(error_ON_roi1**2 + error_OFF_roi1**2))
    RIXS_unpumped_roi1.append(spectrum_OFF_roi1)
    Error_unpumped_roi1.append(np.sqrt(spectrum_OFF_roi1))
    RIXS_pumped_roi1.append(spectrum_ON_roi1)
    Error_pumped_roi1.append(np.sqrt(spectrum_ON_roi1))
    RIXS_transient_roi1.append(spectrum_ON_roi1 - spectrum_OFF_roi1)
    Error_transient_roi1.append(np.sqrt(np.sqrt(spectrum_ON_roi1)**2 + np.sqrt(spectrum_OFF_roi1)**2))
    
    difference_roi2 = spectrum_ON_roi2.sum() - spectrum_OFF_roi2.sum()
    XAS_trans_roi2.append(difference_roi2)
    error_ON_roi2 = np.sum(np.sqrt(spectrum_ON_roi2))
    error_OFF_roi2 = np.sum(np.sqrt(spectrum_OFF_roi2))
    
    Error_XAS_roi2.append(np.sqrt(error_ON_roi2**2 + error_OFF_roi2**2))
    RIXS_unpumped_roi2.append(spectrum_OFF_roi2)
    Error_unpumped_roi2.append(np.sqrt(spectrum_OFF_roi2))
    RIXS_pumped_roi2.append(spectrum_ON_roi2)
    Error_pumped_roi2.append(np.sqrt(spectrum_ON_roi2))
    RIXS_transient_roi2.append(difference_roi2)
    Error_transient_roi2.append(np.sqrt(np.sqrt(spectrum_ON_roi2)**2 + np.sqrt(spectrum_OFF_roi2)**2))
    
    print ("It took",round((time.time() - intermediate_time),2),"s to process this file")
    intermediate_time = time.time()
    
Energy_eV = np.array(Energy_eV)
Delay_mm = np.array(Delay_mm)

XAS_trans_roi1 = np.array(XAS_trans_roi1)
Error_XAS_roi1 = np.array(Error_XAS_roi1)
RIXS_unpumped_roi1 = np.array(RIXS_unpumped_roi1)
Error_unpumped_roi1 = np.array(Error_unpumped_roi1)
RIXS_pumped_roi1 = np.array(RIXS_pumped_roi1)
Error_pumped_roi1 = np.array(Error_pumped_roi1)
RIXS_transient_roi1 = np.array(RIXS_transient_roi1)
Error_transient_roi1 = np.array(Error_transient_roi1)

XAS_trans_roi2 = np.array(XAS_trans_roi2)
Error_XAS_roi2 = np.array(Error_XAS_roi2)
RIXS_unpumped_roi2 = np.array(RIXS_unpumped_roi2)
Error_unpumped_roi2 = np.array(Error_unpumped_roi2)
RIXS_pumped_roi2 = np.array(RIXS_pumped_roi2)
Error_pumped_roi2 = np.array(Error_pumped_roi2)
RIXS_transient_roi2 = np.array(RIXS_transient_roi2)
Error_transient_roi2 = np.array(Error_transient_roi2)

print ("Job done! It took",round((time.time() - start_time),2),"seconds to process",numFiles,"file(s)")
# Out:
# /sf/alvra/data/p17803/res/scan_info/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_scan_info.json
# Processing 50 files
# step 1 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0000.JF02T09V01.h5
# t1 = 0.45346999168395996  time after load data BS
# t2 = 236.26458263397217  time after load data JF
# 4000 4000
# It took 245.35 s to process this file
# step 2 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0001.JF02T09V01.h5
# t1 = 245.91991305351257  time after load data BS
# t2 = 454.66196155548096  time after load data JF
# 4000 4000
# It took 212.31 s to process this file
# step 3 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0002.JF02T09V01.h5
# t1 = 458.4125566482544  time after load data BS
# t2 = 716.8577058315277  time after load data JF
# 4000 4000
# It took 265.29 s to process this file
# step 4 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0003.JF02T09V01.h5
# t1 = 723.2740106582642  time after load data BS
# t2 = 954.5452613830566  time after load data JF
# 4000 4000
# It took 239.28 s to process this file
# step 5 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0004.JF02T09V01.h5
# t1 = 962.5828082561493  time after load data BS
# t2 = 1218.5308020114899  time after load data JF
# 4000 4000
# It took 265.8 s to process this file
# step 6 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0005.JF02T09V01.h5
# t1 = 1228.5480370521545  time after load data BS
# t2 = 1458.133955001831  time after load data JF
# 4000 4000
# It took 234.51 s to process this file
# step 7 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0006.JF02T09V01.h5
# t1 = 1463.014677286148  time after load data BS
# t2 = 1682.576013326645  time after load data JF
# 4000 4000
# It took 227.35 s to process this file
# step 8 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0007.JF02T09V01.h5
# t1 = 1690.146522283554  time after load data BS
# t2 = 1846.5497970581055  time after load data JF
# 4000 4000
# It took 161.45 s to process this file
# step 9 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0008.JF02T09V01.h5
# t1 = 1851.6358222961426  time after load data BS
# t2 = 2047.7077963352203  time after load data JF
# 4000 4000
# It took 204.2 s to process this file
# step 10 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0009.JF02T09V01.h5
# t1 = 2055.7854239940643  time after load data BS
# t2 = 2227.653706073761  time after load data JF
# 4000 4000
# It took 179.8 s to process this file
# step 11 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0010.JF02T09V01.h5
# t1 = 2235.622606754303  time after load data BS
# t2 = 2431.6197352409363  time after load data JF
# 4000 4000
# It took 201.93 s to process this file
# step 12 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0011.JF02T09V01.h5
# t1 = 2437.504233598709  time after load data BS
# t2 = 2618.06813621521  time after load data JF
# 4000 4000
# It took 189.05 s to process this file
# step 13 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0012.JF02T09V01.h5
# t1 = 2626.546586036682  time after load data BS
# t2 = 2817.5146086215973  time after load data JF
# 4000 4000
# It took 196.45 s to process this file
# step 14 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0013.JF02T09V01.h5
# t1 = 2823.047964811325  time after load data BS
# t2 = 3000.8463435173035  time after load data JF
# 4000 4000
# It took 184.99 s to process this file
# step 15 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0014.JF02T09V01.h5
# t1 = 3007.9647283554077  time after load data BS
# t2 = 3197.5908992290497  time after load data JF
# 4000 4000
# It took 199.13 s to process this file
# step 16 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0015.JF02T09V01.h5
# t1 = 3207.1354928016663  time after load data BS
# t2 = 3374.60467004776  time after load data JF
# 4000 4000
# It took 171.04 s to process this file
# step 17 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0016.JF02T09V01.h5
# t1 = 3378.203553199768  time after load data BS
# t2 = 3553.2688252925873  time after load data JF
# 4000 4000
# It took 181.42 s to process this file
# step 18 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0017.JF02T09V01.h5
# t1 = 3559.5988290309906  time after load data BS
# t2 = 3730.9894454479218  time after load data JF
# 4000 4000
# It took 178.24 s to process this file
# step 19 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0018.JF02T09V01.h5
# t1 = 3737.8396258354187  time after load data BS
# t2 = 3926.26949095726  time after load data JF
# 4000 4000
# It took 194.55 s to process this file
# step 20 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0019.JF02T09V01.h5
# t1 = 3932.3759021759033  time after load data BS
# t2 = 4112.240448951721  time after load data JF
# 4000 4000
# It took 186.07 s to process this file
# step 21 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0020.JF02T09V01.h5
# t1 = 4118.465240478516  time after load data BS
# t2 = 4290.105421543121  time after load data JF
# 4000 4000
# It took 179.92 s to process this file
# step 22 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0021.JF02T09V01.h5
# t1 = 4298.365658283234  time after load data BS
# t2 = 4472.128657341003  time after load data JF
# 4000 4000
# It took 178.09 s to process this file
# step 23 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0022.JF02T09V01.h5
# t1 = 4476.48934173584  time after load data BS
# t2 = 4636.248687982559  time after load data JF
# 4000 4000
# It took 163.29 s to process this file
# step 24 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0023.JF02T09V01.h5
# t1 = 4639.761422395706  time after load data BS
# t2 = 4817.090093612671  time after load data JF
# 4000 4000
# It took 185.19 s to process this file
# step 25 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0024.JF02T09V01.h5
# t1 = 4824.956413269043  time after load data BS
# t2 = 4993.499974966049  time after load data JF
# 4000 4000
# It took 174.04 s to process this file
# step 26 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0025.JF02T09V01.h5
# t1 = 4999.005006313324  time after load data BS
# t2 = 5170.952836990356  time after load data JF
# 4000 4000
# It took 180.07 s to process this file
# step 27 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0026.JF02T09V01.h5
# t1 = 5179.171160459518  time after load data BS
# t2 = 5360.725075244904  time after load data JF
# 4000 4000
# It took 188.9 s to process this file
# step 28 of 50 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_012_step0027.JF02T09V01.h5
# t1 = 5367.974227666855  time after load data BS

# %%
error_high = XAS_trans_roi1 + Error_XAS_roi1
error_low = XAS_trans_roi1 - Error_XAS_roi1

plt.figure(figsize=(9,5))
plt.subplots_adjust(wspace=0.5)

plt.subplot(211)
plt.title("XAS")
#plt.plot(Energy_eV, XAS_trans_roi1,label="Energy scan",marker='.') #This is the meaningful plot if it is a monoscan
#plt.fill_between(np.squeeze(Energy_eV), error_low, error_high, color='lightblue')
plt.subplot(212)
plt.title("Delay scan")
plt.plot(Delay_mm[0:len(XAS_trans_roi1)], XAS_trans_roi1,label="Delay scan",marker='.') #This is the meaningful plot if it is a delay scan
#plt.fill_between(np.squeeze(Delay_mm), error_low, error_high, color='lightblue')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
#test= gaussian_filter(RIXS_transient_roi1,10)
#print(RIXS_transient_roi1)

# %%
Delay_mm_14 = Delay_mm
XAS_trans_roi1_14 = XAS_trans_roi1
RIXS_unpumped_roi1_14 = RIXS_unpumped_roi1
RIXS_pumped_roi1_14 = RIXS_pumped_roi1
RIXS_transient_roi1_14 = RIXS_transient_roi1

# %%
plt.figure(figsize=(9,5))
plt.subplots_adjust(wspace=0.5)

plt.subplot(211)
plt.title("XAS")
#plt.plot(Energy_eV, XAS_trans_roi1,label="Energy scan",marker='.') #This is the meaningful plot if it is a monoscan
#plt.fill_between(np.squeeze(Energy_eV), error_low, error_high, color='lightblue')
plt.subplot(212)
plt.title("Delay scan")
plt.plot(Delay_mm_14[0:len(XAS_trans_roi1_14)], XAS_trans_roi1_14,label="Delay scan",marker='.') #This is the meaningful plot if it is a delay scan
#plt.fill_between(np.squeeze(Delay_mm), error_low, error_high, color='lightblue')
plt.show()
# Out:
# <div id='58e4cbfe-faff-4087-bdc6-bd50d02655a0'></div>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-27d1c9b4e459> in <module>()
#       8 plt.subplot(212)
#       9 plt.title("Delay scan")
# ---> 10 plt.plot(Delay_mm_14[0:len(XAS_trans_roi1_14)], XAS_trans_roi1_14,label="Delay scan",marker='.') #This is the meaningful plot if it is a delay scan
#      11 #plt.fill_between(np.squeeze(Delay_mm), error_low, error_high, color='lightblue')
#      12 plt.show()
#
# NameError: name 'Delay_mm_14' is not defined

# %%
#extent = [roi[1][0],roi[1][-1],roi[0][0],roi[0][-1]]

plt.figure(figsize=(5,9))
plt.subplots_adjust(hspace=0.5)

plt.subplot(311)
plt.imshow(RIXS_unpumped_roi1_14, aspect = 'auto', cmap = "bwr", origin ="lower")
plt.title("RIXS unpumped")
plt.colorbar()
plt.show()

plt.subplot(312)
plt.imshow(RIXS_pumped_roi1_14, aspect = 'auto', cmap = "bwr", origin ="lower")#, vmin=-250, vmax=250)
plt.title("RIXS pumped")
plt.colorbar()
plt.show()

plt.subplot(313)
plt.imshow(RIXS_transient_roi1_14, aspect = 'auto', cmap = "rainbow", origin ="lower", vmin=-0.01, vmax=0.008)
plt.title("RIXS transient")
plt.colorbar()
plt.show()

#fig.savefig('RIXS_unpumped')
# Out:
# <img src="data:image/png;base64,..." width="499.58333333333337">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6746feb59d94> in <module>()
#       5
#       6 plt.subplot(311)
# ----> 7 plt.imshow(RIXS_unpumped_roi1_14, aspect = 'auto', cmap = "bwr", origin ="lower")
#       8 plt.title("RIXS unpumped")
#       9 plt.colorbar()
#
# NameError: name 'RIXS_unpumped_roi1_14' is not defined

# %%
#### This is to save h5 data ####

savedir = "/das/work/p17/p17803/Processed_files/"

h5f = h5py.File(savedir + 'Scan_14_XES_CytCFe3','w') 
#h5f = h5py.File(savedir + 'timeScan_4.h5','w')     
#h5f = h5py.File(savedir + 'RIXS_144.h5','w')

h5f.create_dataset('Delay_mm', data = Delay_mm)
#h5f.create_dataset('Energy_BS', data = Energy_eV)
h5f.create_dataset('XAS_transient', data = XAS_trans_roi1)
#h5f.create_dataset('Err_XAS_transient', data = Error_XAS_roi1)
h5f.create_dataset('RIXS_unpumped', data = RIXS_unpumped_roi1)
#h5f.create_dataset('Err_RIXS_unpumped', data = Error_unpumped_roi1)
h5f.create_dataset('RIXS_pumped', data = RIXS_pumped_roi1)
h5f.create_dataset('RIXS_transient', data = RIXS_transient_roi1)
#h5f.create_dataset('Err_RIXS_transient', data = Error_transient_roi1)

h5f.close()

# %%
Loaddir  = "/das/work/p17/p17803/Processed_files/"
h5f = h5py.File(Loaddir + 'Scan_10_XES_CytCFe3','r')
h5f.  create_dataset('Delay_mm', data = Delay_mm)

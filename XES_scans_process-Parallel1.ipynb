# %%
# %matplotlib nbagg
import jungfrau_utils as ju
import numpy as np
import json
import h5py
import matplotlib.pyplot as plt
import scipy
from scipy.ndimage.filters import gaussian_filter
from scipy.special import erf
from scipy.optimize import curve_fit
import os
import time
# Out:
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
#Following lines are to define a couple of functions that will be used later.

def rebin_sum(a):
    if a.size%bin_ != 0:
        a = a[0:a.size//bin_ * bin_]

    return a.reshape((-1, bin_)).sum(axis=1)

def rebin_mean(a):
    if a.size%bin_ != 0:
        a = a[0:a.size//bin_ * bin_]

    return a.reshape((-1, bin_)).mean(axis=1)

# Convert energy to a number of photons counting values falling within a particular range.
# This will always return integer photon counts.
def convert_to_photon_num_range(image):
    return np.ceil(np.divide(image - photon_range[0], np.mean(photon_range)))

# Convert energy to a number of photons using the central energy of a single photon.
# This can return fractional number of photons.`
def convert_to_photon_num_mean(image):
    return image / np.mean(photon_range)

# %%
# Take the correct pedestal file (usually located in /sf/alvra/data/*pgroup*/res/JF_pedestals)
# Take the correct gains.h5 file (usually located in /sf/alvra/config/jungfrau/gainMaps/JF02T09V01/)

#pede_file = "/sf/alvra/data/res/p16581/pedestal_20180307_2303_res.h5"
#pede_file = "/sf/alvra/data/p17803/res/JF_pedestals/pedestal_20190131_1436.JF02T09V01.res.h5"
pede_file = "/sf/alvra/data/p17803/res/JF_pedestals/pedestal_20190124_2035.JF02T09V01.res.h5"
gain_file = "/sf/alvra/config/jungfrau/gainMaps/JF02T09V01/gains.h5"

with h5py.File(gain_file, "r") as file: 
    G = file["gains"][:]
    
with h5py.File(pede_file, "r") as file: 
    P = file["gains"][:]
    mask = file["pixel_mask"][:]
    
#print(list(gain_file.keys()))
    
print("Dimensions of G: ", G.shape)

channel_JFimages = "data/JF02T09V01/data"
channel_pulse_idsJF = "data/JF02T09V01/pulse_id"

channel_delay = "data/SLAAR11-LMOT-M451:ENC_1_BS/data"              #Delay of pump-probe delay stage
channel_energy = "data/SLAAR11-LTIM01-EVR0:DUMMY_PV3_NBS/data"      #Mono energy in eV
channel_pulse_idsBS = "data/SLAAR11-LMOT-M451:ENC_1_BS/pulse_id"      #Pulse ids taken from pump-probe delay stage (100 Hz)

#channel_PIPS_trans = "data/SARES11-GES1:CH1_VAL_GET/data"           #X-ray TRANS diode to PRIME Keysight (channel 1)
#channel_PIPS_fluo = "data/SARES11-GES1:CH2_VAL_GET/data"            #X-ray FLUO diode to PRIME Keysight (channel 2)
channel_Izero = "data/SARES11-LSCP10-FNS:CH1:VAL_GET/data"          #Izero diode to PRIME Ioxos (channel 1)
#channel_Izero2 = "data/SARES11-LSCP10-FNS:CH0:VAL_GET/data"          #Izero diode to PRIME Ioxos (channel 0)
#channel_Izero3 = "data/SARES11-LSCP10-FNS:CH3:VAL_GET/data"          #Izero diode to PRIME Ioxos (channel 3)
#channel_Izero4 = "data/SARES11-LSCP10-FNS:CH2:VAL_GET/data"         #Izero diode to PRIME Ioxos (channel 2)
#channel_LaserDiode = "data/SLAAR11-LSCP1-FNS:CH0:VAL_GET/data"      #Laser diode to ESA Laser Ioxos 
#channel_Laser_refDiode = "data/SLAAR11-LSCP1-FNS:CH2:VAL_GET/data"  #Laser diode leaking from beampath, to ESA Laser Ioxos 
#channel_LAM_delaystage = "data/SLAAR11-LTIM01-EVR0:DUMMY_PV2_NBS/data"       #LAM internal stage position in mm
#channel_LAM_stepper = "data/SLAAR11-LTIM01-EVR0:DUMMY_PV10_NBS/data"         #LAM stepper motor (used for feedback)
#channel_PALM_eTOF = "data/SAROP11-PALMK118:CH2_BUFFER/data"                 #PALM eTof from Ch2
#channel_PALM_drift = "data/SAROP11-PALMK118:CH2_VAL_GET/data"               #PALM drift
# Out:
# Dimensions of G:  (4, 512, 9216)

# %%
def LoadData_JF(filename):
    with h5py.File(filename, 'r') as JF_file:
        pulse_ids = JF_file[channel_pulse_idsJF][:]
        pulse_ids = np.reshape(pulse_ids, (pulse_ids.size,))
        
        #reprate_FEL = ((pulse_ids%10 == 0) & (pulse_ids%20 != 0))              #This is for 10 Hz
        #reprate_laser = pulse_ids%20 == 0                                      #This is for 5 Hz
        reprate_FEL = ((pulse_ids%4 == 0) & (pulse_ids%8 != 0))                #This is for 25 Hz
        reprate_laser = pulse_ids%8 == 0                                       #This is for 12.5 Hz
        
        image_JF_ON = JF_file[channel_JFimages][reprate_laser,:,:][...]
        image_JF_OFF = JF_file[channel_JFimages][:,:,:][reprate_FEL]
        
        pulse_ids_ON = pulse_ids[reprate_laser]
        pulse_ids_OFF = pulse_ids[reprate_FEL]
        
        image_roi1_ON = image_JF_ON[:, roi1[0][0]:roi1[0][1], roi1[1][0]:roi1[1][1]]
        image_roi2_ON = image_JF_ON[:, roi2[0][0]:roi2[0][1], roi2[1][0]:roi2[1][1]]
        
        image_roi1_OFF = image_JF_OFF[:, roi1[0][0]:roi1[0][1], roi1[1][0]:roi1[1][1]]
        image_roi2_OFF = image_JF_OFF[:, roi2[0][0]:roi2[0][1], roi2[1][0]:roi2[1][1]]
        
    return image_roi1_ON, image_roi1_OFF, image_roi2_ON, image_roi2_OFF, pulse_ids_ON, pulse_ids_OFF

def LoadData_BS(filename):
    with h5py.File(filename, 'r') as BS_file:
        pulse_ids = BS_file[channel_pulse_idsBS][:]
        pulse_ids = np.reshape(pulse_ids, (pulse_ids.size,))
        
        #reprate_FEL = ((pulse_ids%10 == 0) & (pulse_ids%20 != 0))              #This is for 10 Hz
        #reprate_laser = pulse_ids%20 == 0                                      #This is for 5 Hz
        reprate_FEL = ((pulse_ids%4 == 0) & (pulse_ids%8 != 0))                #This is for 25 Hz
        reprate_laser = pulse_ids%8 == 0                                       #This is for 12.5 Hz
        
        Izero_pump = BS_file[channel_Izero][:][reprate_laser]
        Izero_unpump = BS_file[channel_Izero][:][reprate_FEL]      
        
        delay = BS_file[channel_delay][:][reprate_FEL]
        energy = BS_file[channel_energy][:][reprate_FEL]
        
    return delay, energy, Izero_pump, Izero_unpump

def LoadData_JF_crop(filename):
    with h5py.File(filename, 'r') as JF_file:
        pulse_ids = JF_file[channel_pulse_idsJF][:]
        pulse_ids = np.reshape(pulse_ids, (pulse_ids.size,)) # .ravel()
        
        image_JF = JF_file[channel_JFimages]
        
        image_roi1 = image_JF[:, roi1[0][0]:roi1[0][1], roi1[1][0]:roi1[1][1]]
        image_roi2 = image_JF[:, roi2[0][0]:roi2[0][1], roi2[1][0]:roi2[1][1]]
        
    return image_roi1, image_roi2, pulse_ids

# %%
DIR = "/sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/"
#DIR = "/sf/alvra/data/p17803/raw/"

DIR_json = "/sf/alvra/data/p17803/res/scan_info/"

# !ls -lah -t /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/
#!ls -lah -t /sf/alvra/data/p17803/raw/


# !hostname

listfile = os.listdir(DIR)
number_files = len(listfile)
print ("There are",number_files,"files in the folder", DIR)
# Out:
# total 1.9T
# drwxrwsr-x. 159 root p17803  32K Jan 31 22:55 ..
# drwxrwsr-x.   2 root p17803  32K Jan 26 16:10 .
# -rw-r--r--.   1 root p17803 1.7G Jan 26 16:10 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0051.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 16:08 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0051.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 16:08 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0051.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 16:07 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0050.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 16:06 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0050.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 16:05 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0050.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 16:05 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0049.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 16:03 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0049.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 16:02 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0049.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 16:02 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0048.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 16:00 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0048.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 16:00 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0048.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:59 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0047.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 15:57 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0047.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:57 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0047.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:56 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0046.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 15:54 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0046.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:54 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0046.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:53 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0045.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 15:52 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0045.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:51 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0045.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:51 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0044.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 15:49 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0044.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:48 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0044.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:48 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0043.BSREAD.h5
# -rw-r--r--.   1 root p17803  14M Jan 26 15:46 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0043.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:46 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0043.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:45 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0042.BSREAD.h5
# -rw-r--r--.   1 root p17803  14M Jan 26 15:43 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0042.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:43 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0042.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:42 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0041.BSREAD.h5
# -rw-r--r--.   1 root p17803  14M Jan 26 15:40 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0041.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:40 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0041.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:39 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0040.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 15:38 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0040.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:37 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0040.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:36 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0039.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 15:35 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0039.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:34 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0039.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:34 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0038.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 15:32 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0038.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:31 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0038.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:31 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0037.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 15:29 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0037.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:29 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0037.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:28 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0036.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 15:26 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0036.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:26 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0036.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:25 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0035.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 15:23 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0035.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:23 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0035.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:22 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0034.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 15:21 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0034.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:20 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0034.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:19 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0033.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 15:18 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0033.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:17 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0033.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:17 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0032.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 15:15 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0032.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:14 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0032.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:14 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0031.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 15:12 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0031.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:12 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0031.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:11 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0030.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 15:09 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0030.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:09 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0030.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:08 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0029.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 15:07 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0029.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:06 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0029.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:05 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0028.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 15:04 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0028.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:03 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0028.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:03 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0027.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 15:01 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0027.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 15:01 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0027.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 15:00 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0026.BSREAD.h5
# -rw-r--r--.   1 root p17803  18M Jan 26 14:58 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0026.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 14:58 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0026.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 14:57 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0025.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 14:55 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0025.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 14:55 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0025.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 14:54 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0024.BSREAD.h5
# -rw-r--r--.   1 root p17803  18M Jan 26 14:53 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0024.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 14:52 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0024.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 14:52 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0023.BSREAD.h5
# -rw-r--r--.   1 root p17803  18M Jan 26 14:50 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0023.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 14:49 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0023.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 14:49 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0022.BSREAD.h5
# -rw-r--r--.   1 root p17803  18M Jan 26 14:47 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0022.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 14:47 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0022.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 14:01 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0021.BSREAD.h5
# -rw-r--r--.   1 root p17803  14M Jan 26 13:59 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0021.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:59 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0021.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:59 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0020.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 13:57 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0020.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:56 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0020.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:56 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0019.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 13:54 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0019.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:54 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0019.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:53 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0018.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 13:51 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0018.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:51 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0018.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:50 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0017.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 13:49 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0017.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:48 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0017.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:48 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0016.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 13:46 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0016.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:45 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0016.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:45 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0015.BSREAD.h5
# -rw-r--r--.   1 root p17803  18M Jan 26 13:43 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0015.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:42 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0015.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:42 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0014.BSREAD.h5
# -rw-r--r--.   1 root p17803  18M Jan 26 13:40 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0014.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:40 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0014.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:39 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0013.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 13:37 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0013.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:37 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0013.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:36 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0012.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 13:35 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0012.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:34 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0012.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:34 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0011.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 13:32 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0011.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:31 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0011.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:31 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0010.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 13:29 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0010.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:28 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0010.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:28 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0009.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 13:26 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0009.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:26 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0009.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:25 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0008.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 13:23 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0008.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:23 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0008.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:22 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0007.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 13:21 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0007.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:20 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0007.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:19 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0006.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 13:18 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0006.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:17 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0006.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:17 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0005.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 13:15 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0005.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:15 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0005.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:14 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0004.BSREAD.h5
# -rw-r--r--.   1 root p17803  17M Jan 26 13:12 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0004.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:12 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0004.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:11 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0003.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 13:09 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0003.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:09 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0003.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:08 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0002.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 13:07 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0002.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:06 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0002.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:06 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0001.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 13:04 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0001.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:03 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0001.JF02T09V01.h5
# -rw-r--r--.   1 root p17803 1.7G Jan 26 13:03 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0000.BSREAD.h5
# -rw-r--r--.   1 root p17803  16M Jan 26 13:01 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0000.BSREAD_CA.h5
# -rw-r--r--.   1 root p17803  36G Jan 26 13:01 CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0000.JF02T09V01.h5
# ra-c-009.psi.ch
# There are 156 files in the folder /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/

# %%
# First we load the first images of a file to check if everything is fine with the pedestal & gain files (check highgain True or False)
# We can see also how the ROIs look like (will be useful later)

fileName = "CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0010.JF02T09V01.h5"
#fileName = "CytC_Fe3_timescan_5uJ_288nm_7122eV_003_step0015.JF02T09V01.h5"

jf_file = h5py.File(DIR + fileName)

print(jf_file)

images = jf_file[channel_JFimages]
pulse_ids = jf_file[channel_pulse_idsJF]
print (images.shape)

nframes = 100

#nframes=images.shape(0)

total = 0
threshold_low = 3
threshold_high = 7

#roi = [[225, 325], [6950, 7075]]
#roi = [[225, 325], [7900, 8450]]
roi = [[0, images.shape[1]], [0, images.shape[2]]]

for i in range(nframes):
    image = images[i][:]
    total += ju.apply_gain_pede(image, G=G, P=P, pixel_mask=mask, highgain=False)[roi[0][0]:roi[0][1], roi[1][0]:roi[1][1]]

total /= nframes


plt.figure()
plt.imshow(total, origin="lower", extent = [roi[1][0],roi[1][-1],roi[0][0],roi[0][-1]], aspect='auto', vmin=0, vmax=0.4)
plt.colorbar()
plt.show()
# Out:
# <HDF5 file "CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0010.JF02T09V01.h5" (mode r)>
# (4000, 512, 9216)
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Set the ROIs (roi1 & roi2 in pixels) in the next cell

# %%
# Ka emission 
roi1 = [[200, 300], [6900, 7100]] # change these numbers, here they are for both crystals1 (up & down) overlapped
#roi1 = [[7030, 7130], [220, 290]]
# Kb emission 
roi2 = [[200, 300], [8300, 8450]] # change these numbers, here they are for both crystals2 (up & down) overlapped

##################################################################

P_r_roi2 = P[:, roi2[0][0]:roi2[0][1], roi2[1][0]:roi2[1][1]]
G_r_roi2 = G[:, roi2[0][0]:roi2[0][1], roi2[1][0]:roi2[1][1]]
mask_r_roi2 = mask[roi2[0][0]:roi2[0][1], roi2[1][0]:roi2[1][1]]

P_r_roi1 = P[:, roi1[0][0]:roi1[0][1], roi1[1][0]:roi1[1][1]]
G_r_roi1 = G[:, roi1[0][0]:roi1[0][1], roi1[1][0]:roi1[1][1]]
mask_r_roi1 = mask[roi1[0][0]:roi1[0][1], roi1[1][0]:roi1[1][1]]

# %%
scan_name ="CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013"                          # you need to change  this name
saveDir = "/das/work/p17/p17803/alvra_beamline_scripts/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_crop/"    # dest folder (needs to exist)

######################################################################################
start_time = time.time()

intermediate_time = time.time()
json_file = DIR_json + scan_name + "_scan_info.json"
print (json_file)

with open(json_file) as file:
    data = json.load(file)
numFiles = len(data['scan_files'])
#numFiles = 2
looptime0 = time.time()
print ("Processing",numFiles,"files")

for i in range(0,numFiles):
    print("step",i+1,"of",numFiles,": Processing %s" % (str(data['scan_files'][i][1])))
    
    (Image_roi1, Image_roi2, Pulse_ids) = LoadData_JF_crop(str(data['scan_files'][i][1]))
    
    nframes = Pulse_ids.size
    #nframes = 10
    fn = str(saveDir + scan_name + "_crop_" + str(i) +".h5")
    with h5py.File(fn, "w") as file2write:
        grp = file2write.create_group("JF02T09V01_crop")
        dstroi1 = grp.create_dataset("roi1", shape = (nframes,) + mask_r_roi1.shape)
        dstroi2 = grp.create_dataset("roi2", shape = (nframes,) + mask_r_roi2.shape)
        dstPID = grp.create_dataset("pulse_ids", shape=(nframes, ), dtype=np.uint64)
        dstPID[:] = Pulse_ids[0:nframes]
    
        for j in range(nframes):
            image_2D_roi1 = Image_roi1[j,:,:]
            image_2D_roi1= ju.apply_gain_pede(image_2D_roi1, G=G_r_roi1, P=P_r_roi1, pixel_mask=mask_r_roi1, highgain=False) 
            dstroi1[j,:,] = image_2D_roi1
        
            image_2D_roi2 = Image_roi2[j,:,:]
            image_2D_roi2= ju.apply_gain_pede(image_2D_roi2, G=G_r_roi1, P=P_r_roi1, pixel_mask=mask_r_roi1, highgain=False)
            dstroi2[j,:,:] = image_2D_roi2
            
    print ("It took",round((time.time() - intermediate_time),2),"s to process this file")
    intermediate_time = time.time()

print ("Job done! It took",round((time.time() - start_time),2),"seconds to process",numFiles,"file(s)")
# Out:
# /sf/alvra/data/p17803/res/scan_info/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_scan_info.json
# Processing 52 files
# step 1 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0000.JF02T09V01.h5
# It took 181.3 s to process this file
# step 2 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0001.JF02T09V01.h5
# It took 180.91 s to process this file
# step 3 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0002.JF02T09V01.h5
# It took 182.61 s to process this file
# step 4 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0003.JF02T09V01.h5
# It took 180.71 s to process this file
# step 5 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0004.JF02T09V01.h5
# It took 179.25 s to process this file
# step 6 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0005.JF02T09V01.h5
# It took 184.51 s to process this file
# step 7 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0006.JF02T09V01.h5
# It took 260.24 s to process this file
# step 8 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0007.JF02T09V01.h5
# It took 264.35 s to process this file
# step 9 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0008.JF02T09V01.h5
# It took 259.91 s to process this file
# step 10 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0009.JF02T09V01.h5
# It took 265.07 s to process this file
# step 11 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0010.JF02T09V01.h5
# It took 259.6 s to process this file
# step 12 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0011.JF02T09V01.h5
# It took 256.28 s to process this file
# step 13 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0012.JF02T09V01.h5
# It took 267.32 s to process this file
# step 14 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0013.JF02T09V01.h5
# It took 257.01 s to process this file
# step 15 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0014.JF02T09V01.h5
# It took 263.73 s to process this file
# step 16 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0015.JF02T09V01.h5
# It took 249.74 s to process this file
# step 17 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0016.JF02T09V01.h5
# It took 257.77 s to process this file
# step 18 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0017.JF02T09V01.h5
# It took 254.68 s to process this file
# step 19 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0018.JF02T09V01.h5
# It took 249.94 s to process this file
# step 20 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0019.JF02T09V01.h5
# It took 252.19 s to process this file
# step 21 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0020.JF02T09V01.h5
# It took 252.17 s to process this file
# step 22 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0021.JF02T09V01.h5
# It took 250.69 s to process this file
# step 23 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0022.JF02T09V01.h5
# It took 240.75 s to process this file
# step 24 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0023.JF02T09V01.h5
# It took 249.29 s to process this file
# step 25 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0024.JF02T09V01.h5
# It took 244.13 s to process this file
# step 26 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0025.JF02T09V01.h5
# It took 241.69 s to process this file
# step 27 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0026.JF02T09V01.h5
# It took 248.72 s to process this file
# step 28 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0027.JF02T09V01.h5
# It took 243.36 s to process this file
# step 29 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0028.JF02T09V01.h5
# It took 242.86 s to process this file
# step 30 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0029.JF02T09V01.h5
# It took 244.46 s to process this file
# step 31 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0030.JF02T09V01.h5
# It took 247.7 s to process this file
# step 32 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0031.JF02T09V01.h5
# It took 250.37 s to process this file
# step 33 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0032.JF02T09V01.h5
# It took 250.24 s to process this file
# step 34 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0033.JF02T09V01.h5
# It took 251.07 s to process this file
# step 35 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0034.JF02T09V01.h5
# It took 259.27 s to process this file
# step 36 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0035.JF02T09V01.h5
# It took 261.49 s to process this file
# step 37 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0036.JF02T09V01.h5
# It took 263.15 s to process this file
# step 38 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0037.JF02T09V01.h5
# It took 251.02 s to process this file
# step 39 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0038.JF02T09V01.h5
# It took 245.45 s to process this file
# step 40 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0039.JF02T09V01.h5
# It took 260.8 s to process this file
# step 41 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0040.JF02T09V01.h5
# It took 269.77 s to process this file
# step 42 of 52 : Processing /sf/alvra/data/p17803/raw/scan_data/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013/CytC_Fe3_XES_timescan_7p5uJ_350nm_8000eV_013_step0041.JF02T09V01.h5

# %%
print (image_2D_roi1.shape)
print (Image_roi1.shape)

# %%
fn = str(saveDir + scan_name + "_" + str(numFiles) + "_crop.h5")

# %%
# !h5ls /das/work/p17/p17803/alvra_beamline_scripts/Test_save/CytC_Fe3_XES_timescan_5uJ_288nm_8000eV_010_crop.h5 -rd

# %%
#fn = "/das/work/p17/p17803/alvra_beamline_scripts/Test_save/FeBpy_monoscan_350nm_10uJ_500fs_007_crop_0.h5"
jf_file = h5py.File(fn)
imageROI1 = jf_file["JF02T09V01_crop/roi1"]
h5py.File.close
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-cbef77081058> in <module>()
#       1 #fn = "/das/work/p17/p17803/alvra_beamline_scripts/Test_save/FeBpy_monoscan_350nm_10uJ_500fs_007_crop_0.h5"
#       2 jf_file = h5py.File(fn)
# ----> 3 imageROI1 = jf_file["JF02T09V01_crop/roi1"]
#       4 h5py.File.close
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/h5py/_hl/group.py in __getitem__(self, name)
#     165                 raise ValueError("Invalid HDF5 object reference")
#     166         else:
# --> 167             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     168
#     169         otype = h5i.get_type(oid)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5o.pyx in h5py.h5o.open()
#
# KeyError: 'Unable to open object (component not found)'

# %%
imageROI1.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-b9d12560ca15> in <module>()
# ----> 1 imageROI1.shape
#
# NameError: name 'imageROI1' is not defined

# %%
plt.figure()
plt.imshow(imageROI1[2], aspect='auto')
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-f8c80a4cd75b> in <module>()
#       1 plt.figure()
# ----> 2 plt.imshow(imageROI1[2], aspect='auto')
#       3 plt.colorbar()
#       4 plt.show()
#
# NameError: name 'imageROI1' is not defined
